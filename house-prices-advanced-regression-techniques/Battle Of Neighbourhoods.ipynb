# %% [markdown]
# # House Pricing Capstone Project

# %% [markdown]
# Author - Dhaval Javia

# %% [markdown]
# ### Problem Statement:

# %% [markdown]
# Hello, My name is Dhaval Javia and I am from India currently working at Infosys. I was thinking to moving abroad and for that first thing you search for when you reach there is House to stay (Of course Food comes first but for now let's keep the hungar  aside.) So i want house on rent which i can afford, so initially price is the factor for me. After i stabilize in the country, i can go for buying a house so i need some sort of system where i can search and compare house rent prices as per neighborhood.

# %% [markdown]
# ### Business Model:

# %% [markdown]
# By the end of this notebook, we should be able to decide housing prices for neighborhood based on features and location and many other dependent parameters. Main focus of audiance is the person living in State for quite some time and now wants a house of his/her own in a choice of neighborhood.

# %% [markdown]
# ### Data Description

# %% [markdown]
# Ask a home buyer to describe their dream house, and they probably won't begin with the height of the basement ceiling or the proximity to an east-west railroad. But this dataset proves that much more influences price negotiations than the number of bedrooms or a white-picket fence.

# %% [markdown]
# Following Data will be used to solve the problem at hand.
#
# 1. Neighborhood data from Foursquare API
# 10. Location data from geopy or foursquare API.
# 20. Pricing dataset with house features.

# %% [markdown]
# ### Data Sources

# %% [markdown]
# We have data available from varius sources but i found this houses on rent price dataset from below sources which requies a lot of data scraping skills and time and processing power. Also, it had all the data avaiable like latitude, longitude, street name, apartment name, rent price, bathrooms and bedrooms.
# For extra features, we will use Foursquare API for nearby popular locations.

# %% [markdown]
# 1. Location data and neighborhood data from Foursquare API
# 2. Raw datase creation using web scraping from https://www.torontorentals.com/toronto
# 3. Pair Plots used for correlation. https://towardsdatascience.com/visualizing-data-with-pair-plots-in-python-f228cf529166

# %% [markdown]
# ### Methodology

# %% [markdown]
# Now, first of all, fetching data from website. Yeah its not an easy task especially when there are 5 home groups on a single webpage which has individual links and each group has multiple options of house as per features and price. Phew!

# %% [markdown]
# Following details are available in the dataset with description.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
# %matplotlib inline
# !pip install geocoder
# !pip install selenium
# !pip install geopy
# !pip install pgeocode
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
import requests
import urllib.request
import time
# !pip install geolocator.geocode
# !pip install geopy
from geopy.geocoders import Nominatim
import json
import re
# Out:
# Requirement already satisfied: geocoder in c:\anaconda3\lib\site-packages (1.38.1)
# Requirement already satisfied: six in c:\anaconda3\lib\site-packages (from geocoder) (1.14.0)
# Requirement already satisfied: ratelim in c:\anaconda3\lib\site-packages (from geocoder) (0.1.6)
# Requirement already satisfied: future in c:\anaconda3\lib\site-packages (from geocoder) (0.18.2)
# Requirement already satisfied: requests in c:\anaconda3\lib\site-packages (from geocoder) (2.22.0)
# Requirement already satisfied: click in c:\anaconda3\lib\site-packages (from geocoder) (7.0)
# Requirement already satisfied: decorator in c:\anaconda3\lib\site-packages (from ratelim->geocoder) (4.4.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda3\lib\site-packages (from requests->geocoder) (2019.11.28)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\anaconda3\lib\site-packages (from requests->geocoder) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\anaconda3\lib\site-packages (from requests->geocoder) (1.25.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\anaconda3\lib\site-packages (from requests->geocoder) (3.0.4)
# Requirement already satisfied: selenium in c:\anaconda3\lib\site-packages (3.141.0)
# Requirement already satisfied: urllib3 in c:\anaconda3\lib\site-packages (from selenium) (1.25.8)
# Requirement already satisfied: geopy in c:\anaconda3\lib\site-packages (1.21.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in c:\anaconda3\lib\site-packages (from geopy) (1.50)
# Requirement already satisfied: pgeocode in c:\anaconda3\lib\site-packages (0.2.1)
# Requirement already satisfied: numpy in c:\anaconda3\lib\site-packages (from pgeocode) (1.18.1)
# Requirement already satisfied: pandas in c:\anaconda3\lib\site-packages (from pgeocode) (1.0.1)
# Requirement already satisfied: requests in c:\anaconda3\lib\site-packages (from pgeocode) (2.22.0)
# Requirement already satisfied: pytz>=2017.2 in c:\anaconda3\lib\site-packages (from pandas->pgeocode) (2019.3)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\anaconda3\lib\site-packages (from pandas->pgeocode) (2.8.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\anaconda3\lib\site-packages (from requests->pgeocode) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda3\lib\site-packages (from requests->pgeocode) (2019.11.28)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\anaconda3\lib\site-packages (from requests->pgeocode) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\anaconda3\lib\site-packages (from requests->pgeocode) (1.25.8)
# Requirement already satisfied: six>=1.5 in c:\anaconda3\lib\site-packages (from python-dateutil>=2.6.1->pandas->pgeocode) (1.14.0)
# ERROR: Could not find a version that satisfies the requirement geolocator.geocode (from versions: none)
# ERROR: No matching distribution found for geolocator.geocode
# Requirement already satisfied: geopy in c:\anaconda3\lib\site-packages (1.21.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in c:\anaconda3\lib\site-packages (from geopy) (1.50)

# %% [markdown]
# So, what i did is that i used the raw url link and observed it how it is changing with each webpage. So it was quite easy and just neeeded was the for loop of request and response.
# Then again i didn't want to increase load on website so i just saved each response in a webpage and then read it from there.
#
# Below is the code used for fetching and saving response or urls.

# %%
# all_web_pages = {}
# for i in range(0,260):
#     url = 'https://www.torontorentals.com/toronto?p=' + str(i+1)
#     print(url)
#     all_web_pages[i] = requests.get(url)

# %%
# for i in range(0,260):
#     filename = "./htmls/" + str(i) + '.html'
#     print(filename)
#     with open(filename, "w", encoding="utf-8") as f:
#         f.write(all_web_pages[i].text)

# %% [markdown]
# Alright, the tricky part, processing htmls and fetching data between SCRIPT HTML tag. and using BeautifulSoup to get the content  inside the tag and using url(inside tag content) to fetch various configurations related to configuration and price.
#
# Once we looped in all the requied data in separate lists. we will create dataframe and save its content in a CSV.
# Now the following data takes a long time to run as it searches all urls and extracts requied data. Took about 2 hrs to fetch and format data for all 3000 rows.So we have commented below code to prevent execution again.
#
# We can save data to a dataframe and then export it to CSV.
# We will use that CSV for later use and rerun of project.

# %%
# from os import listdir

# columns = ['ApartmentName','latitude','longitude', 'NoofBedrooms','NoofBathrooms']
# apartname = []
# latitude1 = []
# longi = []
# bedrms = []
# bathrms = []
# priceL = []
# streetnames = []
# #iterating through each html for content
# j = 0
# for each in listdir("./htmls/"):
#     filename = './htmls/' + each
#     with open(filename, "r", encoding="utf-8") as f:
#         response1 = f.read()                 #saving response of each request to response1 var
        
#     #using soap to find script tag in html content
#     soap1 = BeautifulSoup(response1,"html.parser")
#     #soap1
#     script_dump = soap1.find_all("script")
    
#     #3 to -6 is defined after testing and found that all the necessary elements are in range. Although -1 contains all location,
#     # and other url infos which we could have used, but Meh. Ma Project, Ma rules!!!.
    
#     #iterating through each script html tag
#     for group in script_dump[3:-6]:
#         test1 = group
#         test2 = BeautifulSoup(test1.text,"html.parser")
        
#         #saving all necessary things like name, location, streetname, price, apartment type blah blah.
#         newDictionary=json.loads(test2.text)
#         NameofApartment = newDictionary['name']
#         streetAddress = newDictionary['address']['streetAddress']
#         print('---------------ApartMent Name:- ',NameofApartment,"------------------")
        
#         #getting url for the group and fetching more data from there like price, apartment type, no of bathrooms, etc.
#         response2 = requests.get(newDictionary['url'])
#         sub_soap = BeautifulSoup(response2.text,"html.parser")
#         sub_soap
#         table = sub_soap.find_all('td')
#         price_lst = sub_soap.find_all('td',{"class": "price"})
#         beds_lst = sub_soap.find_all('td',{"class": "beds"})
#         baths_lst = sub_soap.find_all('td',{"class": "baths"})
#         beds_lst = sub_soap.find_all('td',{"class": "baths"})
#         print(len(price_lst))
#         #print("Table:-- ", table)
#         #print((len(table)//5)*5)
#         #print(table)
#         for i in range(0,len(price_lst)):
            
# #             beds = BeautifulSoup((table[i+1]).text,"html.parser")
# #             bath = BeautifulSoup((table[i+2]).text,"html.parser")
# #             price = BeautifulSoup((table[i+3]).text,"html.parser")
# #             #price = str(price).split('\n')[1]
# #             print(newDictionary['url'])
#             beds = beds_lst[i].text.replace('\n','')
#             bath = baths_lst[i].text.replace('\n','')
#             price = price_lst[i].text.replace('\n','')
#             print("No of bedrooms are {}, No of bathrooms are {}, Price is {}".format(beds,bath,price))
#             apartname.append(NameofApartment)
#             streetnames.append(streetAddress)
#             priceL.append(price)
#             bedrms.append(beds)
#             bathrms.append(bath)
#             #latitude1.append(latitude)
#             #longi.append(longitude)
            
#             #saving all data in CSV and dataframe
#             #print({'ApartmentName':NameofApartment,'latitude':latitude,'longitude':longitude,'NoofBedrooms':beds,'NoofBathrooms':bath,'Price':price})

# %%
# type(priceL)
# columns = ['ApartmentName', 'Streetname' , 'NoofBedrooms','NoofBathrooms', 'Price']
# print(columns)
# df = pd.DataFrame(columns=columns)
# df['Price'] = priceL
# df['ApartmentName'] = apartname
# df['NoofBathrooms'] = bathrms
# df['NoofBedrooms'] = bedrms
# #df['latitude'] = latitude1
# #df['longitude'] = longi
# df['Streetname'] = streetnames
# #df = df.append({'ApartmentName':NameofApartment,'latitude':latitude,'longitude':longitude,'NoofBedrooms':beds,'NoofBathrooms':bath,'Price':price},ignore_index=True)
# df.head()

# %%
#df.to_csv('./raw_df.csv')

# %%
#str(price).split('\n')[1]
# df = pd.read_csv('./raw_df.csv',index_col=None)
# df.drop('Unnamed: 0',inplace=True,axis=1)

# %%
#response1 = all_web_pages[5]
# df.shape
# Out:
# (2982, 5)

# %%
# df.head()
# Out:
#             ApartmentName              Streetname NoofBedrooms NoofBathrooms  \
# 0  571 Prince Edward Dr N  571 Prince Edward Dr N            1             1
# 1  571 Prince Edward Dr N  571 Prince Edward Dr N            1             1
# 2  571 Prince Edward Dr N  571 Prince Edward Dr N            2             2
# 3  571 Prince Edward Dr N  571 Prince Edward Dr N            2             2
# 4                eCentral       15 Roehampton Ave            1             1
#
#       Price
# 0    $2,000
# 1    $2,300
# 2    $2,700
# 3    $3,850
# 4  $2,002.5

# %%
# response = requests.get('https://www.torontorentals.com/toronto')
# soap = BeautifulSoup(response.text,"html.parser")
# script_dump = soap.find_all('script')
# #script_dump[-1]

# %%
# f1 = re.sub("\n    \n      \n        \n        \n        \n\n        ",'', script_dump[-1].text)
# f1 = re.sub("\n    const markers = \[\];","",f1)
# f1 = re.sub("\n        ","",f1)
# f1 = re.sub("\n       ",'',f1)
# f1 = re.sub('   ','',f1)
# f1 = re.sub('\n\n','',f1)
# f1 = re.sub('markers.push\(','',f1)
# f1 = re.sub('\n','',f1)
# f1 = re.sub('\)','',f1)
# f2 = re.split(r'\;',f1)
# name_of_apt_dict = {}

# for i in range(0,len(f2)):
#     try:
#         name = re.sub("\'","",re.sub("\"","",(re.findall(r'name:\s(.*?),',f2[i])[0])))
#         streetname = re.sub("\'","",re.sub("\"","",(re.findall(r'street:\s(.*?),',f2[i])[0])))
#         name_of_apt_dict[str(name)] = str(streetname.split('|')[0])
# #         print("name of apartment:- {}".format(name))
# #         print('streetname:- {}'.format(streetname))
# #         print(i)
#     except:
#         pass

# %%
#print(name_of_apt_dict.keys())
# df['Streetname'] = ''
# for key in (name_of_apt_dict.keys()):
#     df.loc[df['ApartmentName'] == key,'Streetname'] = name_of_apt_dict[key]

# %%
# print(df)
# df.to_csv('./raw_df.csv')

# %%
# df.head()
# Out:
#             ApartmentName              Streetname NoofBedrooms NoofBathrooms  \
# 0  571 Prince Edward Dr N  571 Prince Edward Dr N            1             1
# 1  571 Prince Edward Dr N  571 Prince Edward Dr N            1             1
# 2  571 Prince Edward Dr N  571 Prince Edward Dr N            2             2
# 3  571 Prince Edward Dr N  571 Prince Edward Dr N            2             2
# 4                eCentral       15 Roehampton Ave            1             1
#
#       Price
# 0    $2,000
# 1    $2,300
# 2    $2,700
# 3    $3,850
# 4  $2,002.5

# %%
# new_df = df.ApartmentName.str.split("|",expand=True)
# new_df = new_df[[0]]
# new_df
# Out:
#                            0
# 0     571 Prince Edward Dr N
# 1     571 Prince Edward Dr N
# 2     571 Prince Edward Dr N
# 3     571 Prince Edward Dr N
# 4                   eCentral
# ...                      ...
# 2977            Niagara West
# 2978            Niagara West
# 2979            Niagara West
# 2980            Niagara West
# 2981            Niagara West
#
# [2982 rows x 1 columns]

# %%
# df['ApartmentName'] = new_df

# %%
# df.head()
# Out:
#             ApartmentName              Streetname NoofBedrooms NoofBathrooms  \
# 0  571 Prince Edward Dr N  571 Prince Edward Dr N            1             1
# 1  571 Prince Edward Dr N  571 Prince Edward Dr N            1             1
# 2  571 Prince Edward Dr N  571 Prince Edward Dr N            2             2
# 3  571 Prince Edward Dr N  571 Prince Edward Dr N            2             2
# 4                eCentral       15 Roehampton Ave            1             1
#
#       Price
# 0    $2,000
# 1    $2,300
# 2    $2,700
# 3    $3,850
# 4  $2,002.5

# %%
# df['Latitude'] = ''
# df['Longitude'] = ''
# aptnames_unique = df['ApartmentName'].unique()
# #print(aptnames_unique)
# geolocator = Nominatim(user_agent='myagent')
# dict_location = {}
# for each in aptnames_unique:
#     try:
#         each1 = each + ', Toronto'
#         location = geolocator.geocode(each1)
#         dict_location[each] = [location.latitude, location.longitude]
#         print('Address,lat,long:-',each1,location.latitude,location.longitude)
#     except:
#         pass
# Out:
# Address,lat,long:- 571 Prince Edward Dr N, Toronto 43.660515 -79.5102122
# Address,lat,long:- Kings Club, Toronto 43.640191900000005 -79.42302333946935
# Address,lat,long:- 70 Ruddington Drive, Toronto 43.792570299999994 -79.390885
# Address,lat,long:- Clipper Place, Toronto 43.7876206 -79.33149899843514
# Address,lat,long:- 665 Roselawn Avenue, Toronto 43.7050725 -79.42486674989438
# Address,lat,long:- 1182 Ossington Ave , Toronto 43.673361150000005 -79.43058640833334
# Address,lat,long:- 43 Eglinton Avenue East, Toronto 43.706932 -79.396963
# Address,lat,long:- Penrose Building, Toronto 43.659694349999995 -79.38592832974705
# Address,lat,long:- 10 Navy Wharf Ct, Toronto 43.6404321 -79.3920708
# Address,lat,long:- 222 The Esplanade, Toronto, Toronto 43.6495673 -79.3655213
# Address,lat,long:- (#1271), Toronto -34.8899421 -56.0790982
# Address,lat,long:- 5 Valhalla Inn Rd, Toronto 43.6410767 -79.5593612
# Address,lat,long:- 145 Marlee Ave, Toronto 43.7036555 -79.4408534
# Address,lat,long:- 22 Olive Avenue, Toronto 43.77893771666666 -79.41425053333333
# Address,lat,long:- 111 Saint Clair Avenue West, Toronto 43.68666265 -79.39948655
# Address,lat,long:- 23 Brant Street, Toronto 43.64591115 -79.39657150688737
# Address,lat,long:- 473 Dupont Street, Toronto 43.6728586 -79.4150702
# Address,lat,long:- 88 Grandview Way , Toronto 43.77464285 -79.41220533983518
# Address,lat,long:- 10 Park Lawn Rd , Toronto 43.6229459 -79.4816583
# Address,lat,long:- 3504 Hurontario St , Toronto 43.62183 -79.67481685000001
# Address,lat,long:- 2 Massey Square, Toronto 43.696371 -79.2933538
# Address,lat,long:- 120 Raglan Avenue, Toronto 43.6862903 -79.4210315
# Address,lat,long:- 52 Clubhouse Ct, Toronto 43.743604710321165 -79.49973612180959
# Address,lat,long:- The Jack, Toronto 43.6403707 -79.3752617
# Address,lat,long:- 6 Jackes Ave , Toronto 43.685190500000004 -79.39251150000001
# Address,lat,long:- Massey Tower, Toronto 43.6533905 -79.37925784226252
# Address,lat,long:- 1 Lord Seaton Rd, Toronto 43.752423500000006 -79.40717006560283
# Address,lat,long:- 1650 Bathurst Street, Toronto 43.6938145 -79.4231232
# Address,lat,long:- 1065 Eglinton Ave. West, Toronto 43.698844 -79.43397280559601
# Address,lat,long:- 2402-2406 Queen St. East, Toronto 43.67449572727273 -79.27992741818183
# Address,lat,long:- 3896 Bathurst Street, Toronto 43.743918949999994 -79.43618223265409
# Address,lat,long:- York Mills and Leslie, Toronto 43.733797100000004 -79.35795323049351
# Address,lat,long:- 455 Queen St W , Toronto 43.6484611 -79.3971442
# Address,lat,long:- 20 Wardlaw Crescent, Toronto 43.73957410434439 -79.564661977088
# Address,lat,long:- The Kip, Toronto 43.633903700000005 -79.54085560886429
# Address,lat,long:- 2A Tiverton Ave , Toronto 43.6643348 -79.3453531
# Address,lat,long:- 1202 York Mills Road - The York Mills, Toronto 43.7479925 -79.3842263
# Address,lat,long:- 1200 York Mills Road - The York Mills, Toronto 43.7479925 -79.3842263
# Address,lat,long:- 15 Iceboat Terr, Toronto 43.6405275 -79.39680993843717
# Address,lat,long:- 260 Doris Ave , Toronto 43.772128699999996 -79.41232594691738
# Address,lat,long:- 31 Bales Ave, Toronto 43.7600538 -79.40890361563143
# Address,lat,long:- 1427 Lansdowne Ave, Toronto 43.67551587370444 -79.45003741085188
# Address,lat,long:- 33 Hellensfield Crescent, Toronto 43.66133278068947 -79.58532666657128
# Address,lat,long:- 488 University Ave, Toronto 43.6551808 -79.3888064
# Address,lat,long:- 87 Peter St , Toronto 43.6468429 -79.3924735
# Address,lat,long:- 388 Bloor St E, Toronto 43.6725485 -79.3774858372642
# Address,lat,long:- 85 E Liberty St , Toronto 43.6378584 -79.41547648236936
# Address,lat,long:- 84 Falmouth Ave, Toronto 43.7353867 -79.2532082
# Address,lat,long:- 2356 Sheppard Ave W , Toronto 43.7339199 -79.538017
# Address,lat,long:- Metro Condominiums, Toronto 43.775486 -79.3450895
# Address,lat,long:- Treviso 1, Toronto 45.7825254 12.0728856
# Address,lat,long:- 97 Granby St, Toronto 43.6612595 -79.378602
# Address,lat,long:- 655 Manning Ave , Toronto 43.663871711111106 -79.41589309999999
# Address,lat,long:- 1202 Royal York Rd , Toronto 43.66549095 -79.5196211
# Address,lat,long:- 460 Adelaide St E , Toronto 43.652675 -79.366632
# Address,lat,long:- London on the Esplanade, Toronto 43.64698945 -79.37472225254237
# Address,lat,long:- 68 Merton St , Toronto 43.696768270270276 -79.39356216216217
# Address,lat,long:- 44 Sixteenth St, Toronto 43.60045805 -79.515944375
# Address,lat,long:- King's Club, Toronto 43.640191900000005 -79.42302333946935
# Address,lat,long:- 6 Fuller Ave, Toronto 43.6404959 -79.4394167
# Address,lat,long:- 4727 Sheppard Ave E , Toronto 43.7894745 -79.25356784523811
# Address,lat,long:- 190 Exbury Road, Toronto 43.72925025 -79.50919335
# Address,lat,long:- 62 Forest Manor Rd, Toronto 43.7723652 -79.3445747
# Address,lat,long:- Residences of The World Trade Centre, Toronto 43.64216025 -79.3756933449112
# Address,lat,long:- Chaz Yorkville, Toronto 43.66878375 -79.38392758840939
# Address,lat,long:- Montage LE, Toronto 43.64103195 -79.39440224659694
# Address,lat,long:- 64 Oxford St , Toronto 43.6561259 -79.4029349
# Address,lat,long:- 60 Heintzman St, Toronto 43.666996600000004 -79.46469428603879
# Address,lat,long:- 340 Avenue Road, Toronto 43.6808355 -79.39946209986928
# Address,lat,long:- 17 Dobbin Rd, Toronto 43.77334498450807 -79.31690204840858
# Address,lat,long:- 3237 Bayview Ave , Toronto 43.7899793 -79.3929389
# Address,lat,long:- Empire Plaza, Toronto 43.64621855 -79.38357684874603
# Address,lat,long:- 37 Garden Ave, Toronto 43.64482066348361 -79.44150609505698
# Address,lat,long:- 36 Park Lawn Rd , Toronto 43.62354279208538 -79.482974462424
# Address,lat,long:- 2200 Lake Shore Blvd W , Toronto 43.6229142 -79.4816461
# Address,lat,long:- 16 Brookers Ln , Toronto 43.6269302 -79.4785104
# Address,lat,long:- 80 Marine Parade Dr , Toronto 43.6248298 -79.4773738
# Address,lat,long:- 414 Willowdale Avenue, Toronto 43.7772425 -79.4056625112851
# Address,lat,long:- 44 Nursewood Rd, Toronto 43.673461918181815 -79.2812843590909
# Address,lat,long:- 110 Bloor St W, Toronto 43.6696732 -79.392085
# Address,lat,long:- 55 E Liberty St, Toronto 43.6386004 -79.4127833345012
# Address,lat,long:- 5 Rosehill Avenue, Toronto 43.6861387 -79.3930993
# Address,lat,long:- 47 Major St, Toronto 43.65899293333333 -79.40320153333333
# Address,lat,long:- Ocean Club, Toronto 40.014123 -74.087212
# Address,lat,long:- 118 Chestnut Crescent, Toronto 43.7175444 -79.2764223
# Address,lat,long:- 3840 Bathurst St, Toronto 43.74002895 -79.43500172221735
# Address,lat,long:- 2212 Lake Shore Blvd W , Toronto 43.6224472 -79.4822192
# Address,lat,long:- 101 Peter St , Toronto 43.6475125 -79.3927771
# Address,lat,long:- 3 Navy Wharf Ct, Toronto 43.640431 -79.3910006
# Address,lat,long:- 20 Bruyeres Mews , Toronto 43.6373046 -79.4004642
# Address,lat,long:- 100 Western Battery Rd , Toronto 43.63964665 -79.41590827083749
# Address,lat,long:- 150 E Liberty St , Toronto 43.6388738 -79.4164324
# Address,lat,long:- 51 E Liberty St , Toronto 43.638639999999995 -79.4121354777391
# Address,lat,long:- 2983 Bloor St W , Toronto 43.6475903 -79.5095265
# Address,lat,long:- 630 Roselawn Avenue, Toronto 43.706265 -79.42269654689878
# Address,lat,long:- 3 Winchfield Pl, Toronto 43.7422494 -79.3623128
# Address,lat,long:- Bloor Walk, Toronto 43.6461749 -79.5154911
# Address,lat,long:- Casa 3, Toronto 43.6695538 -79.38363668817757
# Address,lat,long:- 5128 Dundas St W, Toronto 43.6442408 -79.5330753
# Address,lat,long:- Icon, Toronto 43.6655868 -79.4696778
# Address,lat,long:- 560 Front St W , Toronto 43.6415231 -79.40027808797224
# Address,lat,long:- The Residences, Toronto 43.6597907 -79.3849782
# Address,lat,long:- 60 Lynvalley Crescent, Toronto 43.7503399 -79.3088667
# Address,lat,long:- Cherry Yang, Toronto 43.6370261 -79.34379126722979
# Address,lat,long:- ICON, Toronto 43.6655868 -79.4696778
# Address,lat,long:- Electra Lofts, Toronto 43.6410817 -79.41567079117227
# Address,lat,long:- 75 E Liberty St , Toronto 43.6379927 -79.41476910085089
# Address,lat,long:- 11 Rothwell Rd, Toronto 43.7638648 -79.3133618
# Address,lat,long:- Pantages Tower, Toronto 43.65442965 -79.37916402031503
# Address,lat,long:- Heritage on the Trail, Toronto 43.65082325 -79.37793584643234
# Address,lat,long:- 50 Bruyeres Mews, Toronto 43.63769415 -79.40212594562183
# Address,lat,long:- 46 Dewson St, Toronto 43.65681029204856 -79.42552586896183
# Address,lat,long:- the Wyatt, Toronto 43.6603368 -79.3590563
# Address,lat,long:- 87 Peter St, Toronto 43.6468429 -79.3924735
# Address,lat,long:- Ritz Carlton, Toronto 43.6453061 -79.38708661586364
# Address,lat,long:- 711 Bay St , Toronto 43.6584264 -79.3848284
# Address,lat,long:- 141 Lake Crescent, Toronto 43.60565507142857 -79.49882688095238
# Address,lat,long:- 50 Lynn Williams St, Toronto 43.63947795 -79.4151685945755
# Address,lat,long:- 101 Erskine, Toronto 43.71139445 -79.39533594781491
# Address,lat,long:- 5168 Yonge St, Toronto 43.7614399 -79.4109923
# Address,lat,long:- 2356 Queen St E, Toronto 43.673999875 -79.28162195
# Address,lat,long:- 59 Roseland Dr, Toronto 43.59897467692308 -79.54870012307693
# Address,lat,long:- 58 Orchard View Blvd , Toronto 43.708051 -79.4008154
# Address,lat,long:- 7400 Markham Rd , Toronto 43.7427005 -79.2186311
# Address,lat,long:- 181 Village Green Square , Toronto 43.7792065 -79.2815769643811
# Address,lat,long:- NXT Windermere-By-The-Lake, Toronto 43.635695999999996 -79.4712399021442
# Address,lat,long:- The Massey Tower, Toronto 43.6533905 -79.37925784226252
# Address,lat,long:- 317 Jones Ave , Toronto 43.671313399999995 -79.3363062
# Address,lat,long:- Monde Condominiums, Toronto 43.64599945 -79.36501142545296
# Address,lat,long:- The Wyatt, Toronto 43.6603368 -79.3590563
# Address,lat,long:- 106 Dewey Dr, Toronto 43.75868666211666 -79.30427576337105
# Address,lat,long:- 87-99 Silver Springs Boulevard, Toronto 43.80157671813733 -79.30396568952617
# Address,lat,long:- 75 Silver Springs Boulevard, Toronto 43.80152488670738 -79.30454064521241
# Address,lat,long:- 65 Silver Springs Boulevard, Toronto 43.8013395 -79.30421301531621
# Address,lat,long:- 1450 Sheppard Avenue, West, Toronto 43.7615911 -79.4108588
# Address,lat,long:- Lucy C, Toronto 43.64247425 -79.4834293052433
# Address,lat,long:- 208 Queens Quay West, Toronto 43.6399699 -79.3812666
# Address,lat,long:- 101 Coe Hill Drive, Toronto 43.6417861 -79.47341539115229
# Address,lat,long:- 33 Bay Street, Toronto 43.642563300000006 -79.37720998730094
# Address,lat,long:- 19 Craigton Drive, Toronto 43.727413999999996 -79.30094009946237
# Address,lat,long:- 155 Wellesley Street East, Toronto 43.666368000000006 -79.37539819533711
# Address,lat,long:- 350 The East Mall, Toronto 43.6409264 -79.55810451556849
# Address,lat,long:- 555 The West Mall, Toronto 43.65238875 -79.57035811532279
# Address,lat,long:- 1330 Danforth Road, Toronto 43.7429045 -79.24593597892786
# Address,lat,long:- 1360 Danforth Road, Toronto 43.744939 -79.24538647727273
# Address,lat,long:- 1350 Danforth Road, Toronto 43.744262 -79.24574346666665
# Address,lat,long:- 25 Cougar Court, Toronto 43.7460115 -79.21803961191067
# Address,lat,long:- 135 Tyndall Avenue, Toronto 43.637689550000005 -79.42829857362983
# Address,lat,long:- 201 Sherbourne Street, Toronto 43.65772235 -79.37019495
# Address,lat,long:- 191 Sherbourne Street, Toronto 43.65679355 -79.36986085000001
# Address,lat,long:- 78 Allingham Gardens, Toronto 43.7381128 -79.4391824
# Address,lat,long:- CASA 2, Toronto 43.66947145 -79.38412773928317
# Address,lat,long:- 5508 Yonge St, Toronto 43.77833142222222 -79.41537371111112
# Address,lat,long:- 3986 Ellesmere Rd, Toronto 43.79293566266569 -79.16265677400254
# Address,lat,long:- Key West, Toronto 43.6601662 -79.4696652
# Address,lat,long:- 705 King St W, Toronto 43.6434096 -79.4040401
# Address,lat,long:- 739 Birchmount, Toronto 43.724907 -79.27493282051282
# Address,lat,long:- 120 Bayview Ave, Toronto 43.65382235 -79.35446184972523
# Address,lat,long:- 3575 Bathurst Street, Toronto 43.7318335 -79.43236647364446
# Address,lat,long:- Aqua, Toronto 43.7201967 -79.44787335390625
# Address,lat,long:- Musee, Toronto 43.678931 -79.408114
# Address,lat,long:- 20 Ellis Park Rd, Toronto 43.64652379169852 -79.47144865953236
# Address,lat,long:- 75 E Liberty St, Toronto 43.6379927 -79.41476910085089
# Address,lat,long:- 8 Rosebank Dr , Toronto 43.791899 -79.2373615
# Address,lat,long:- 431 Woburn Ave, Toronto 43.7252408 -79.4170622
# Address,lat,long:- Triomphe, Toronto 43.775784599999994 -79.41324471984112
# Address,lat,long:- 99 Santamonica Blvd, Toronto 43.708188248345216 -79.27543760185063
# Address,lat,long:- 1080 Kingston Rd., Toronto 43.6814035 -79.283185
# Address,lat,long:- 177 Lyndhurst Ave, Toronto 43.68232285882353 -79.41456137058825
# Address,lat,long:- 61 Hummingbird Dr, Toronto 43.828991329295334 -79.23710051944853
# Address,lat,long:- 16 YONGE ST, Toronto 43.6433817 -79.3766356
# Address,lat,long:- Redpath Tower - Yonge and Eglinton, Toronto 43.7099627 -79.3936224
# Address,lat,long:- 35 Trudelle St, Toronto 43.7388435 -79.2436494640625
# Address,lat,long:- 102 Bloor St W , Toronto 43.6697693 -79.3918497
# Address,lat,long:- 15 Hilda Ave, Toronto 43.785321825000004 -79.4237895
# Address,lat,long:- 1398 Bloor St W , Toronto 43.657508166666666 -79.4473965
# Address,lat,long:- Smart House, Toronto 43.6465462 -79.3880892
# Address,lat,long:- 35 Bales Avenue, Toronto 43.7590936 -79.4090345
# Address,lat,long:- Grenadier Landing, Toronto 43.6296832 -79.47536629539889
# Address,lat,long:- 17 Powerhouse St, Toronto 43.6698373 -79.4484517
# Address,lat,long:- Bohemian Embassy, Toronto 43.641876249999996 -79.42546963611979
# Address,lat,long:- 18 Ionview Rd, Toronto 43.73281805 -79.27196805
# Address,lat,long:- 208 McCaul St , Toronto 43.65721030434782 -79.39281252173913
# Address,lat,long:- 46 Cavell Ave, Toronto 43.617712 -79.4934894800532
# Address,lat,long:- Lawrence Ave. East/Kingston Road, Toronto 43.7678815 -79.18961
# Address,lat,long:- 59 E Liberty St, Toronto 43.63838385 -79.41357599999999
# Address,lat,long:- 18 Harbour St , Toronto 43.6430741 -79.3767967
# Address,lat,long:- 39 Sherbourne St , Toronto 43.6582303 -79.3709605
# Address,lat,long:- 30 Church St , Toronto 43.6490739 -79.3741943
# Address,lat,long:- Elm Place, Toronto 43.7834405 -79.18447064666667
# Address,lat,long:- 105 The Queensway, Toronto 43.635695999999996 -79.4712399021442
# Address,lat,long:- 130 Raglan Avenue, Toronto 43.6847615 -79.4202488
# Address,lat,long:- 488 University Ave , Toronto 43.6551808 -79.3888064
# Address,lat,long:- The Garrison, Toronto 43.6491534 -79.42233608865013
# Address,lat,long:- 200 Clinton St, Toronto 43.6593711 -79.41567570000001
# Address,lat,long:- 27 Hammersmith Ave , Toronto 43.671935754744524 -79.29569043722627
# Address,lat,long:- 6 Bushwood Ct, Toronto 43.805271648413594 -79.20241808345435
# Address,lat,long:- 1185 The Queensway, Toronto 43.6369532 -79.4714243
# Address,lat,long:- 376 Hwy 7 , Toronto 43.7678813 -79.3259759
# Address,lat,long:- 115 George Appleton Way, Toronto 43.725954616297024 -79.47982799364931
# Address,lat,long:- 2504 Lake Shore Blvd W , Toronto 43.6121228 -79.4901864
# Address,lat,long:- 333 Rimilton Ave , Toronto 43.6071117 -79.5311939
# Address,lat,long:- The Residences of College Park, Toronto 43.6597907 -79.3849782
# Address,lat,long:- 316 Jedburgh Rd, Toronto 43.7329415 -79.4084446
# Address,lat,long:- 30 Denton Ave, Toronto 43.6939435 -79.28771220388349
# Address,lat,long:- 2575 Danforth Avenue, Toronto 43.688277 -79.3003142
# Address,lat,long:- 763 Woodbine Ave, Toronto 43.680649243243245 -79.31049267027026
# Address,lat,long:- 15 Brookbanks Dr, Toronto 43.751718999999994 -79.3319606608527
# Address,lat,long:- 12 Rockford Rd, Toronto 43.7860251 -79.44770250634741
# Address,lat,long:- One Park Place, Toronto 43.6602853 -79.360709
# Address,lat,long:- 25 Viking Ln , Toronto 43.63853760000001 -79.53564985
# Address,lat,long:- 2701 Eglinton Avenue West, Toronto 43.6891761 -79.4787776
# Address,lat,long:- Broadview Lofts, Toronto 43.657417 -79.3501324912377
# Address,lat,long:- 465 Woodfield Rd, Toronto 43.6762182 -79.3256444
# Address,lat,long:- 545 Sherbourne St, Toronto 43.6684676 -79.3749655
# Address,lat,long:- 125 Kingsview Blvd, Toronto 43.69663608386093 -79.56261539860085
# Address,lat,long:- 214 Brandon Ave, Toronto 43.6694175 -79.4442896
# Address,lat,long:- The Panache, Toronto 43.6707477 -79.3860524
# Address,lat,long:- 77 Allingham Gardens, Toronto 43.7378535 -79.4396903
# Address,lat,long:- 4252 Lawrence Ave E, Toronto 43.769548 -79.18170432
# Address,lat,long:- 66 Isabella Street, Toronto 43.66835 -79.382588
# Address,lat,long:- 460 Adelaide St E, Toronto 43.652675 -79.366632
# Address,lat,long:- E Condos, Toronto 43.707497000000004 -79.39806304671656
# Address,lat,long:- The Britt, Toronto 43.664794 -79.38695929584918
# Address,lat,long:- 50 Wellesley St E, Toronto 43.6655754 -79.38199660000001
# Address,lat,long:- Fashion house, Toronto 43.7209627 -79.6000148
# Address,lat,long:- 5390 Steeles Ave W, Toronto 43.7911357 -79.4516981
# Address,lat,long:- 7171 Yonge St, Toronto 43.7808484 -79.415698
# Address,lat,long:- Minto Plaza, Toronto 43.668044 -79.39074426995322
# Address,lat,long:- 257 Roxton Rd, Toronto 43.6526529 -79.4207038
# Address,lat,long:- 56 Forest Manor Rd , Toronto 43.7723652 -79.3445747
# Address,lat,long:- 739 Midland Ave, Toronto 43.72954211538462 -79.25579334615385
# Address,lat,long:- 1 Mallory Gardens, Toronto 43.691002350000005 -79.39595619868123
# Address,lat,long:- Bretton Place, Toronto 43.6857897 -79.39116600064143
# Address,lat,long:- Garden Court, Toronto 43.653963 -79.387207
# Address,lat,long:- Harbour Plaza, Toronto 43.7772713 -79.1409599
# Address,lat,long:- 21 Carisbrooke Square, Toronto 43.816872995360704 -79.21378799423208
# Address,lat,long:- 27 Bathurst St , Toronto 43.641411 -79.401552
# Address,lat,long:- Livlofts, Toronto 43.73276 -79.34564225
# Address,lat,long:- 31 Meadow Ave, Toronto 43.68188851666666 -79.28230205
# Address,lat,long:- 47 Lower River Street, Toronto 43.656340150000005 -79.35511458478955
# Address,lat,long:- 115 Maitland St, Toronto 43.664901 -79.378876
# Address,lat,long:- 98 Anthia Dr, Toronto 43.76241281666667 -79.57257070833333
# Address,lat,long:- 85 E Liberty St, Toronto 43.6378584 -79.41547648236936
# Address,lat,long:- 33 Empress Ave, Toronto 43.7693604 -79.4122631
# Address,lat,long:- 68 Merton St, Toronto 43.696768270270276 -79.39356216216217
# Address,lat,long:- 14 Buller Ave, Toronto 43.66692871428571 -79.3037844
# Address,lat,long:- 32 Camden St, Toronto 43.6472278 -79.397088
# Address,lat,long:- 74 Curlew Dr., Toronto 43.743464 -79.31630321234118
# Address,lat,long:- 35 Canyon Ave , Toronto 43.757983100000004 -79.43692176984774
# Address,lat,long:- 2200 Lake Shore Blvd W, Toronto 43.6229142 -79.4816461
# Address,lat,long:- 175 Marion St, Toronto 43.6406128 -79.4482923
# Address,lat,long:- 150 Redpath, Toronto 43.7087675 -79.39365285
# Address,lat,long:- 415 Palmerston Blvd, Toronto 43.66009935555556 -79.4116372
# Address,lat,long:- 3311 Kingston Rd, Toronto 43.7001844 -79.2549492
# Address,lat,long:- 88 Corporate Dr, Toronto 43.7809725 -79.2498068
# Address,lat,long:- 36 Lee Centre Dr, Toronto 43.7816245 -79.24737616826923
# Address,lat,long:- Dundas Square Gardens, Toronto 43.6561162 -79.38016329843242
# Address,lat,long:- 88 Scott, Toronto 43.64848615 -79.37651147905876
# Address,lat,long:- 260 Queens Quay W , Toronto 43.6391699 -79.3857361
# Address,lat,long:- Eau du Soleil, Toronto 43.623461199999994 -79.47952343575182
# Address,lat,long:- 1101 Bay Street, Toronto 43.667760799999996 -79.38831379798847
# Address,lat,long:- Forest Lane Apartments, Toronto 43.7812811 -79.45008192438564
# Address,lat,long:- Goldengate Apartments, Toronto 43.725466499999996 -79.30510754570157
# Address,lat,long:- The Eglinton, Toronto 43.7061229 -79.39853
# Address,lat,long:- 65 Southport St , Toronto 43.63996865 -79.47358605938773
# Address,lat,long:- L Tower, Toronto 43.64615715 -79.3762915645473
# Address,lat,long:- 216 Heath St W , Toronto 43.6868559 -79.4123255
# Address,lat,long:- 5 Oakburn Crescent , Toronto 43.757999549999994 -79.40540165282695
# Address,lat,long:- Concorde Place, Toronto 43.7295537 -79.3283639
# Address,lat,long:- 49 Jardine Pl, Toronto 43.68778098053553 -79.55738200734984
# Address,lat,long:- 872 Sheppard Ave W, Toronto 43.75231488235294 -79.45432882941176
# Address,lat,long:- 809 Duplex Ave , Toronto 43.718186975 -79.40349275
# Address,lat,long:- 262 Birmingham St, Toronto 43.60109131666667 -79.51682555000001
# Address,lat,long:- 100 Leeward Glenway , Toronto 43.711583000000005 -79.32933373423973
# Address,lat,long:- 9 Cannon Rd , Toronto 43.6339785 -79.48608917424242
# Address,lat,long:- 3 Lois Ave , Toronto 43.7104849 -79.4463383
# Address,lat,long:- The Ossington, Toronto 43.6623836 -79.4260422
# Address,lat,long:- 6151 Bathurst, Toronto 43.7880742 -79.44597268697916
# Address,lat,long:- 765 Steeles, Toronto 43.8161778 -79.3145378
# Address,lat,long:- Dufferin Crossing, Toronto 43.6602019 -79.4357191
# Address,lat,long:- 425 Avenue Road, Toronto 43.6833793 -79.39972652871757
# Address,lat,long:- 22 Farmcote Rd, Toronto 43.7463885 -79.3437811
# Address,lat,long:- Merchandise Building, Toronto 43.65770495 -79.37647652580884
# Address,lat,long:- 951 Bay St, Toronto 43.66451 -79.387105
# Address,lat,long:- Queens Harbour, Toronto 43.6367319 -79.39786968529413
# Address,lat,long:- 29 Huron St , Toronto 43.651449 -79.395262
# Address,lat,long:- The Summit, Toronto 43.673987600000004 -79.403293744205
# Address,lat,long:- 3560 St Clair Ave E , Toronto 43.7167037 -79.2611166
# Address,lat,long:- 88 Boultbee Ave, Toronto 43.67356291932788 -79.3354455636289
# Address,lat,long:- The Riviera Condos, Toronto 43.639718599999995 -79.38359910049877
# Address,lat,long:- 1 Bedford Rd , Toronto 43.66866 -79.397431
# Address,lat,long:- 627 Dufferin St , Toronto 43.6498372 -79.43133044999999
# Address,lat,long:- Gramercy Park, Toronto 43.8227022 -79.2126151
# Address,lat,long:- 37 Sorauren Ave , Toronto 43.641309 -79.4413124
# Address,lat,long:- 35 Balmuto, Toronto 43.6694927 -79.38741454732649
# Address,lat,long:- 300 Front St W, Toronto 43.6439847 -79.3893423
# Address,lat,long:- 28 Wellesley St E, Toronto 43.6653202 -79.3831538
# Address,lat,long:- 62 Haimer Avenue, Toronto 43.7550567 -79.5920704
# Address,lat,long:- 21 Widmer St , Toronto 43.6484785 -79.3918992
# Address,lat,long:- Emerald City, Toronto 43.771861349999995 -79.3453210923482
# Address,lat,long:- 45 Forty Second St., Toronto 43.5882491 -79.54274895
# Address,lat,long:- Portland Park Village, Toronto 43.64148855 -79.3995011761998
# Address,lat,long:- 58 Marine Parade Dr, Toronto 43.6271571 -79.476928
# Address,lat,long:- KIP, Toronto 43.633903700000005 -79.54085560886429
# Address,lat,long:- Tableau, Toronto 43.648401199999995 -79.39272978071831
# Address,lat,long:- 97 Sufi Crescent, Toronto 43.72286816195848 -79.30923344673876
# Address,lat,long:- 3580 Lake Shore Blvd W , Toronto 43.5944641 -79.5341213
# Address,lat,long:- 115 Hillcrest Ave , Toronto 43.76865025425261 -79.40662459197753
# Address,lat,long:- HOEM on Jarvis, Toronto 43.656206 -79.37458665819894
# Address,lat,long:- 3091 Dufferin St, Toronto 43.71477477142857 -79.45470527142857
# Address,lat,long:- 55 Crockamhill Dr, Toronto 43.79797356183991 -79.28164239645638
# Address,lat,long:- 75 The Donway W, Toronto 43.73276 -79.34564225
# Address,lat,long:- 3018 Yonge St , Toronto 43.724281000000005 -79.40248448150777
# Address,lat,long:- The Brant Park, Toronto 43.6465302 -79.39764436661751
# Address,lat,long:- 5418 Yonge St , Toronto 43.7756962 -79.4147639
# Address,lat,long:- 504 Roxton Rd , Toronto 43.66084925 -79.42400704166667
# Address,lat,long:- 77 Wellesley Street East, Toronto 43.66566 -79.3804862
# Address,lat,long:- 15 Greenview Ave, Toronto 43.779783769999995 -79.41853152
# Address,lat,long:- 23 Sheppard Ave E, Toronto 43.76083555 -79.40900564751334
# Address,lat,long:- 2210 Dundas St W , Toronto 43.6538325 -79.4514735
# Address,lat,long:- 77 Harbour Square , Toronto 43.6398894 -79.3795913
# Address,lat,long:- 10 Old York Mills Rd, Toronto 43.743434 -79.4062745
# Address,lat,long:- 375 Apache Trail , Toronto 43.80000488364451 -79.33976305144795
# Address,lat,long:- 11 Birchmount Rd, Toronto 43.7633769 -79.2912587
# Address,lat,long:- 230 Oak St, Toronto 43.662922 -79.358133
# Address,lat,long:- 310-312 Lonsdale Road, Toronto 43.68923409230769 -79.41061117692307
# Address,lat,long:- 580 The East Mall, Toronto 43.653667299999995 -79.56432998422784
# Address,lat,long:- 778 Broadview Avenue, Toronto 43.6764286 -79.359242
# Address,lat,long:- Cinema Tower, Toronto 43.646728100000004 -79.39051164454267
# Address,lat,long:- Ice Condos, Toronto 43.6417865 -79.38175712860597
# Address,lat,long:- 88 Harbour St , Toronto 43.64188 -79.37904109039007
# Address,lat,long:- Bisha Hotel, Toronto 43.6453007 -79.39244960966198
# Address,lat,long:- 18 Valley Woods Rd, Toronto 43.7524945 -79.33284085416668
# Address,lat,long:- 90 Sumach St , Toronto 43.6554344 -79.3741571
# Address,lat,long:- 455 Dovercourt Rd , Toronto 43.6541784902439 -79.42642634146341
# Address,lat,long:- 295 Adelaide St W , Toronto 43.647051 -79.3941058
# Address,lat,long:- 197 Yonge St , Toronto 43.65325152 -79.37948092
# Address,lat,long:- 110 Marine Parade Dr , Toronto 43.6251412 -79.4776672
# Address,lat,long:- 1080 Bay St , Toronto 43.66712725 -79.38849775
# Address,lat,long:- 311 Bay St , Toronto 43.6584264 -79.3848284
# Address,lat,long:- 63 St Mary St , Toronto 43.667288 -79.388738
# Address,lat,long:- 180 University Ave , Toronto 43.6489079 -79.3860758
# Address,lat,long:- 42 Glen Elm Avenue, Toronto 43.6920482 -79.39300881062545
# Address,lat,long:- 3533 Derry Rd E, Toronto 43.718256 -79.6205478
# Address,lat,long:- Skymark, Toronto 43.7945876 -79.35586330971846
# Address,lat,long:- 78 James St, Toronto 43.590159411157785 -79.54142386465705
# Address,lat,long:- 667 Queen St E, Toronto 43.6578259 -79.3545087
# Address,lat,long:- 501 Adelaide St W, Toronto 43.64549616666667 -79.40128058333333
# Address,lat,long:- 1836 Queen St E, Toronto 43.668329 -79.3082635
# Address,lat,long:- Liberty Place, Toronto 43.6388044 -79.41626786668814
# Address,lat,long:- 602 Birchmount Rd , Toronto 43.71548798181818 -79.2719211
# Address,lat,long:- 189 Lippincott St, Toronto 43.6599448 -79.4076749
# Address,lat,long:- Studio 2, Toronto 33.5784975 -117.7292186
# Address,lat,long:- 2200 Eglinton Ave W, Toronto 43.69330208 -79.46158312
# Address,lat,long:- 290 Adelaide St W, Toronto 43.647876 -79.390598
# Address,lat,long:- Pantages Hotel, Toronto 43.65442965 -79.37916402031503
# Address,lat,long:- MINTO, Toronto 43.668044 -79.39074426995322
# Address,lat,long:- 540 Birchmount Road, Toronto 43.710786 -79.27027952860834
# Address,lat,long:- Massey, Toronto 43.653966600000004 -79.37898145514912
# Address,lat,long:- 106 Holcolm Rd, Toronto 43.77560608571429 -79.42332208571428
# Address,lat,long:- 8 Telegram Mews, Toronto 43.640541 -79.394839
# Address,lat,long:- Linwood Apartments, Toronto 43.671752049999995 -79.34843938303725
# Address,lat,long:- Holly Tower - Yonge and Eglinton, Toronto 43.7060148 -79.3963729
# Address,lat,long:- 88 Charles St E, Toronto 43.669920399999995 -79.38150239155573
# Address,lat,long:- 230 S Kingsway, Toronto 43.659129182684445 -79.51911639148699
# Address,lat,long:- Bisha, Toronto 43.6453007 -79.39244960966198
# Address,lat,long:- Palace Gate, Toronto 43.78579255 -79.3911871787428
# Address,lat,long:- 1 Valhalla Inn Rd, Toronto 43.6408605 -79.5601143
# Address,lat,long:- 1 De Boers Dr , Toronto 43.751253500000004 -79.46403676308978
# Address,lat,long:- 5793 Yonge St , Toronto 43.78441265 -79.41620056943592
# Address,lat,long:- 74 Twenty Ninth St, Toronto 43.598449933333335 -79.5299606
# Address,lat,long:- 352 Front St W , Toronto 43.64356915 -79.3921850009371
# Address,lat,long:- 319 Carlaw Ave , Toronto 43.6642278 -79.3411709
# Address,lat,long:- 27 Bathurst St, Toronto 43.641411 -79.401552
# Address,lat,long:- 56 Hambly Ave , Toronto 43.673189825 -79.298036946875
# Address,lat,long:- Casa condominiums, Toronto 43.66697595 -79.38904775006048
# Address,lat,long:- 447 Longmore St , Toronto 43.7800184 -79.4034483
# Address,lat,long:- 75 Cambridge Ave , Toronto 43.677975 -79.3597108
# Address,lat,long:- Sq on the park, Toronto 43.653963 -79.387207
# Address,lat,long:- 540 Russell Hill Rd , Toronto 43.7029193 -79.41555
# Address,lat,long:- Sixty Colborne, Toronto 43.64948705 -79.37443426317324
# Address,lat,long:- 1169 Queen St W, Toronto 43.6426466 -79.425873
# Address,lat,long:- 60 Brian Harrison Way , Toronto 43.7738375 -79.2575629
# Address,lat,long:- 208 Lake Promenade, Toronto 43.58925101520327 -79.52936457063244
# Address,lat,long:- Apex Cityplace, Toronto -26.2113123 28.3396679
# Address,lat,long:- 591 Sheppard Ave E, Toronto 43.7674729 -79.384
# Address,lat,long:- Monde, Toronto 43.66716 -79.3901783
# Address,lat,long:- Riverview Apartments, Toronto 43.6489011 -79.4942306934516
# Address,lat,long:- 35 Walmer Road, Toronto 43.669119 -79.40560729744459
# Address,lat,long:- 3888 Bathurst Street, Toronto 43.7428429 -79.43583605008567
# Address,lat,long:- 4900 Bathurst Street, Toronto 43.77235315 -79.44306101330504
# Address,lat,long:- 4981 Bathurst Street, Toronto 43.7762217 -79.44313270288401
# Address,lat,long:- 4222 Bathurst Street, Toronto 43.749562 -79.43765745056356
# Address,lat,long:- 1650 Sheppard Avenue East, Toronto 43.77510100000001 -79.34905702034744
# Address,lat,long:- 4979 Bathurst Street, Toronto 43.77521205 -79.44287412178198
# Address,lat,long:- 4190 Bathurst Street, Toronto 43.74853335 -79.43725229185685
# Address,lat,long:- 3894 Bathurst Street, Toronto 43.7436959 -79.43611784557838
# Address,lat,long:- 1660 Bathurst Street, Toronto 43.694932 -79.42362732376237
# Address,lat,long:- 311 Richmond St E , Toronto 43.653268 -79.369181
# Address,lat,long:- 2 Regal Road, Toronto 43.6753379 -79.4331458
# Address,lat,long:- 700 King St W , Toronto 43.6441579 -79.4030516
# Address,lat,long:- Quad Lofts II, Toronto 43.64591115 -79.39657150688737
# Address,lat,long:- 2397 Finch Avenue West, Toronto 43.7512788 -79.5443689
# Address,lat,long:- 286 Finch Avenue West, Toronto 43.7747062 -79.44006918998491
# Address,lat,long:- 1038 Dundas St E, Toronto 43.66381015 -79.3457243
# Address,lat,long:- 269 Soudan Ave , Toronto 43.70590228571429 -79.38967957142857
# Address,lat,long:- Wyatt, Toronto 43.6603368 -79.3590563
# Address,lat,long:- Opus, Toronto 43.654834 -79.37935930256663
# Address,lat,long:- 5 St Joseph St, Toronto 43.66585 -79.385535
# Address,lat,long:- 117 St Johns Rd, Toronto 43.664573 -79.477417
# Address,lat,long:- 7 Lorraine Dr, Toronto 43.7787489 -79.4171422
# Address,lat,long:- 18 Harrison Garden Blvd, Toronto 43.7572356 -79.4093347731574
# Address,lat,long:- 23 Lorraine Dr, Toronto 43.77805435 -79.4166885363577
# Address,lat,long:- 33 Singer Crt, Toronto 43.7695026 -79.3708357
# Address,lat,long:- 80 Harrison Garden Blvd, Toronto 43.756331 -79.40578116709267
# Address,lat,long:- 100 Antibes Dr, Toronto 43.78044915 -79.44700529986994
# Address,lat,long:- 503 Beecroft Rd, Toronto 43.77815805 -79.41757221231303
# Address,lat,long:- 1101 Steeles Ave W, Toronto 43.79046785 -79.44815928645951
# Address,lat,long:- 5791 Yonge St, Toronto 43.78402605 -79.41610670008043
# Address,lat,long:- 1862 Bathurst Street, Toronto 43.697573500000004 -79.42451841494844
# Address,lat,long:- 1531-1539 Bathurst Street, Toronto 43.685555 -79.419153
# Address,lat,long:- 14-30 Tichester Road, Toronto 43.6855019 -79.4187307
# Address,lat,long:- 70 Spadina Road, Toronto 43.6705856 -79.4057813
# Address,lat,long:- 66 Spadina Road, Toronto 43.670030100000005 -79.40546170239293
# Address,lat,long:- 50 Spadina Road, Toronto 43.669241400000004 -79.40512639652184
# Address,lat,long:- 100 Hayden St, Toronto 43.6703272 -79.3819875
# Address,lat,long:- 52 Inglewood Dr, Toronto 43.690871349999995 -79.38797305
# Address,lat,long:- World on Yonge, Toronto 43.70794 -79.391779
# Address,lat,long:- Ola, Toronto 43.6982301 -79.5027738
# Address,lat,long:- 7768 Kennedy Rd , Toronto 43.7619973 -79.2797197
# Address,lat,long:- Murano, Toronto 43.66188855 -79.385719
# Address,lat,long:- 59 E Liberty St , Toronto 43.63838385 -79.41357599999999
# Address,lat,long:- 25 Mayland Ave, Toronto 43.637230699999996 -79.5654852875
# Address,lat,long:- 600 Fleet St, Toronto 43.6369513 -79.4000826
# Address,lat,long:- 68 Hamilton St , Toronto 43.66062285 -79.3516782
# Address,lat,long:- 132 Painted Post Dr, Toronto 43.76498984 -79.23038614000001
# Address,lat,long:- 28 Douro St, Toronto 43.6407534 -79.4129437
# Address,lat,long:- 668 Queen St W , Toronto 43.6466839 -79.4071318
# Address,lat,long:- Lillian Park, Toronto 43.797584349999994 -79.40864533677438
# Address,lat,long:- 480 Queens Quay W, Toronto 43.6375564 -79.3937647
# Address,lat,long:- Ten York, Toronto 43.64119975 -79.38117383543945
# Address,lat,long:- Park Manor, Toronto -34.8899421 -56.0790982
# Address,lat,long:- 68 Hillside, Toronto 43.6900604 -79.3567028
# Address,lat,long:- 8, Mercer, Toronto 43.6459848 -79.3897372
# Address,lat,long:- 2067 Lake Shore Blvd W, Toronto 43.630558949999994 -79.47561915158967
# Address,lat,long:- Glendale, Toronto 43.74757635 -79.61223310695333
# Address,lat,long:- 33 Mill St , Toronto 43.650324499999996 -79.36063136490475
# Address,lat,long:- 2327 Gerrard St E, Toronto 43.685183775 -79.293776075
# Address,lat,long:- 120 Harrison Garden Blvd, Toronto 43.75803165 -79.40318685164361
# Address,lat,long:- 36 Hiawatha Rd, Toronto 43.669193210526316 -79.32184755438597
# Address,lat,long:- 361 Front St W , Toronto 43.6431912 -79.3913725
# Address,lat,long:- The Sheldrake, Toronto 43.7151557 -79.3990522
# Address,lat,long:- 5 Concorde Pl, Toronto 43.729935499999996 -79.3273039375
# Address,lat,long:- 2800 Condominiums, Toronto 43.66697595 -79.38904775006048
# Address,lat,long:- 1116 Dundas St W, Toronto 43.6495554 -79.4202083
# Address,lat,long:- Lumiere, Toronto 43.6601038 -79.3860526
# Address,lat,long:- 10 Baybrook Crescent , Toronto 43.766529111455036 -79.24478882723534
# Address,lat,long:- Yorkville Plaza, Toronto 43.6719734 -79.38965070716851
# Address,lat,long:- The Modern, Toronto 43.6531958 -79.3687757
# Address,lat,long:- 66 Portland, Toronto 43.6205595 -79.492931
# Address,lat,long:- The bond, Toronto 43.6557497 -79.3782498
# Address,lat,long:- 300 Bleecker St, Toronto 43.668366984496124 -79.37435313953488
# Address,lat,long:- 29 Queens Quay E, Toronto 43.6413123 -79.3728733
# Address,lat,long:- 550 Queens Quay W, Toronto 43.6369486 -79.3965328
# Address,lat,long:- 45 Soho Square, Toronto 43.6509821 -79.3934982
# Address,lat,long:- 100 Parrotta Dr , Toronto 43.7340092 -79.53617604
# Address,lat,long:- 78 Tecumseth St , Toronto 43.643496999999996 -79.40544525
# Address,lat,long:- 100 Lake Crescent, Toronto 43.60642172727273 -79.49692211818181
# Address,lat,long:- 115 McMahon Dr , Toronto 43.766804914483 -79.37269863540978
# Address,lat,long:- Charlie, Toronto 43.6459872 -79.39397827889105
# Address,lat,long:- 4300 Lawrence Ave E, Toronto 43.7705428 -79.1773638
# Address,lat,long:- 8 Eglinton Ave E , Toronto 43.706852 -79.398212
# Address,lat,long:- River City 3, Toronto 43.65694795 -79.35553385106853
# Address,lat,long:- 88 Sheppard Ave E, Toronto 43.789539 -79.2588822
# Address,lat,long:- 6 Willingdon Ave, Toronto 43.7032343239639 -79.26153875389697
# Address,lat,long:- Broadway, Toronto 43.70925595 -79.39663645148869
# Address,lat,long:- 176 Lisgar St, Toronto 43.64527357368421 -79.42453341842105
# Address,lat,long:- 703 Grandview Way, Toronto 43.7755349 -79.4112564
# Address,lat,long:- 3 Michael Power Pl, Toronto 43.643963 -79.529496
# Address,lat,long:- 49 Ardagh St, Toronto 43.6569155 -79.48087157941177
# Address,lat,long:- 53 Roskell Crescent, Toronto 43.75611575218497 -79.49571979401168
# Address,lat,long:- 20 Joe Shuster Way, Toronto 43.6401487 -79.4238567
# Address,lat,long:- 2 Manaham Rd, Toronto 43.7686033 -79.1631779
# Address,lat,long:- 25 Capreol Ct, Toronto 43.6401072 -79.3956851
# Address,lat,long:- 988 Kennedy Rd, Toronto 43.74494462 -79.27339167333334
# Address,lat,long:- 15 Viking Ln, Toronto 43.6390834 -79.53517360000001
# Address,lat,long:- 208 McCaul St, Toronto 43.65721030434782 -79.39281252173913
# Address,lat,long:- 215 Queen St W, Toronto 43.6504307 -79.3879849
# Address,lat,long:- 25 Telegram Mews, Toronto 43.64103195 -79.39440224659694
# Address,lat,long:- Balliol Park, Toronto 43.698129800000004 -79.39436050538617
# Address,lat,long:- The Torontonian, Toronto 43.7060398 -79.39420611343033
# Address,lat,long:- FLY, Toronto 43.6502332 -79.3910076
# Address,lat,long:- 16 Annapearl Ct, Toronto 43.777394062257876 -79.40689230659723
# Address,lat,long:- 137 Earlscourt Ave, Toronto 43.68080442857143 -79.4488575857143
# Address,lat,long:- 107 Preston St , Toronto 43.705891072 -79.25990458400001
# Address,lat,long:- 151 Village Green Square , Toronto 43.778555 -79.28128749999999
# Address,lat,long:- 45 Strathavon Dr, Toronto 43.749337161883915 -79.58601468286739
# Address,lat,long:- 22 E Haven Dr, Toronto 43.70416697373026 -79.25157009061925
# Address,lat,long:- 916 Woodbine Ave, Toronto 43.684472968706274 -79.31246393089265
# Address,lat,long:- 19 Pony Farm Drive, Toronto 43.6763419 -79.5567253
# Address,lat,long:- 75 St Nicholas St , Toronto 43.667731 -79.386616
# Address,lat,long:- 16 Bonnycastle St , Toronto 43.645939285714284 -79.36442842857143
# Address,lat,long:- Neptune, Toronto 39.7375946 -89.6550211
# Address,lat,long:- 7 Foxwarren Dr, Toronto 43.770895964309666 -79.3880244438897
# Address,lat,long:- Windermere By The Lake, Toronto 43.635695999999996 -79.4712399021442
# Address,lat,long:- 8 The Esplanade , Toronto 43.64615715 -79.3762915645473
# Address,lat,long:- 18 Yonge St , Toronto 43.6442904 -79.3762474
# Address,lat,long:- 40 Gerrard St E, Toronto 43.6598344 -79.38035645640073
# Address,lat,long:- 181 Dundas St E , Toronto 43.657046785714286 -79.37417142857143
# Address,lat,long:- 89 McGill St , Toronto 43.6606332 -79.3789949
# Address,lat,long:- 7 Grenville St , Toronto 43.661925454545454 -79.38391927272727
# Address,lat,long:- 45 Charles St E , Toronto 43.66878375 -79.38392758840939
# Address,lat,long:- Memphis, Toronto 43.6746538 -79.3890069
# Address,lat,long:- 3 Sevenoaks Ave, Toronto 43.639799 -79.50996176851851
# Address,lat,long:- 519 Runnymede Rd , Toronto 43.6606504 -79.4800065
# Address,lat,long:- 219 Fort York Blvd, Toronto 43.6367509 -79.4055001
# Address,lat,long:- 544 Brock Ave, Toronto 43.657160810551524 -79.43862157720802
# Address,lat,long:- 18 Yonge St, Toronto 43.6442904 -79.3762474
# Address,lat,long:- Wellington on the Park, Toronto 43.6487685 -79.37557592150924
# Address,lat,long:- 4 Treewood, Toronto 43.7542654 -79.2634941
# Address,lat,long:- 45 Greenbrae, Toronto 43.759319500000004 -79.23118041540404
# Address,lat,long:- 39 Bannatyne Dr, Toronto 43.7619211 -79.372431
# Address,lat,long:- 1089 Gerrard St E, Toronto 43.66939046428571 -79.33431967142857
# Address,lat,long:- 2 Hedge End Rd, Toronto 43.807834 -79.1740679
# Address,lat,long:- Cranbrooke Village, Toronto 43.7236068 -79.4297746
# Address,lat,long:- 475 The West Mall, Toronto 43.647661 -79.5665457047331
# Address,lat,long:- observatory, Toronto 43.7739327 -79.50731119919011
# Address,lat,long:- Embassy Apartments, Toronto 43.6709228 -79.3865566
# Address,lat,long:- 170 Bayview Ave, Toronto 43.65548475 -79.35409368987114
# Address,lat,long:- 1165 Avenue Rd , Toronto 43.711089 -79.4112533
# Address,lat,long:- Art Condos, Toronto 43.70392035 -79.39720819284182
# Address,lat,long:- 52 Inglewood, Toronto 43.690871349999995 -79.38797305
# Address,lat,long:- 42 Connaught Ave, Toronto 43.78899026504369 -79.4199220116515
# Address,lat,long:- 45 Jeavons Ave, Toronto 43.7058286 -79.2663762
# Address,lat,long:- 13 Artisan Pl, Toronto 43.79709616666667 -79.35913396666666
# Address,lat,long:- 2 Sevenoaks Ave, Toronto 43.639915 -79.51057038557994
# Address,lat,long:- 182 S Kingsway, Toronto 43.642551 -79.48105298268399
# Address,lat,long:- 19 Grand Trunk Crescent , Toronto 43.6416809 -79.3830414
# Address,lat,long:- 21 Replin Rd , Toronto 43.71752344 -79.4426232
# Address,lat,long:- 2095 Lake Shore Blvd W , Toronto 43.629333849999995 -79.47736496403608
# Address,lat,long:- 1910 Lake Shore Blvd W , Toronto 43.636167167745306 -79.46617283050362
# Address,lat,long:- The Bridge, Toronto 43.653963 -79.387207
# Address,lat,long:- 230 Queens Quay W, Toronto 43.63957785 -79.38413143956137
# Address,lat,long:- Parkside Square, Toronto 43.7745956 -79.33311995480861
# Address,lat,long:- 38 Joe Shuster Way , Toronto 43.6404401 -79.42457159222741
# Address,lat,long:- 299 Mill Rd, Toronto 43.63842115 -79.58208689712573
# Address,lat,long:- 42 Amelia St, Toronto 43.667668 -79.36771826
# Address,lat,long:- Aura, Toronto 43.6594044 -79.38281993391472
# Address,lat,long:- MAPLE LEAF SQUARE, Toronto 43.6424777 -79.38048359601797
# Address,lat,long:- 117 McMahon Dr, Toronto 43.766849871724496 -79.37193745311465
# Address,lat,long:- 1341 Dundas St W, Toronto 43.649379415 -79.42710997
# Address,lat,long:- 3865 Lake Shore Blvd W, Toronto 43.5899635 -79.5450666
# Address,lat,long:- 197 Yonge St, Toronto 43.65325152 -79.37948092
# Address,lat,long:- Bayview Square, Toronto 43.78773015 -79.3916901
# Address,lat,long:- 2 Anndale Drive, Toronto 43.76051805 -79.4102189417774
# Address,lat,long:- 5 Sheppard Ave E, Toronto 43.7612636 -79.4102202
# Address,lat,long:- 9 Bogert Ave, Toronto 43.7604569 -79.4113256
# Address,lat,long:- 28 Hollywood Ave, Toronto 43.766707800000006 -79.41032094058497
# Address,lat,long:- 35 Bales Ave, Toronto 43.7590936 -79.4090345
# Address,lat,long:- 100 Upper Madison Ave, Toronto 43.7642145 -79.41272309375
# Address,lat,long:- 5180 Yonge St, Toronto 43.77022549047619 -79.4133065095238
# Address,lat,long:- 201 Sherbourne St , Toronto 43.65772235 -79.37019495
# Address,lat,long:- Eau Du Soleil, Toronto 43.623461199999994 -79.47952343575182
# Address,lat,long:- 903 Bathurst St , Toronto 43.66877951111111 -79.41245125555555
# Address,lat,long:- 763 Bay St , Toronto 43.6599901 -79.3852164
# Address,lat,long:- 218 Queen St E , Toronto 43.65464 -79.36932025
# Address,lat,long:- 159 Gerrard St E , Toronto 43.66072918181818 -79.374067
# Address,lat,long:- Parkside Student Residence, Toronto 43.6621242 -79.37703454278912
# Address,lat,long:- 33 Rose Ave, Toronto 43.666722 -79.370305
# Address,lat,long:- 2 Glenhaven Street, Toronto 43.691531499999996 -79.47004413125
# Address,lat,long:- Cedar Grove, Toronto 43.7832305 -79.1834779067599
# Address,lat,long:- 9500 Markham Rd, Toronto 43.7427005 -79.2186311
# Address,lat,long:- 2240 Lake Shore Blvd W , Toronto 43.6212424 -79.4830236
# Address,lat,long:- Parc Lofts, Toronto 43.641860550000004 -79.41019750000001
# Address,lat,long:- 295 Adelaide St W, Toronto 43.647051 -79.3941058
# Address,lat,long:- 255 Village Green Square, Toronto 43.7781607 -79.2815201
# Address,lat,long:- 365 Church St , Toronto 43.660811 -79.378788
# Address,lat,long:- 561 Sherbourne, Toronto 43.6530662 -79.3689885
# Address,lat,long:- Clifton Manor, Toronto 43.6687406 -79.5536452
# Address,lat,long:- 87 Stoney Creek Dr, Toronto 43.7710229 -79.1699429
# Address,lat,long:- 11 Garnet Ave, Toronto 43.66897706 -79.42152836
# Address,lat,long:- 49 Fernwood Park Ave, Toronto 43.67107701960045 -79.28824003659818
# Address,lat,long:- 589 Rhodes Ave, Toronto 43.67988726216216 -79.32331241351352
# Address,lat,long:- 3830 Bathurst St, Toronto 43.73952405 -79.4349018439637
# Address,lat,long:- 3018 Yonge St, Toronto 43.724281000000005 -79.40248448150777
# Address,lat,long:- 150 Neptune Dr, Toronto 43.729731 -79.4412084
# Address,lat,long:- 10 Tapscott Rd, Toronto 43.8059365 -79.21908470571762
# Address,lat,long:- 103 Grayson Crescent, Toronto 43.8161567 -79.2029618
# Address,lat,long:- One City Hall, Toronto 43.6550328 -79.38473156308993
# Address,lat,long:- 2798 Dundas St W, Toronto 43.6654874 -79.4626692
# Address,lat,long:- Rose Park, Toronto 43.685598850000005 -79.5178422176324
# Address,lat,long:- 22 Kencliff Crescent, Toronto 43.7610956 -79.2485605
# Address,lat,long:- 340 Bellamy Rd N, Toronto 43.7551324 -79.2350824
# Address,lat,long:- 155 Yorkville Ave , Toronto 43.6703025 -79.3944791
# Address,lat,long:- 576 Front St W , Toronto 43.64091555555555 -79.40110955555555
# Address,lat,long:- Roehampton, Toronto 43.7085493 -79.39763879876776
# Address,lat,long:- Gibson Square, Toronto 43.76917685 -79.4147586565534
# Address,lat,long:- hARDING, Toronto 43.7001929 -79.4999969
# Address,lat,long:- Harding, Toronto 43.7001929 -79.4999969
# Address,lat,long:- Yorkdale Village, Toronto 43.7246418 -79.4475031
# Address,lat,long:- 97 Kalmar Ave, Toronto 43.692979018181816 -79.26957195454546
# Address,lat,long:- 150 Sudbury St, Toronto 43.6414778 -79.42408901188773
# Address,lat,long:- Tridel, Toronto 43.64457185 -79.52518976422965
# Address,lat,long:- 56 Leyton Ave , Toronto 43.694859720000004 -79.27852828
# Address,lat,long:- 38 Grand Magazine St , Toronto 43.6365496 -79.4023142
# Address,lat,long:- 33 Bay St , Toronto 43.642563300000006 -79.37720998730094
# Address,lat,long:- 15 Wedmore Ave , Toronto 43.720848645327514 -79.30587786571947
# Address,lat,long:- 90 Rowntree Ave, Toronto 43.6805285 -79.4649081
# Address,lat,long:- 109 Sunnyside Ave, Toronto 43.64110686666667 -79.44910696666666
# Address,lat,long:- 399 Pape Ave, Toronto 43.6704125 -79.34112636666667
# Address,lat,long:- 341 Eglinton Ave E, Toronto 43.7090495 -79.3864142
# Address,lat,long:- 5418 Yonge St, Toronto 43.7756962 -79.4147639
# Address,lat,long:- Bay & College Park, Toronto 43.653963 -79.387207
# Address,lat,long:- 250 Queens Quay W , Toronto 43.6391703 -79.3858573
# Address,lat,long:- 100 Western Battery Rd, Toronto 43.63964665 -79.41590827083749
# Address,lat,long:- 429 Broadview Ave, Toronto 43.6668502 -79.3529981
# Address,lat,long:- 21 Grand Magazine St , Toronto 43.6365496 -79.4023142
# Address,lat,long:- 117 McMahon Dr , Toronto 43.766849871724496 -79.37193745311465
# Address,lat,long:- 2230 Lake Shore Blvd W , Toronto 43.6213764 -79.4829458
# Address,lat,long:- 155 Redpath Ave , Toronto 43.70881885 -79.39273848084403
# Address,lat,long:- 31 Boyce Ave , Toronto 43.735095345454546 -79.24422526818182
# Address,lat,long:- 43 Eglinton Ave E , Toronto 43.706932 -79.396963
# Address,lat,long:- 666 Mt Pleasant Rd, Toronto 43.70542445 -79.38922804293725
# Address,lat,long:- 320-342 Avenue Road, Toronto 43.6803732 -79.3990873
# Address,lat,long:- 784 Markham St, Toronto 43.66896005238095 -79.41413955714286
# Address,lat,long:- 65 Southport St, Toronto 43.63996865 -79.47358605938773
# Address,lat,long:- 125 Peter St, Toronto 43.6465059 -79.3925191
# Address,lat,long:- Luna Vista CityPlace, Toronto 43.6408028 -79.39557366454727
# Address,lat,long:- 213 Brooke Ave, Toronto 43.73331439030572 -79.41847765101828
# Address,lat,long:- 60 Town Centre Court , Toronto 43.773396 -79.25603146428571
# Address,lat,long:- 1055 Victoria Park Avenue, Toronto 43.7064969 -79.2947821
# Address,lat,long:- The Jazz, Toronto 43.6505363 -79.3884696
# Address,lat,long:- The Prelude, Toronto 43.6367868 -79.3951087
# Address,lat,long:- 200 Roehampton Av, Toronto 43.7095525 -79.39226712352941
# Address,lat,long:- 2775 Jane Street, Toronto 43.74865015 -79.51453295000002
# Address,lat,long:- 1 Rosemount, Toronto 43.7315385 -79.27392699999999
# Address,lat,long:- 7 Kenaston Gardens, Toronto 43.76673909139377 -79.38588205967798
# Address,lat,long:- 145 Elinor Ave , Toronto 43.7539916 -79.3043944
# Address,lat,long:- 21 Clairtrell Rd, Toronto 43.7681452 -79.3907804
# Address,lat,long:- 50 Lynn Williams St , Toronto 43.63947795 -79.4151685945755
# Address,lat,long:- 209 Clinton St, Toronto 43.65951748260869 -79.41535528695653
# Address,lat,long:- 32 Davenport Rd, Toronto 43.673388349999996 -79.38995247544204
# Address,lat,long:- Liberty market lofts, Toronto 43.63737535 -79.41833894922632
# Address,lat,long:- SQ, Toronto 43.653963 -79.387207
# Address,lat,long:- 875 Queen St E, Toronto 43.6601389 -79.3429398
# Address,lat,long:- Edge, Toronto 43.6425012 -79.3871153
# Address,lat,long:- 121 McMahon Dr, Toronto 43.7677262 -79.3706232
# Address,lat,long:- 50 Gerrard St E, Toronto 43.6599479 -79.3788223
# Address,lat,long:- 15 Merchants' Wharf , Toronto 43.6442891 -79.3634915
# Address,lat,long:- 65 E Liberty St , Toronto 43.63815065 -79.41407665185808
# Address,lat,long:- 110 Charles St E , Toronto 43.670045 -79.380083
# Address,lat,long:- 36 Blue Jays Way, Toronto 43.6449168 -79.391987
# Address,lat,long:- 770 Bay St , Toronto 43.660198 -79.385863
# Address,lat,long:- 11 Brunel Ct , Toronto 43.63940245 -79.39314572608257
# Address,lat,long:- 3317 Ellesmere Rd, Toronto 43.78695893333334 -79.1858319
# Address,lat,long:- 512 Delaware Ave N, Toronto 43.671468 -79.4323019
# Address,lat,long:- 576 Front St W, Toronto 43.64091555555555 -79.40110955555555
# Address,lat,long:- Park Terrace, Toronto 43.653963 -79.387207
# Address,lat,long:- 3 Butterfield Dr, Toronto 43.748931 -79.3214212
# Address,lat,long:- 382 Beresford Ave, Toronto 43.655550403530114 -79.4798281724442
# Address,lat,long:- Somerset Apartments, Toronto 43.7713343 -79.45270175504001
# Address,lat,long:- 15 Jean St, Toronto 43.6874064 -79.3739888
# Address,lat,long:- 301 Gilmour Ave, Toronto 43.6660165 -79.4788744
# Address,lat,long:- 20 John St , Toronto 43.6444924 -79.389066
# Address,lat,long:- 15 Windermere Ave , Toronto 43.6372128 -79.4699121
# Address,lat,long:- Majorca Towers, Toronto 43.7864415 -79.35366460866055
# Address,lat,long:- 352 Howland Ave, Toronto 43.675914021052634 -79.4131439368421
# Address,lat,long:- Casa Condos, Toronto 43.77743325 -79.33675078433157
# Address,lat,long:- 33 Harbour Square , Toronto 43.6406828 -79.3769999
# Address,lat,long:- Elle, Toronto 43.6729059 -79.4704574
# Address,lat,long:- 640 Pape Ave, Toronto 43.67685685 -79.34417735000001
# Address,lat,long:- 58 Sherwood Ave , Toronto 43.7144438 -79.39681665810753
# Address,lat,long:- 119 Harlandale Ave, Toronto 43.7608343 -79.41758744444445
# Address,lat,long:- 307 Gilmour Ave, Toronto 43.6660165 -79.4788744
# Address,lat,long:- 57 St Joseph St , Toronto 43.6659655 -79.3854984
# Address,lat,long:- 628 Fleet St , Toronto 43.6361103 -79.4033294
# Address,lat,long:- 1060 Sheppard Ave W , Toronto 43.7506185 -79.46388396218887
# Address,lat,long:- The Colonnade, Toronto 43.7729866 -79.5008713
# Address,lat,long:- 125 Peter St , Toronto 43.6465059 -79.3925191
# Address,lat,long:- YC, Toronto -34.8899421 -56.0790982
# Address,lat,long:- 88 Scott St, Toronto 43.64848615 -79.37651147905876
# Address,lat,long:- The Yards, Toronto 43.6706718 -79.4706264
# Address,lat,long:- Glas, Toronto 43.6462921 -79.3942702
# Address,lat,long:- Ice Condos 2, Toronto 43.6417865 -79.38175712860597
# Address,lat,long:- The Charlie, Toronto 43.6459872 -79.39397827889105
# Address,lat,long:- 555 Yonge St , Toronto 43.6647874 -79.3842539
# Address,lat,long:- 954 King St W , Toronto 43.6418949 -79.4134661
# Address,lat,long:- 9 Byng Ave, Toronto 43.7765971 -79.4141366
# Address,lat,long:- 21 Brookside Dr , Toronto 43.6789162 -79.3052873
# Address,lat,long:- Atlantis Aquarius, Toronto 43.6368301 -79.40637272427871
# Address,lat,long:- 21 Lippincott St, Toronto 43.65527335454546 -79.40579573636364
# Address,lat,long:- 90 Adelaide St. East, Toronto 43.6514060625 -79.37430975
# Address,lat,long:- 57 Blackfriar Ave, Toronto 43.69577951448301 -79.56015957461973
# Address,lat,long:- 79 Elise Terrace, Toronto 43.78993639759539 -79.44147392758357
# Address,lat,long:- 1251 King St W, Toronto 43.6381991 -79.42965895
# Address,lat,long:- 101 Charles St E , Toronto 43.669787 -79.380288
# Address,lat,long:- Exhibit Residences, Toronto 43.66875745 -79.39539042887898
# Address,lat,long:- 36 Park Lawn Rd, Toronto 43.62354279208538 -79.482974462424
# Address,lat,long:- 39 Annie Craig Dr, Toronto 43.6253878 -79.4784544
# Address,lat,long:- 56 Annie Craig Dr, Toronto 43.6253878 -79.4784544
# Address,lat,long:- 99 Mulock Ave, Toronto 43.6705571 -79.46537013333334
# Address,lat,long:- 2400 Bathurst Street, Toronto 43.7050255 -79.42694050234192
# Address,lat,long:- Rob C, Toronto 43.7239286 -79.5258844
# Address,lat,long:- 25 Fisherville Rd, Toronto 43.78885215 -79.44896084999999
# Address,lat,long:- 43 Lee Ave , Toronto 43.6686659875 -79.29712445
# Address,lat,long:- 60 mendelssohn st, Toronto 43.7163525 -79.2817794
# Address,lat,long:- 262 St George St , Toronto 43.67313671739131 -79.40244779999999
# Address,lat,long:- 3210 Lake Shore Blvd W, Toronto 43.5974497 -79.5209901
# Address,lat,long:- Concord, Toronto 43.782521900000006 -79.46636283293554
# Address,lat,long:- 83 Tansley Ave, Toronto 43.74612384278216 -79.24651850408564
# Address,lat,long:- 151 St George St , Toronto 43.669450749999996 -79.40006630000002
# Address,lat,long:- Leaside Towers, Toronto 43.7071975 -79.34122067605054
# Address,lat,long:- The Heathview, Toronto 43.7824114 -79.3849962
# Address,lat,long:- Fifty on the Park, Toronto 43.64333095 -79.40027386852458
# Address,lat,long:- Meadowvale Gardens, Toronto 43.7987721 -79.1661282
# Address,lat,long:- 2379 Cliff Rd, Toronto 32.779557 -96.833548
# Address,lat,long:- 1101 Bay St, Toronto 43.667760799999996 -79.38831379798847
# Address,lat,long:- 761 Bay St, Toronto 43.6594185 -79.3849666
# Address,lat,long:- 372 Shuter St , Toronto 43.65751088 -79.36302498
# Address,lat,long:- 15 Merchants' Wharf, Toronto 43.6442891 -79.3634915
# Address,lat,long:- 128 De Grassi St, Toronto 43.6630556 -79.34729019999999
# Address,lat,long:- Liberty Walk, Toronto 43.715148150000005 -79.45157480190812
# Address,lat,long:- Epic, Toronto 43.7215245 -79.5063046
# Address,lat,long:- 158 Cottonwood Dr, Toronto 43.7299355214384 -79.34473766582366
# Address,lat,long:- 280 Morningside Ave, Toronto 43.7707355 -79.18783555681819
# Address,lat,long:- 70 Mossbank Dr, Toronto 43.7665848 -79.2138948
# Address,lat,long:- 102 Goulding Ave, Toronto 43.79025149090909 -79.42711962727273
# Address,lat,long:- 89 Isabella St, Toronto 43.6683872 -79.38064978899561
# Address,lat,long:- 1 King West, Toronto 43.6487854 -79.3781831237976
# Address,lat,long:- 38 Cameron St, Toronto 43.6496024 -79.3982075687222
# Address,lat,long:- 901 Sheppard Ave W, Toronto 43.7514924 -79.4568655
# Address,lat,long:- GROVE, Toronto 39.3646687 22.9644165
# Address,lat,long:- 222 Oakridge Dr, Toronto 43.73365435 -79.22747771249999
# Address,lat,long:- 36 Kelway Blvd, Toronto 43.70734886428571 -79.41231577857143
# Address,lat,long:- 85 Glenmore Rd, Toronto 43.67820366428571 -79.3108426357143
# Address,lat,long:- 88 Blue Jays Way , Toronto 43.645594483870966 -79.39226277419355
# Address,lat,long:- 5180 Yonge St , Toronto 43.77022549047619 -79.4133065095238
# Address,lat,long:- 1960 Queen St E, Toronto 43.6697074 -79.3021014
# Address,lat,long:- 697 Ellesmere Rd, Toronto 43.763761083333335 -79.28907693333333
# Address,lat,long:- Prince Arthur, Toronto 43.6694835 -79.3967445
# Address,lat,long:- Bridge Condo, Toronto 43.77129585 -79.41400363239174
# Address,lat,long:- 32 Culnan Ave, Toronto 43.6234472 -79.5251947
# Address,lat,long:- 55 Munson Crescent, Toronto 43.76131207349984 -79.26463098983426
# Address,lat,long:- 610 Birchmount Rd, Toronto 43.71603187272727 -79.2721631
# Address,lat,long:- 3 Castle Hill Dr, Toronto 43.79278770418253 -79.29969892554197
# Address,lat,long:- 123 Strath Ave, Toronto 43.657705718181816 -79.5127011909091
# Address,lat,long:- Boutique, Toronto 43.76971725 -79.36690291013011
# Address,lat,long:- 23 Elise Terrace, Toronto 43.79138344306223 -79.44086135936925
# Address,lat,long:- 68 Rayside Dr, Toronto 43.6326715 -79.56151924636242
# Address,lat,long:- Success Tower, Toronto 43.64304325 -79.37696723150378
# Address,lat,long:- 90 Stadium Rd, Toronto 43.6350565 -79.4014216
# Address,lat,long:- 28 Byng Ave, Toronto 43.77705425 -79.41380640679672
# Address,lat,long:- 750 Military Trail, Toronto 43.7903878 -79.1977317
# Address,lat,long:- 25 Scarborough Golf Club Rd, Toronto 43.74474126666667 -79.20861758333334
# Address,lat,long:- 225 Sackville St, Toronto 43.659551 -79.362606
# Address,lat,long:- 355 King St W , Toronto 43.645993 -79.392132
# Address,lat,long:- 9471 Yonge St, Toronto 43.7808484 -79.415698
# Address,lat,long:- GRAND GENESIS, Toronto 43.6583659 -79.3527306
# Address,lat,long:- 9608 Yonge St, Toronto 43.7808484 -79.415698
# Address,lat,long:- 8 Foundry Ave, Toronto 43.66846088 -79.44860478
# Address,lat,long:- 97 Atlee Ave, Toronto 43.71555745 -79.2524143625
# Address,lat,long:- 2003 Dundas St W, Toronto 43.6513428 -79.4462693
# Address,lat,long:- Beacon, Toronto 43.7500328 -79.2846088
# Address,lat,long:- 21 Grand Magazine St, Toronto 43.6365496 -79.4023142
# Address,lat,long:- 75 S Town Centre Blvd, Toronto 43.8502109 -79.3362758
# Address,lat,long:- 155 Weir Crescent, Toronto 43.771552071773804 -79.19674156919412
# Address,lat,long:- 124 Dupont St, Toronto 43.67616282857143 -79.40171775714285
# Address,lat,long:- Residence on Bloor, Toronto 43.66729105 -79.3993657383167
# Address,lat,long:- 79 Muir Ave, Toronto 43.6534023 -79.4363621
# Address,lat,long:- 111 St Clair Ave W , Toronto 43.68666265 -79.39948655
# Address,lat,long:- 415 Jarvis St, Toronto 43.663326 -79.3769522
# Address,lat,long:- 399 Spring Garden Ave , Toronto 43.768759571487735 -79.3895288370071
# Address,lat,long:- Curve, Toronto 43.64169445 -79.42466314861012
# Address,lat,long:- King Charlotte, Toronto 43.6462299 -79.3936647
# Address,lat,long:- 8323 Kennedy Rd, Toronto 43.7619973 -79.2797197
# Address,lat,long:- 8200 Birchmount Rd, Toronto 43.7633769 -79.2912587
# Address,lat,long:- 101 Peter Street, Toronto 43.6475125 -79.3927771
# Address,lat,long:- 77 McMurrich St , Toronto 43.67488985 -79.38979399488011
# Address,lat,long:- 50 Silverhill Dr, Toronto 43.63520403431513 -79.55010945991164
# Address,lat,long:- 100 Harbour St , Toronto 43.64190295 -79.37964466028694
# Address,lat,long:- 220 Victoria St, Toronto 43.65488543478261 -79.3791214347826
# Address,lat,long:- Grid, Toronto 43.7039222 -79.3885781
# Address,lat,long:- 47 Hove St, Toronto 43.75778633636364 -79.44242959090909
# Address,lat,long:- 50 Sellers Ave, Toronto 43.68237024390244 -79.44605345609756
# Address,lat,long:- 43 Bulbourne Rd, Toronto 43.7453156 -79.5917369
# Address,lat,long:- 36 Shank St , Toronto 43.642382016666666 -79.41439483333333
# Address,lat,long:- 60 South Town Centre Blvd, Toronto 43.8502109 -79.3362758
# Address,lat,long:- 50 Town Centre Court, Toronto 43.773255500000005 -79.25526814999999
# Address,lat,long:- 215 Sherway Gardens Rd, Toronto 43.609152449999996 -79.55761698577052
# Address,lat,long:- Waterclub, Toronto 43.6399017 -79.3824661
# Address,lat,long:- Enigma on the Park, Toronto 43.6562876 -79.4533858
# Address,lat,long:- YC Condos, Toronto 43.77743325 -79.33675078433157
# Address,lat,long:- 125 Village Green Square , Toronto 43.7774165 -79.2812115
# Address,lat,long:- 8323 Kennedy Rd Markham, Toronto 43.8236377 -79.3069381
# Address,lat,long:- Aria, Toronto 43.643481 -79.3803828
# Address,lat,long:- Venture, Toronto 43.8069208 -79.1990513
# Address,lat,long:- 5940 Yonge St, Toronto 43.7874075 -79.41811806448942
# Address,lat,long:- 7768 Kennedy Rd Markham, Toronto 43.8236377 -79.3069381
# Address,lat,long:- 430 Mclevin Ave Scarborough, Toronto 43.8102563 -79.220702
# Address,lat,long:- 8228 Birchmount Rd Markham, Toronto 43.8214845 -79.3168504
# Address,lat,long:- 135 Village Green Square, Toronto 43.7778723 -79.2807506
# Address,lat,long:- Bridge Condominiums, Toronto 43.66697595 -79.38904775006048
# Address,lat,long:- 1080 Bay St, Toronto 43.66712725 -79.38849775
# Address,lat,long:- 32 Ivordale Crescent, Toronto 43.753845907861646 -79.31242742616375
# Address,lat,long:- 1575 Lake Shore Blvd W , Toronto 43.6373446 -79.45300157583081
# Address,lat,long:- 1 Michael Power Pl, Toronto 43.64396 -79.529488
# Address,lat,long:- Madison, Toronto 43.6771392 -79.4066846
# Address,lat,long:- 189 Sheridan Ave , Toronto 43.652642 -79.4345629
# Address,lat,long:- West One City Place, Toronto -26.2113123 28.3396679
# Address,lat,long:- Bridge, Toronto 43.653963 -79.387207
# Address,lat,long:- 31 Alma Ave, Toronto 43.644589 -79.4292387
# Address,lat,long:- 2220 Lake Shore Blvd W, Toronto 43.6228625 -79.48329
# Address,lat,long:- Royal Arms, Toronto 43.77546085 -79.41524187047557
# Address,lat,long:- Essex II, Toronto 43.63886735 -79.53691409999999
# Address,lat,long:- 268 Kenilworth Ave , Toronto 43.67426416 -79.30407826
# Address,lat,long:- 200 Dundas St E , Toronto 43.657184 -79.374408
# Address,lat,long:- NORTH VIEW TERRACE, Toronto 43.6756332 -79.3939047
# Address,lat,long:- 830 Lawrence Ave W, Toronto 43.7144801 -79.45411203165295
# Address,lat,long:- 50 Town Centre Crt, Toronto 43.773255500000005 -79.25526814999999
# Address,lat,long:- 61 Town Centre crt, Toronto 43.773740000000004 -79.25260400341443
# Address,lat,long:- 60 Town Centre Crt, Toronto 43.773396 -79.25603146428571
# Address,lat,long:- 59 Shoreview Dr, Toronto 43.76236861264556 -79.17832915172511
# Address,lat,long:- 64 Bluewater Ct, Toronto 43.6210335 -79.4891707
# Address,lat,long:- 19 Brant St, Toronto 43.645583 -79.3977131
# Address,lat,long:- 40 Pleasant Blvd, Toronto 43.68757 -79.39237039165286
# Address,lat,long:- 288 Pellatt Ave, Toronto 43.71346078675076 -79.52692260888952
# Address,lat,long:- 3231 Eglinton Ave E, Toronto 43.7439149 -79.2144402
# Address,lat,long:- Front Street and Spadina, Toronto 43.64418805 -79.38525791850914
# Address,lat,long:- 21 Nelson St, Toronto 43.7459948 -79.2335052
# Address,lat,long:- 2380 Queen St E, Toronto 43.67419090666667 -79.28085946
# Address,lat,long:- 47 Highcastle Rd, Toronto 43.78896714545455 -79.21535328181818
# Address,lat,long:- 18 Mondeo Dr , Toronto 43.76483455 -79.28809319999999
# Address,lat,long:- 351 Clinton St , Toronto 43.663214745454546 -79.41678514545455
# Address,lat,long:- han li, Toronto 52.4613862 -1.9800872
# Address,lat,long:- James Cooper Mansion, Toronto 43.6709193 -79.37658140461926
# Address,lat,long:- 1498 King St W, Toronto 43.6365499 -79.4397834
# Address,lat,long:- 1950 Kennedy Road, Toronto 43.767626 -79.28286057646277
# Address,lat,long:- Maple Leaf Square, Toronto 43.6424777 -79.38048359601797
# Address,lat,long:- 15 Yorkville Ave, Toronto 43.6707824 -79.3929111
# Address,lat,long:- 13 St Joseph St, Toronto 43.66574903603105 -79.38617484567492
# Address,lat,long:- 1125 Bay St, Toronto 43.6584264 -79.3848284
# Address,lat,long:- 20 Bruyeres Mews, Toronto 43.6373046 -79.4004642
# Address,lat,long:- 160 Flemington Rd, Toronto 43.7192478 -79.4450503
# Address,lat,long:- The Curve, Toronto 43.64169445 -79.42466314861012
# Address,lat,long:- 75 Queens Wharf Rd, Toronto 43.63849825 -79.39799287066958
# Address,lat,long:- 1 King St W, Toronto 43.6487854 -79.3781831237976
# Address,lat,long:- Century Plaza, Toronto 43.6649477 -79.38598736049107
# Address,lat,long:- 185 Roehampton Ave, Toronto 43.709033705882355 -79.3929990882353

# %%
# tdf = pd.DataFrame(dict_location.items())
# tdf.rename(columns = {0:'ApartmentName',1:'location'},inplace=True)
# tdf.head()
# tdf = pd.DataFrame(data=tdf.location.to_list(),index=tdf.ApartmentName)
# tdf.rename(columns = {0:'Latitude',1:'longitude'},inplace=True)
# tdf.reset_index(inplace=True)
# tdf.head()
# df_new = pd.merge(df,tdf,on='ApartmentName',how='outer')
# df_new.drop(['Latitude_x','Longitude'],inplace=True,axis = 1)
# df_new.rename(columns={'Latitude_y':'Latitude'},inplace=True)
# print(df_new[df_new['ApartmentName']=='eCentral'])
# df_new.replace(' ½','.5',inplace=True,regex=True)

# df_new.head()
# Out:
#   ApartmentName         Streetname NoofBedrooms NoofBathrooms     Price  \
# 4      eCentral  15 Roehampton Ave            1             1  $2,002.5
# 5      eCentral  15 Roehampton Ave            1             1  $2,248.5
# 6      eCentral  15 Roehampton Ave            2             2  $2,455.8
# 7      eCentral  15 Roehampton Ave            2             2    $3,608
# 8      eCentral  15 Roehampton Ave            2             2    $3,847
# 9      eCentral  15 Roehampton Ave          2 ½           2 ½  $4,998.3
#
#    Latitude  longitude
# 4       NaN        NaN
# 5       NaN        NaN
# 6       NaN        NaN
# 7       NaN        NaN
# 8       NaN        NaN
# 9       NaN        NaN
#             ApartmentName              Streetname NoofBedrooms NoofBathrooms  \
# 0  571 Prince Edward Dr N  571 Prince Edward Dr N            1             1
# 1  571 Prince Edward Dr N  571 Prince Edward Dr N            1             1
# 2  571 Prince Edward Dr N  571 Prince Edward Dr N            2             2
# 3  571 Prince Edward Dr N  571 Prince Edward Dr N            2             2
# 4                eCentral       15 Roehampton Ave            1             1
#
#       Price   Latitude  longitude
# 0    $2,000  43.660515 -79.510212
# 1    $2,300  43.660515 -79.510212
# 2    $2,700  43.660515 -79.510212
# 3    $3,850  43.660515 -79.510212
# 4  $2,002.5        NaN        NaN

# %%
# df_new.to_csv('./raw_df.csv')

# %%
df_new = pd.read_csv('./raw_df.csv',index_col=None)
df_new.drop('Unnamed: 0',inplace=True,axis=1)
df_new.head()
# Out:
#             ApartmentName              Streetname  NoofBedrooms  \
# 0  571 Prince Edward Dr N  571 Prince Edward Dr N           1.0
# 1  571 Prince Edward Dr N  571 Prince Edward Dr N           1.0
# 2  571 Prince Edward Dr N  571 Prince Edward Dr N           2.0
# 3  571 Prince Edward Dr N  571 Prince Edward Dr N           2.0
# 4                eCentral       15 Roehampton Ave           1.0
#
#    NoofBathrooms     Price   Latitude  longitude
# 0            1.0    $2,000  43.660515 -79.510212
# 1            1.0    $2,300  43.660515 -79.510212
# 2            2.0    $2,700  43.660515 -79.510212
# 3            2.0    $3,850  43.660515 -79.510212
# 4            1.0  $2,002.5        NaN        NaN

# %%
from geopy.extra.rate_limiter import RateLimiter

geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)
test1 = df_new[df_new['ApartmentName']=='eCentral']
test1['ApartmentName'].apply(geocode)
# Out:
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('eCentral',), **{}).
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\site-packages\geopy\geocoders\base.py", line 355, in _call_geocoder
#     page = requester(req, timeout=timeout, **kwargs)
#   File "C:\Anaconda3\lib\urllib\request.py", line 531, in open
#     response = meth(req, response)
#   File "C:\Anaconda3\lib\urllib\request.py", line 641, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "C:\Anaconda3\lib\urllib\request.py", line 569, in error
#     return self._call_chain(*args)
#   File "C:\Anaconda3\lib\urllib\request.py", line 503, in _call_chain
#     result = func(*args)
#   File "C:\Anaconda3\lib\urllib\request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 429: Too Many Requests
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\site-packages\geopy\extra\rate_limiter.py", line 126, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Anaconda3\lib\site-packages\geopy\geocoders\osm.py", line 406, in geocode
#     self._call_geocoder(url, timeout=timeout), exactly_one
#   File "C:\Anaconda3\lib\site-packages\geopy\geocoders\base.py", line 373, in _call_geocoder
#     raise ERROR_CODE_MAP[code](message)
# geopy.exc.GeocoderQuotaExceeded: HTTP Error 429: Too Many Requests

# %%
for key in test_dict.keys():
    print(test_df.loc[test_df['ApartmentName']==key])

# %%
test_dict = {'571 Prince Edward Dr N':[43.660515, -79.5102122],
            '1182 Ossington Ave':[43.673361150000005 -79.43058640833334]}
test_df['Latitude'] = test_df['ApartmentName'].map(test_dict)

# %%
test_df.head()

# %%
test_df['Longitude'] = test_df.Latitude.map(lambda x: x)
test_df['Latitude'] = test_df.Latitude.apply(lambda x: str(x))

# %%
test_df.dropna(inplace=True,axis=0)
test_df.Latitude.apply(lambda x: x.split(', ')[0])
