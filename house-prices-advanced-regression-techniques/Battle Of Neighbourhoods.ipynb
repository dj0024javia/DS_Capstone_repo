# %% [markdown]
# # House Pricing Capstone Project

# %% [markdown]
# Author - Dhaval Javia

# %% [markdown]
# ### Problem Statement:

# %% [markdown]
# Hello, My name is Dhaval Javia and I am from India currently working at Infosys. I was thinking to moving abroad and for that first thing you search for when you reach there is House to stay (Of course Food comes first but for now let's keep the hungar  aside.) Let's assume that i will be able to buy a house in a year so i need some sort of system where i can search and compare house prices as per neighborhood.

# %% [markdown]
# ### Business Model:

# %% [markdown]
# By the end of this notebook, we should be able to predict housing prices for neighborhood based on features and location and many other dependent parameters. Main focus of audiance is the person living in State for quite some time and now wants a house of his/her own in a choice of neighborhood.

# %% [markdown]
# ### Data Description

# %% [markdown]
# Ask a home buyer to describe their dream house, and they probably won't begin with the height of the basement ceiling or the proximity to an east-west railroad. But this dataset proves that much more influences price negotiations than the number of bedrooms or a white-picket fence.

# %% [markdown]
# Following Data will be used to solve the problem at hand.
#
# 1. Neighborhood data from Foursquare API
# 10. Location data from geopy or foursquare API.
# 20. Pricing dataset with house features.

# %% [markdown]
# ### Data Sources

# %% [markdown]
# We have data available from varius sources but i found this housing price dataset from Kaggle.com which has dataset splitted in training and testset. Also dataset is unorganized. So lot of cleaning and data wrangling will be required.

# %% [markdown]
# 1. Location data and neighborhood data from Foursquare API
# 2. Traing Dataset available on Kaggle.com(https://www.kaggle.com/c/house-prices-advanced-regression-techniques/overview)
# 3. Test Dataset avaiable on Kaggle.com(https://www.kaggle.com/c/house-prices-advanced-regression-techniques/overview)

# %% [markdown]
# ### Methodology

# %% [markdown]
# We will be using dataset with below features and some of the features will be removed after analysis and if the dependency is not found on Sales Price, then we can safely eliminate those features from our analysis.
#
#     Firstly, we will convert each feature to numeric value or some definite categories and then plot each feature w.r.t. Sales Price to find out dependency of each feature on Sales Price. Also, We will be using HeatMap to visulize dependency of each feature on Sales Price.
#
#     After above step, we will finalize the data and assign each house with its latitude and longitude using Foursquare API and then use this data to predict Sales Price and plot the data onto Folium Map for better visulization.

# %% [markdown]
# Following details are available in the dataset with description.

# %% [markdown]
# Data fields
# Here's a brief version of what you'll find in the data description file.
#
# 1. SalePrice - the property's sale price in dollars. This is the target variable that you're trying to predict.
# 2. MSSubClass: The building class
# 5. MSZoning: The general zoning classification
# 5. LotFrontage: Linear feet of street connected to property
# 5. LotArea: Lot size in square feet
# 5. Street: Type of road access
# 5. Alley: Type of alley access
# 5. LotShape: General shape of property
# 5. LandContour: Flatness of the property
# 5. Utilities: Type of utilities available
# 5. LotConfig: Lot configuration
# 5. LandSlope: Slope of property
# 5. Neighborhood: Physical locations within Ames city limits
# 5. Condition1: Proximity to main road or railroad
# 5. Condition2: Proximity to main road or railroad (if a second is present)
# 5. BldgType: Type of dwelling
# 5. HouseStyle: Style of dwelling
# 5. OverallQual: Overall material and finish quality
# 5. OverallCond: Overall condition rating
# 5. YearBuilt: Original construction date
# 5. YearRemodAdd: Remodel date
# 5. RoofStyle: Type of roof
# 5. RoofMatl: Roof material
# 5. Exterior1st: Exterior covering on house
# 5. Exterior2nd: Exterior covering on house (if more than one material)
# 5. MasVnrType: Masonry veneer type
# 5. MasVnrArea: Masonry veneer area in square feet
# 5. ExterQual: Exterior material quality
# 5. ExterCond: Present condition of the material on the exterior
# 5. Foundation: Type of foundation
# 5. BsmtQual: Height of the basement
# 5. BsmtCond: General condition of the basement
# 5. BsmtExposure: Walkout or garden level basement walls
# 5. BsmtFinType1: Quality of basement finished area
# 5. BsmtFinSF1: Type 1 finished square feet
# 5. BsmtFinType2: Quality of second finished area (if present)
# 5. BsmtFinSF2: Type 2 finished square feet
# 5. BsmtUnfSF: Unfinished square feet of basement area
# 5. TotalBsmtSF: Total square feet of basement area
# 5. Heating: Type of heating
# 5. HeatingQC: Heating quality and condition
# 5. CentralAir: Central air conditioning
# 5. Electrical: Electrical system
# 5. 1stFlrSF: First Floor square feet
# 5. 2ndFlrSF: Second floor square feet
# 5. LowQualFinSF: Low quality finished square feet (all floors)
# 5. GrLivArea: Above grade (ground) living area square feet
# 5. BsmtFullBath: Basement full bathrooms
# 5. BsmtHalfBath: Basement half bathrooms
# 5. FullBath: Full bathrooms above grade
# 5. HalfBath: Half baths above grade
# 5. Bedroom: Number of bedrooms above basement level
# 5. Kitchen: Number of kitchens
# 5. KitchenQual: Kitchen quality
# 5. TotRmsAbvGrd: Total rooms above grade (does not include bathrooms)
# 5. Functional: Home functionality rating
# 5. Fireplaces: Number of fireplaces
# 5. FireplaceQu: Fireplace quality
# 5. GarageType: Garage location
# 5. GarageYrBlt: Year garage was built
# 5. GarageFinish: Interior finish of the garage
# 5. GarageCars: Size of garage in car capacity
# 5. GarageArea: Size of garage in square feet
# 5. GarageQual: Garage quality
# 5. GarageCond: Garage condition
# 5. PavedDrive: Paved driveway
# 5. WoodDeckSF: Wood deck area in square feet
# 5. OpenPorchSF: Open porch area in square feet
# 5. EnclosedPorch: Enclosed porch area in square feet
# 5. 3SsnPorch: Three season porch area in square feet
# 5. ScreenPorch: Screen porch area in square feet
# 5. PoolArea: Pool area in square feet
# 5. PoolQC: Pool quality
# 5. Fence: Fence quality
# 5. MiscFeature: Miscellaneous feature not covered in other categories
# 5. MiscVal: $Value of miscellaneous feature
# 5. MoSold: Month Sold
# 5. YrSold: Year Sold
# 5. SaleType: Type of sale
# 5. SaleCondition: Condition of sale

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
# %matplotlib inline
# !pip install geocoder
# !pip install selenium
# !pip install geopy
# !pip install pgeocode
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
import requests
import urllib.request
import time
# !pip install geolocator.geocode
# !pip install geopy
from geopy.geocoders import Nominatim
import json
# Out:
# Requirement already satisfied: geocoder in c:\anaconda3\lib\site-packages (1.38.1)
# Requirement already satisfied: requests in c:\anaconda3\lib\site-packages (from geocoder) (2.22.0)
# Requirement already satisfied: ratelim in c:\anaconda3\lib\site-packages (from geocoder) (0.1.6)
# Requirement already satisfied: click in c:\anaconda3\lib\site-packages (from geocoder) (7.0)
# Requirement already satisfied: six in c:\anaconda3\lib\site-packages (from geocoder) (1.14.0)
# Requirement already satisfied: future in c:\anaconda3\lib\site-packages (from geocoder) (0.18.2)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\anaconda3\lib\site-packages (from requests->geocoder) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda3\lib\site-packages (from requests->geocoder) (2019.11.28)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\anaconda3\lib\site-packages (from requests->geocoder) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\anaconda3\lib\site-packages (from requests->geocoder) (1.25.8)
# Requirement already satisfied: decorator in c:\anaconda3\lib\site-packages (from ratelim->geocoder) (4.4.1)
# Requirement already satisfied: selenium in c:\anaconda3\lib\site-packages (3.141.0)
# Requirement already satisfied: urllib3 in c:\anaconda3\lib\site-packages (from selenium) (1.25.8)
# Requirement already satisfied: geopy in c:\anaconda3\lib\site-packages (1.21.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in c:\anaconda3\lib\site-packages (from geopy) (1.50)
# Requirement already satisfied: pgeocode in c:\anaconda3\lib\site-packages (0.2.1)
# Requirement already satisfied: pandas in c:\anaconda3\lib\site-packages (from pgeocode) (1.0.1)
# Requirement already satisfied: numpy in c:\anaconda3\lib\site-packages (from pgeocode) (1.18.1)
# Requirement already satisfied: requests in c:\anaconda3\lib\site-packages (from pgeocode) (2.22.0)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\anaconda3\lib\site-packages (from pandas->pgeocode) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in c:\anaconda3\lib\site-packages (from pandas->pgeocode) (2019.3)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\anaconda3\lib\site-packages (from requests->pgeocode) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\anaconda3\lib\site-packages (from requests->pgeocode) (1.25.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\anaconda3\lib\site-packages (from requests->pgeocode) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda3\lib\site-packages (from requests->pgeocode) (2019.11.28)
# Requirement already satisfied: six>=1.5 in c:\anaconda3\lib\site-packages (from python-dateutil>=2.6.1->pandas->pgeocode) (1.14.0)
# ERROR: Could not find a version that satisfies the requirement geolocator.geocode (from versions: none)
# ERROR: No matching distribution found for geolocator.geocode
# Requirement already satisfied: geopy in c:\anaconda3\lib\site-packages (1.21.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in c:\anaconda3\lib\site-packages (from geopy) (1.50)

# %%
df = pd.read_csv("./train.csv").set_index('Id')

# %%
df.head()
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                  ...
# 1          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
# 3          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 4          Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
# 5          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
#
#    MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1        0      2    2008        WD         Normal     208500
# 2        0      5    2007        WD         Normal     181500
# 3        0      9    2008        WD         Normal     223500
# 4        0      2    2006        WD        Abnorml     140000
# 5        0     12    2008        WD         Normal     250000
#
# [5 rows x 80 columns]

# %%
df.shape
# Out:
# (1460, 80)

# %%
df.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
#        'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond',
#        'PavedDrive', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'PoolQC', 'Fence', 'MiscFeature', 'MiscVal',
#        'MoSold', 'YrSold', 'SaleType', 'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
df['Neighborhood'].head()
# Out:
# Id
# 1    CollgCr
# 2    Veenker
# 3    CollgCr
# 4    Crawfor
# 5    NoRidge
# Name: Neighborhood, dtype: object

# %%
# CLIENT_ID = 'FSGWGXKGYQMRDNNC0BW33O15RUZ44L0MOVB4AHKXV5G4Y4WI'
# CLIENT_SECRET = 'OQUKUFEOWXDFYDHGYKAZYFIDFSLIVI2RVHNSDKFT10GGB0G1'
# query = 'Veenker'
# # latitude = 
# # longitude = 
# VERSION =  '20200301'
# near = 'Ames, IA'
# intent = 'browse'
# url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&v={}&query={}&near={}&intent'.format(CLIENT_ID, CLIENT_SECRET, VERSION, query, near, intent)
# url
# results = requests.get(url).json()
# print(results)

# %%
# geolocator = Nominatim(user_agent='my_user')
# location = geolocator.geocode("571 Prince Edward ON")
# latitude = location
# longitude = location
# print(latitude)
# print(longitude)

# %%
# import folium
# map = folium.Map(location = [latitude,longitude],zoom_start=15)
# map

# %%
response = requests.get("https://rentals.ca/toronto?bbox=-79.58248,43.55720,-79.26457,43.70456")

# %%
response
# Out:
# <Response [200]>

# %%
import time
from bs4 import BeautifulSoup
soap = BeautifulSoup(response.text,"html.parser")

# %%
soap
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <link href="https://use.typekit.net" rel="preconnect"/>
# <link href="https://images.rentals.ca" rel="preconnect"/>
# <link href="https://fonts.googleapis.com" rel="preconnect"/>
# <link href="https://maps.googleapis.com" rel="preconnect"/>
# <link href="https://maps.gstatic.com" rel="preconnect"/>
# <link href="https://www.google-analytics.com" rel="preconnect"/>
# <link href="https://s7.addthis.com" rel="preconnect"/>
# <link href="https://cdnjs.cloudflare.com" rel="preconnect"/>
# <link href="https://static.hotjar.com" rel="preconnect"/>
# <link href="https://script.hotjar.com" rel="preconnect"/>
# <link href="https://vars.hotjar.com" rel="preconnect"/>
# <link href="https://cdn.sift.com" rel="preconnect"/>
# <link href="https://hexagon-analytics.com" rel="preconnect"/>
# <link href="https://analytics.trovit.com" rel="preconnect"/>
# <link as="script" href="/static/rentalsca-phoenix/js/app.2e05ce0eec80.js" rel="preload"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <meta content="notranslate" name="google"/>
# <link href="/static/rentalsca-phoenix/img/favicon/apple-touch-icon.17095b6226c0.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/static/rentalsca-phoenix/img/favicon/favicon-32x32.dd117ff2f786.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/static/rentalsca-phoenix/img/favicon/favicon-16x16.105bd029cc78.png" rel="icon" sizes="16x16" type="image/png"/>
# <link crossorigin="use-credentials" href="/static/rentalsca-phoenix/img/favicon/site.826bed6d4eb5.webmanifest" rel="manifest"/>
# <link color="#5bbad5" href="/static/rentalsca-phoenix/img/favicon/safari-pinned-tab.2930a877023a.svg" rel="mask-icon"/>
# <meta content="#ff0000" name="msapplication-TileColor"/>
# <meta content="#ffffff" name="theme-color"/>
# <link href="https://rentals.ca/toronto?bbox=-79.58248%2C43.55720%2C-79.26457%2C43.70456" hreflang="en" rel="alternate"/>
# <link href="https://rentals.ca/fr/a-louer-toronto?bbox=-79.58248%2C43.55720%2C-79.26457%2C43.70456" hreflang="fr" rel="alternate"/>
# <link href="https://rentals.ca/toronto?bbox=-79.58248%2C43.55720%2C-79.26457%2C43.70456" hreflang="x-default" rel="alternate"/>
# <link href="android-app://com.rentalsca/http/toronto?bbox=-79.58248,43.55720,-79.26457,43.70456" rel="alternate"/>
# <link href="ios-app://1475449043/http/toronto?bbox=-79.58248,43.55720,-79.26457,43.70456" rel="alternate"/>
# <link href="/static/rentalsca-phoenix/css/app.6edbc1f65d24.css" rel="stylesheet" type="text/css"/>
# <!-- Rollbar -->
# <script>
#   var _rollbarConfig = {
#     accessToken: "3f24af335361418bbb9fd9cfddc387af",
#     captureUncaught: true,
#     captureUnhandledRejections: true,
#     payload: {
#       environment: "production"
#     }
#   };
#   // Rollbar Snippet
#   !function(r){function e(n){if(o[n])return o[n].exports;var t=o[n]={exports:{},id:n,loaded:!1};return r[n].call(t.exports,t,t.exports,e),t.loaded=!0,t.exports}var o={};return e.m=r,e.c=o,e.p="",e(0)}([function(r,e,o){"use strict";var n=o(1),t=o(4);_rollbarConfig=_rollbarConfig||{},_rollbarConfig.rollbarJsUrl=_rollbarConfig.rollbarJsUrl||"https://cdnjs.cloudflare.com/ajax/libs/rollbar.js/2.4.6/rollbar.min.js",_rollbarConfig.async=void 0===_rollbarConfig.async||_rollbarConfig.async;var a=n.setupShim(window,_rollbarConfig),l=t(_rollbarConfig);window.rollbar=n.Rollbar,a.loadFull(window,document,!_rollbarConfig.async,_rollbarConfig,l)},function(r,e,o){"use strict";function n(r){return function(){try{return r.apply(this,arguments)}catch(r){try{console.error("[Rollbar]: Internal error",r)}catch(r){}}}}function t(r,e){this.options=r,this._rollbarOldOnError=null;var o=s++;this.shimId=function(){return o},"undefined"!=typeof window&&window._rollbarShims&&(window._rollbarShims[o]={handler:e,messages:[]})}function a(r,e){if(r){var o=e.globalAlias||"Rollbar";if("object"==typeof r[o])return r[o];r._rollbarShims={},r._rollbarWrappedError=null;var t=new p(e);return n(function(){e.captureUncaught&&(t._rollbarOldOnError=r.onerror,i.captureUncaughtExceptions(r,t,!0),i.wrapGlobals(r,t,!0)),e.captureUnhandledRejections&&i.captureUnhandledRejections(r,t,!0);var n=e.autoInstrument;return e.enabled!==!1&&(void 0===n||n===!0||"object"==typeof n&&n.network)&&r.addEventListener&&(r.addEventListener("load",t.captureLoad.bind(t)),r.addEventListener("DOMContentLoaded",t.captureDomContentLoaded.bind(t))),r[o]=t,t})()}}function l(r){return n(function(){var e=this,o=Array.prototype.slice.call(arguments,0),n={shim:e,method:r,args:o,ts:new Date};window._rollbarShims[this.shimId()].messages.push(n)})}var i=o(2),s=0,d=o(3),c=function(r,e){return new t(r,e)},p=d.bind(null,c);t.prototype.loadFull=function(r,e,o,t,a){var l=function(){var e;if(void 0===r._rollbarDidLoad){e=new Error("rollbar.js did not load");for(var o,n,t,l,i=0;o=r._rollbarShims[i++];)for(o=o.messages||[];n=o.shift();)for(t=n.args||[],i=0;i<t.length;++i)if(l=t[i],"function"==typeof l){l(e);break}}"function"==typeof a&&a(e)},i=!1,s=e.createElement("script"),d=e.getElementsByTagName("script")[0],c=d.parentNode;s.crossOrigin="",s.src=t.rollbarJsUrl,o||(s.async=!0),s.onload=s.onreadystatechange=n(function(){if(!(i||this.readyState&&"loaded"!==this.readyState&&"complete"!==this.readyState)){s.onload=s.onreadystatechange=null;try{c.removeChild(s)}catch(r){}i=!0,l()}}),c.insertBefore(s,d)},t.prototype.wrap=function(r,e,o){try{var n;if(n="function"==typeof e?e:function(){return e||{}},"function"!=typeof r)return r;if(r._isWrap)return r;if(!r._rollbar_wrapped&&(r._rollbar_wrapped=function(){o&&"function"==typeof o&&o.apply(this,arguments);try{return r.apply(this,arguments)}catch(o){var e=o;throw e&&("string"==typeof e&&(e=new String(e)),e._rollbarContext=n()||{},e._rollbarContext._wrappedSource=r.toString(),window._rollbarWrappedError=e),e}},r._rollbar_wrapped._isWrap=!0,r.hasOwnProperty))for(var t in r)r.hasOwnProperty(t)&&(r._rollbar_wrapped[t]=r[t]);return r._rollbar_wrapped}catch(e){return r}};for(var u="log,debug,info,warn,warning,error,critical,global,configure,handleUncaughtException,handleUnhandledRejection,captureEvent,captureDomContentLoaded,captureLoad".split(","),f=0;f<u.length;++f)t.prototype[u[f]]=l(u[f]);r.exports={setupShim:a,Rollbar:p}},function(r,e){"use strict";function o(r,e,o){if(r){var t;"function"==typeof e._rollbarOldOnError?t=e._rollbarOldOnError:r.onerror&&!r.onerror.belongsToShim&&(t=r.onerror,e._rollbarOldOnError=t);var a=function(){var o=Array.prototype.slice.call(arguments,0);n(r,e,t,o)};a.belongsToShim=o,r.onerror=a}}function n(r,e,o,n){r._rollbarWrappedError&&(n[4]||(n[4]=r._rollbarWrappedError),n[5]||(n[5]=r._rollbarWrappedError._rollbarContext),r._rollbarWrappedError=null),e.handleUncaughtException.apply(e,n),o&&o.apply(r,n)}function t(r,e,o){if(r){"function"==typeof r._rol ...
#   // End Rollbar Snippet
# </script>
# <script>
#   (function(d) {
#     var config = {
#           kitId: 'gec7gtm',
#           scriptTimeout: 3000,
#           async: true
#         },
#         h=d.documentElement,t=setTimeout(function(){h.className=h.className.replace(/\bwf-loading\b/g,"")+" wf-inactive";},config.scriptTimeout),tk=d.createElement("script"),f=false,s=d.getElementsByTagName("script")[0],a;h.className+=" wf-loading";tk.src='https://use.typekit.net/'+config.kitId+'.js';tk.async=true;tk.onload=tk.onreadystatechange=function(){a=this.readyState;if(f||a&&a!="complete"&&a!="loaded")return;f=true;clearTimeout(t);try{Typekit.load(config)}catch(e){}};s.parentNode.insertBefore(tk,s)
#   })(document);
# </script>
# <script defer="" src="/static/rentalsca-phoenix/js/app.2e05ce0eec80.js" type="text/javascript"></script>
# <script type="text/javascript">
#     var AppStartup = [];
#   </script>
# <title>Rentals.ca :) Toronto Apartments, Condos and Houses For Rent</title>
# <meta content="Finding a place to call home in Toronto, ON has never been so easy. Quickly find your new Apartment, Condo or House using our easy-to-use map-based search." name="description"/>
# <link href="/toronto?suppress_pagination=0&amp;pagenum=2&amp;bbox=BoundingBox%28max_point%3D%3CPoint+object+at+0x7fa262e23130%3E%2C+min_point%3D%3CPoint+object+at+0x7fa2612fa640%3E%29" rel="next"/>
# <link href="https://rentals.ca/toronto" rel="canonical"/>
# <meta content="262245211172453" property="fb:app_id"/>
# <meta content="Rentals.ca :) Toronto Apartments, Condos and Houses For Rent" property="og:title"/>
# <meta content="Finding a place to call home in Toronto, ON has never been so easy. Quickly find your new Apartment, Condo or House using our easy-to-use map-based search." property="og:description"/>
# <meta content="https://rentals.ca/toronto" property="og:url"/>
# <meta content="article" property="og:type"/>
# <meta content="en" property="og:locale"/>
# <meta content="Rentals.ca" property="og:site_name"/>
# <meta content="https://images.rentals.ca/images/canada-3290310_1920.width-585.jpg" property="og:image"/>
# <meta content="585" property="og:image:width"/>
# <meta content="362" property="og:image:height"/>
# <meta content="The heart of it all" property="og:image:alt"/>
# <meta content="https://images.rentals.ca/images/canada-3290310_1920.width-585.jpg" name="twitter:image"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@rentalsdotca" name="twitter:site"/>
# <meta content="@rentalsdotca" name="twitter:creator"/>
# <meta content="Rentals.ca :) Toronto Apartments, Condos and Houses For Rent" name="twitter:title"/>
# <meta content="Finding a place to call home in Toronto, ON has never been so easy. Quickly find your new Apartment, Condo or House using our easy-to-use map-based search." name="twitter:description"/>
# </head>
# <body>
# <input name="csrfmiddlewaretoken" type="hidden" value="CP81Fvu2LBX2YnfijARS5P5JL9P1dL6z6oSkXtxJXFdbIpfgggvUBdCdktyk3eUD"/>
# <div id="app" v-cloak="">
# <app-smart-banner></app-smart-banner>
# <navbar-main :user="store.user">
# </navbar-main>
# <search-results-page :content="store.search.response" :extra-response-fields="{ recordActive: store.search.recordActive }" :user="store.user">
# <template slot="list-footer">
# <div class="footer">
# <a class="main-logo main-logo--light" href="/">
# <img alt="Rentals.ca" src="/static/rentalsca-phoenix/img/logo.b3cdac8bd08a.svg"/> Rentals.ca
#   </a>
# <span class="footer__copyright">
#
#     Copyright © 2020 Rentals.ca, Inc. All rights reserved.
#   </span>
# <p class="footer__links">
# <a href="/contact" target="_blank">Contact Us</a>
#     |
#     <a href="/team" target="_blank">Team</a>
#     |
#
#       <a href="/blog">Blog</a>
#       |
#
#     <a href="/terms" target="_blank">Terms</a>
#     |
#     <a href="/privacy" target="_blank">Privacy Policy</a>
# </p>
# </div>
# </template>
# </search-results-page>
# <script type="application/ld+json">
#  {
#      "@context": "http://schema.org",
#      "@type": "SearchResultsPage",
#      "lastReviewed": "2020-03-07"
#  }
# </script>
# <script type="application/ld+json">
#    {
#        "@context": "http://schema.org",
#
#        "@type": "City",
#
#        "name": "Toronto",
#
#        "address": {
#            "@type": "PostalAddress",
#            "addressLocality": "Toronto",
#            "addressRegion": "ON",
#            "addressCountry": "CA"
#        }
#    }
#   </script>
# <!-- Begin listings schema.org markup -->
# <script type="application/ld+json">
#
#  {
#      "@context": "http://schema.org",
#
#      "@type": "ApartmentComplex",
#
#      "url": "https://rentals.ca/york/120-raglan-avenue",
#      "name": "120 Raglan Avenue",
#      "description": "\n\n",
#      "geo": {
#          "@type": "GeoCoordinates",
#          "latitude": 43.6865158,
#          "longitude": -79.4210052
#      },
#      "containedInPlace": {
#          "@type": "City",
#          "url": "https://rentals.ca/york",
#          "name" : "York",
#          "address": {
#              "@type": "PostalAddress",
#              "addressCountry" : "CA",
#              "addressRegion" : "Ontario"
#          }
#      },
#      "containsPlace": [
#
#          {
#              "@context": "http://schema.org",
#
#              "@type": "Apartment",
#
#              "name": "Jr. 1 Bedroom",
#              "potentialAction": {
#                  "@type": "RentAction",
#                  "priceSpecification": {
#                      "@type": "PriceSpecification",
#                      "price": 1864.00,
#                      "priceCurrency": "CAD"
#                  }
#              },
#
#          },
#
#          {
#              "@context": "http://schema.org",
#
#              "@type": "Apartment",
#
#              "name": "1 Bedroom",
#              "potentialAction": {
#                  "@type": "RentAction",
#                  "priceSpecification": {
#                      "@type": "PriceSpecification",
#                      "price": 2003.00,
#                      "priceCurrency": "CAD"
#                  }
#              },
#
#          },
#
#          {
#              "@context": "http://schema.org",
#
#              "@type": "Apartment",
#
#              "name": "2 Bedroom",
#              "potentialAction": {
#                  "@type": "RentAction",
#                  "priceSpecification": {
#                      "@type": "PriceSpecification",
#                      "price": 2347.00,
#                      "priceCurrency": "CAD"
#                  }
#              },
#
#          }
#
#      ],
#      "address": {
#          "@type" : "PostalAddress",
#          "addressCountry" : "CA",
#          "addressLocality" : "",
#          "addressRegion" : "",
#          "postalCode" : "M6C1L7",
#          "streetAddress" : "120 Raglan Avenue"
#      },
#      "telephone" :  "",
#      "photo" : [
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/york-on/299820/apartment-1767848.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/york-on/299820/apartment-1767848.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/york-on/299820/apartment-1767849.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/york-on/299820/apartment-1767849.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/york-on/299820/apartment-1767850.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/york-on/299820/apartment-1767850.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/york-on/299820/apartment-1767851.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/york-on/299820/apartment-1767851.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/york-on/299820/apartment-1767852.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/york-on/299820/apartment-1767852.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/york-on/299820/apartment-1767853.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/york-on/299820/apartment-1767853.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/york-on/299820/apartment-1767854.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/york-on/299820/apartment-1767854.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/york-on/299820/apartment-1767855.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/york-on/299820/apartment-1767855.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/york-on/299820/apartment-1767856.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/york-on/299820/apartment-1767856.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/york-on/299820/apartment-1767857.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/york-on/299820/apartment-1767857.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/york-on/299820/apartment-1767858.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/york-on/299820/apartment-1767858.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/york-on/299820/apartment-1767859.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/york-on/299820/apartment-1767859.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/york-on/299820/apartment-1767860.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/york-on/299820/apartment-1767860.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/york-on/299820/apartment-1767861.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/york-on/299820/apartment-1767861.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/york-on/299820/apartment-1767862.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/york-on/299820/apartment-1767862.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/york-on/299820/apartment-1767863.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/york-on/299820/apartment-1767863.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/york-on/299820/apartment-1767864.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/york-on/299820/apartment-1767864.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/york-on/299820/apartment-1767865.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/york-on/299820/apartment-1767865.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/york-on/299820/apartment-1767866.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/york-on/299820/apartment-1767866.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/york-on/299820/apartment-1767867.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/york-on/299820/apartment-1767867.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/york-on/299820/apartment-1767868.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/york-on/299820/apartment-1767868.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/york-on/299820/apartment-1767869.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/york-on/299820/apartment-1767869.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/york-on/299820/apartment-1767870.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/york-on/299820/apartment-1767870.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/york-on/299820/apartment-1767871.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/york-on/299820/apartment-1767871.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/york-on/299820/apartment-1767872.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/york-on/299820/apartment-1767872.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/york-on/299820/apartment-1767873.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/york-on/299820/apartment-1767873.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/york-on/299820/apartment-1767874.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/york-on/299820/apartment-1767874.jpg"
#          }
#
#      ]
#  }
#
# </script>
# <script type="application/ld+json">
#
#  {
#      "@context": "http://schema.org",
#
#      "@type": "ApartmentComplex",
#
#      "url": "https://rentals.ca/toronto/35-walmer-road",
#      "name": "35 Walmer Road",
#      "description": "\n\n",
#      "geo": {
#          "@type": "GeoCoordinates",
#          "latitude": 43.6688769,
#          "longitude": -79.4055552
#      },
#      "containedInPlace": {
#          "@type": "City",
#          "url": "https://rentals.ca/toronto",
#          "name" : "Toronto",
#          "address": {
#              "@type": "PostalAddress",
#              "addressCountry" : "CA",
#              "addressRegion" : "Ontario"
#          }
#      },
#      "containsPlace": [
#
#          {
#              "@context": "http://schema.org",
#
#              "@type": "Apartment",
#
#              "name": "Jr. 1 Bedroom",
#              "potentialAction": {
#                  "@type": "RentAction",
#                  "priceSpecification": {
#                      "@type": "PriceSpecification",
#                      "price": 2183.00,
#                      "priceCurrency": "CAD"
#                  }
#              },
#
#          },
#
#          {
#              "@context": "http://schema.org",
#
#              "@type": "Apartment",
#
#              "name": "1 Bedroom",
#              "potentialAction": {
#                  "@type": "RentAction",
#                  "priceSpecification": {
#                      "@type": "PriceSpecification",
#                      "price": 2353.00,
#                      "priceCurrency": "CAD"
#                  }
#              },
#
#          },
#
#          {
#              "@context": "http://schema.org",
#
#              "@type": "Apartment",
#
#              "name": "2 Bedroom",
#              "potentialAction": {
#                  "@type": "RentAction",
#                  "priceSpecification": {
#                      "@type": "PriceSpecification",
#                      "price": 2889.00,
#                      "priceCurrency": "CAD"
#                  }
#              },
#
#          }
#
#      ],
#      "address": {
#          "@type" : "PostalAddress",
#          "addressCountry" : "CA",
#          "addressLocality" : "",
#          "addressRegion" : "",
#          "postalCode" : "M5R 2X3",
#          "streetAddress" : "35 Walmer Road"
#      },
#      "telephone" :  "",
#      "photo" : [
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/279962/high-rise-apartment-living-room-natural-light-high-ceiling-1486849.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/279962/high-rise-apartment-living-room-natural-light-high-ceiling-1486849.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/279962/high-rise-apartment-outdoor-building-1486847.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/279962/high-rise-apartment-outdoor-building-1486847.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/279962/high-rise-apartment-outdoor-building-lawn-1486848.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/279962/high-rise-apartment-outdoor-building-lawn-1486848.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/279962/high-rise-apartment-empty-room-stainless-steel-1486850.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/279962/high-rise-apartment-empty-room-stainless-steel-1486850.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/279962/high-rise-apartment-patio-terrace-tile-floor-1486851.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/279962/high-rise-apartment-patio-terrace-tile-floor-1486851.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/279962/high-rise-apartment-corridor-carpet-1486852.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/279962/high-rise-apartment-corridor-carpet-1486852.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/279962/high-rise-apartment-empty-room-hardwood-floor-natural-light-tile-floor-1486853.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/279962/high-rise-apartment-empty-room-hardwood-floor-natural-light-tile-floor-1486853.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/279962/high-rise-apartment-empty-room-hardwood-floor-stainless-steel-1486854.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/279962/high-rise-apartment-empty-room-hardwood-floor-stainless-steel-1486854.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/279962/high-rise-apartment-kitchen-tile-floor-1486855.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/279962/high-rise-apartment-kitchen-tile-floor-1486855.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/279962/high-rise-apartment-kitchen-hardwood-floor-natural-light-tile-floor-1486856.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/279962/high-rise-apartment-kitchen-hardwood-floor-natural-light-tile-floor-1486856.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/279962/high-rise-apartment-empty-room-hardwood-floor-vaulted-ceiling-1486857.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/279962/high-rise-apartment-empty-room-hardwood-floor-vaulted-ceiling-1486857.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/279962/high-rise-apartment-kitchen-stainless-steel-1486858.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/279962/high-rise-apartment-kitchen-stainless-steel-1486858.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/279962/high-rise-apartment-empty-room-hardwood-floor-natural-light-1486859.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/279962/high-rise-apartment-empty-room-hardwood-floor-natural-light-1486859.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/279962/high-rise-apartment-bathroom-1486860.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/279962/high-rise-apartment-bathroom-1486860.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/279962/high-rise-apartment-patio-terrace-1486861.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/279962/high-rise-apartment-patio-terrace-1486861.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/279962/high-rise-apartment-patio-terrace-1486862.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/279962/high-rise-apartment-patio-terrace-1486862.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/279962/high-rise-apartment-living-room-hardwood-floor-1486863.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/279962/high-rise-apartment-living-room-hardwood-floor-1486863.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/279962/high-rise-apartment-misc-room-hardwood-floor-1486864.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/279962/high-rise-apartment-misc-room-hardwood-floor-1486864.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/279962/high-rise-apartment-living-room-1486865.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/279962/high-rise-apartment-living-room-1486865.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/279962/high-rise-apartment-misc-room-hardwood-floor-1486866.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/279962/high-rise-apartment-misc-room-hardwood-floor-1486866.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/279962/high-rise-apartment-misc-room-hardwood-floor-1486867.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/279962/high-rise-apartment-misc-room-hardwood-floor-1486867.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/279962/high-rise-apartment-misc-room-hardwood-floor-1486868.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/279962/high-rise-apartment-misc-room-hardwood-floor-1486868.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/279962/high-rise-apartment-gym-carpet-1486869.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/279962/high-rise-apartment-gym-carpet-1486869.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/279962/high-rise-apartment-gym-1486870.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/279962/high-rise-apartment-gym-1486870.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/279962/high-rise-apartment-gym-1486871.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/279962/high-rise-apartment-gym-1486871.jpg"
#          }
#
#      ]
#  }
#
# </script>
# <script type="application/ld+json">
#
#  {
#      "@context": "http://schema.org",
#
#      "@type": "ApartmentComplex",
#
#      "url": "https://rentals.ca/toronto/50-spadina-road",
#      "name": "50 Spadina Road",
#      "description": "\n\n",
#      "geo": {
#          "@type": "GeoCoordinates",
#          "latitude": 43.66906952269367,
#          "longitude": -79.40467178954924
#      },
#      "containedInPlace": {
#          "@type": "City",
#          "url": "https://rentals.ca/toronto",
#          "name" : "Toronto",
#          "address": {
#              "@type": "PostalAddress",
#              "addressCountry" : "CA",
#              "addressRegion" : "Ontario"
#          }
#      },
#      "containsPlace": [
#
#          {
#              "@context": "http://schema.org",
#
#              "@type": "Apartment",
#
#              "name": "1 Bedroom",
#              "potentialAction": {
#                  "@type": "RentAction",
#                  "priceSpecification": {
#                      "@type": "PriceSpecification",
#                      "price": 2549.00,
#                      "priceCurrency": "CAD"
#                  }
#              },
#
#          },
#
#          {
#              "@context": "http://schema.org",
#
#              "@type": "Apartment",
#
#              "name": "Large 1-Bedroom",
#              "potentialAction": {
#                  "@type": "RentAction",
#                  "priceSpecification": {
#                      "@type": "PriceSpecification",
#                      "price": 2711.00,
#                      "priceCurrency": "CAD"
#                  }
#              },
#
#          }
#
#      ],
#      "address": {
#          "@type" : "PostalAddress",
#          "addressCountry" : "CA",
#          "addressLocality" : "",
#          "addressRegion" : "",
#          "postalCode" : "M5R 2P1",
#          "streetAddress" : "50 Spadina Road"
#      },
#      "telephone" :  "",
#      "photo" : [
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/279121/luxury-apartment-outdoor-building-1472260.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/279121/luxury-apartment-outdoor-building-1472260.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/279121/luxury-apartment-patio-terrace-1472262.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/279121/luxury-apartment-patio-terrace-1472262.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/279121/apartment-1966329.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/279121/apartment-1966329.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/279121/apartment-1966330.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/279121/apartment-1966330.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/279121/apartment-1966331.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/279121/apartment-1966331.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/279121/apartment-1868168.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/279121/apartment-1868168.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/279121/apartment-1868169.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/279121/apartment-1868169.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/279121/luxury-apartment-empty-room-hardwood-floor-natural-light-1472276.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/279121/luxury-apartment-empty-room-hardwood-floor-natural-light-1472276.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/279121/apartment-1868172.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/279121/apartment-1868172.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/279121/luxury-apartment-kitchen-hardwood-floor-stainless-steel-tile-floor-1472280.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/279121/luxury-apartment-kitchen-hardwood-floor-stainless-steel-tile-floor-1472280.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/279121/luxury-apartment-bathroom-tile-floor-1472290.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/279121/luxury-apartment-bathroom-tile-floor-1472290.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/279121/luxury-apartment-living-room-hardwood-floor-natural-light-fireplace-1472292.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/279121/luxury-apartment-living-room-hardwood-floor-natural-light-fireplace-1472292.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/279121/luxury-apartment-living-room-hardwood-floor-1472293.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/279121/luxury-apartment-living-room-hardwood-floor-1472293.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/279121/luxury-apartment-misc-room-hardwood-floor-1472294.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/279121/luxury-apartment-misc-room-hardwood-floor-1472294.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/279121/luxury-apartment-gym-carpet-1472297.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/279121/luxury-apartment-gym-carpet-1472297.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/279121/luxury-apartment-sauna-vaulted-ceiling-deck-1472298.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/279121/luxury-apartment-sauna-vaulted-ceiling-deck-1472298.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/279121/apartment-1868175.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/279121/apartment-1868175.jpg"
#          }
#
#      ]
#  }
#
# </script>
# <script type="application/ld+json">
#
#  {
#      "@context": "http://schema.org",
#
#      "@type": "Accommodation",
#
#      "url": "https://rentals.ca/toronto/310-312-lonsdale-road",
#      "name": "310-312 Lonsdale Road",
#      "description": "\n\n",
#      "geo": {
#          "@type": "GeoCoordinates",
#          "latitude": 43.6892239,
#          "longitude": -79.4111993
#      },
#      "containedInPlace": {
#          "@type": "City",
#          "url": "https://rentals.ca/toronto",
#          "name" : "Toronto",
#          "address": {
#              "@type": "PostalAddress",
#              "addressCountry" : "CA",
#              "addressRegion" : "Ontario"
#          }
#      },
#      "containsPlace": [
#
#          {
#              "@context": "http://schema.org",
#
#              "@type": "Accommodation",
#
#              "name": "1 Bedroom",
#              "potentialAction": {
#                  "@type": "RentAction",
#                  "priceSpecification": {
#                      "@type": "PriceSpecification",
#                      "price": 2146.00,
#                      "priceCurrency": "CAD"
#                  }
#              },
#
#          },
#
#          {
#              "@context": "http://schema.org",
#
#              "@type": "Accommodation",
#
#              "name": "2 Bedroom",
#              "potentialAction": {
#                  "@type": "RentAction",
#                  "priceSpecification": {
#                      "@type": "PriceSpecification",
#                      "price": 2575.00,
#                      "priceCurrency": "CAD"
#                  }
#              },
#
#          }
#
#      ],
#      "address": {
#          "@type" : "PostalAddress",
#          "addressCountry" : "CA",
#          "addressLocality" : "",
#          "addressRegion" : "",
#          "postalCode" : "M4V 1X4",
#          "streetAddress" : "310-312 Lonsdale Road"
#      },
#      "telephone" :  "",
#      "photo" : [
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/283563/apartment-empty-room-hardwood-floor-stainless-steel-natural-light-1601069.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/283563/apartment-empty-room-hardwood-floor-stainless-steel-natural-light-1601069.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/283563/apartment-1601066.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/283563/apartment-1601066.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/283563/apartment-outdoor-building-1601074.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/283563/apartment-outdoor-building-1601074.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/283563/apartment-outdoor-building-1601067.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/283563/apartment-outdoor-building-1601067.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/283563/apartment-stairs-natural-light-1601068.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/283563/apartment-stairs-natural-light-1601068.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/283563/apartment-empty-room-hardwood-floor-1601070.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/283563/apartment-empty-room-hardwood-floor-1601070.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/283563/apartment-kitchen-hardwood-floor-stainless-steel-1601071.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/283563/apartment-kitchen-hardwood-floor-stainless-steel-1601071.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/283563/apartment-bathroom-natural-light-tile-floor-1601072.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/283563/apartment-bathroom-natural-light-tile-floor-1601072.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/283563/apartment-laundry-room-1601073.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/283563/apartment-laundry-room-1601073.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/283563/apartment-bathroom-1601076.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/283563/apartment-bathroom-1601076.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/283563/apartment-1601077.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/283563/apartment-1601077.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/283563/apartment-kitchen-stainless-steel-kitchen-island-1601078.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/283563/apartment-kitchen-stainless-steel-kitchen-island-1601078.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/283563/apartment-empty-room-hardwood-floor-1601079.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/283563/apartment-empty-room-hardwood-floor-1601079.jpg"
#          }
#
#      ]
#  }
#
# </script>
# <script type="application/ld+json">
#
#  {
# ...
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/305442/condo-1842861.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/305442/condo-1842859.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/305442/condo-1842859.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/305442/condo-1842858.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/305442/condo-1842858.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/305442/condo-1842857.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/305442/condo-1842857.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/305442/condo-1842855.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/305442/condo-1842855.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/305442/condo-1842856.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/305442/condo-1842856.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/305442/condo-1842854.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/305442/condo-1842854.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/305442/condo-1842853.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/305442/condo-1842853.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/305442/condo-1842852.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/305442/condo-1842852.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/305442/condo-1842851.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/305442/condo-1842851.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/305442/condo-1842850.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/305442/condo-1842850.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/305442/condo-1842849.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/305442/condo-1842849.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/305442/condo-1842848.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/305442/condo-1842848.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/305442/condo-1842847.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/305442/condo-1842847.jpg"
#          },
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://images.rentals.ca/property-pictures/small/toronto-on/305442/condo-1842846.jpg",
#              "image": "https://images.rentals.ca/property-pictures/large/toronto-on/305442/condo-1842846.jpg"
#          }
#
#      ]
#  }
#
# </script>
# <!-- End listings schema.org markup -->
# <div class="footer-main">
# <div class="container">
# <div class="footer">
# <a class="main-logo main-logo--light" href="/">
# <img alt="Rentals.ca" src="/static/rentalsca-phoenix/img/logo.b3cdac8bd08a.svg"/> Rentals.ca
#   </a>
# <span class="footer__copyright">
#
#     Copyright © 2020 Rentals.ca, Inc. All rights reserved.
#   </span>
# <p class="footer__links">
# <a href="/contact" target="_blank">Contact Us</a>
#     |
#     <a href="/team" target="_blank">Team</a>
#     |
#
#       <a href="/blog">Blog</a>
#       |
#
#     <a href="/terms" target="_blank">Terms</a>
#     |
#     <a href="/privacy" target="_blank">Privacy Policy</a>
# </p>
# </div>
# </div>
# </div>
# <create-account-modal></create-account-modal>
# <error-modal class="modal-error"></error-modal>
# <listing-complaint class="modal-listing-complaint"></listing-complaint>
# <listing-contact-modal class="modal-listing-contact"></listing-contact-modal>
# <login-modal class="modal-login">
# <template slot="recoverLink">
# <a href="/reset-password">
#       Recover
#     </a>
# </template>
# </login-modal>
# <photo-swipe></photo-swipe>
# <please-login-error-modal class="modal-please-login-error"></please-login-error-modal>
# <social-share-modal class="modal-social-share"></social-share-modal>
# <v-dialog></v-dialog>
# </div>
# <script type="text/javascript">
#     AppStartup.push(function() {
#       App.store.search = {
#         response: {"meta": {"pagination": {"current_page": 1, "last_page": 248, "per_page": 10, "total": 2472, "next_page_url": "/toronto?suppress_pagination=0&pagenum=2&bbox=BoundingBox%28max_point%3D%3CPoint+object+at+0x7fa262e23130%3E%2C+min_point%3D%3CPoint+object+at+0x7fa2612fa640%3E%29", "prev_page_url": null, "invalid": false, "total_units": 2941}, "focus": {"city": {"id": 6167865, "slug": "toronto", "name": "Toronto", "url": "https://rentals.ca/toronto", "region": {"id": 6093943, "code": "ON", "name": "Ontario"}, "location": {"x": -79.3831843, "y": 43.653226, "lng": -79.3831843, "lat": 43.653226}}, "type": "city", "centre": {"x": -79.3831843, "y": 43.653226, "lat": 43.653226, "lng": -79.3831843}, "url": "/toronto", "obj_path": "toronto", "property_count": 2472, "unit_count": 2941, "breadcrumbs": [{"label": "Home", "href": "/"}, {"label": "ON", "label_alt": "Ontario", "href": "/ontario"}, {"label_alt": "Toronto Rentals", "label": "Toronto", "href": "/toronto"}], "guide": "\n  <article class=\"content-guide\">\n    <header>\n      <div class=\"row\">\n        <div class=\"title\">\n          <h2>\n            <strong>Toronto</strong>,\n            ON\n          </h2>\n          <p>Renting Guide</p>\n        </div>\n\n        <nav>\n          <ul>\n            \n              <li><a href=\"#housing-market\">Housing Market</a></li>\n            \n              <li><a href=\"#average-rent\">Average Rent</a></li>\n            \n              <li><a href=\"#apartment-hunting\">Apartment Hunting</a></li>\n            \n              <li><a href=\"#residents\">Residents</a></li>\n            \n              <li><a href=\"#life-style\">Life &amp; Style</a></li>\n            \n              <li><a href=\"#neighbourhood\">Neighbourhood</a></li>\n            \n          </ul>\n        </nav>\n      </div>\n    </header>\n\n    <section class=\"hero\">\n      <div class=\"row\">\n        <div class=\"text-container\">\n          <p>The heart of it all</p>\n        </div>\n        <div class=\"img-container\">\n          <img alt=\"Toronto Downtown Skyline Skyscraper Condos Rental Rentals Apartments\" height=\"362\" src=\"https://images.rentals.ca/images/canada-3290310_1920.width-585.jpg\" width=\"585\">\n        </div>\n      </div>\n    </section>\n    \n    <section class=\"content-guide-intro\">\n      <a name=\"intro\"></a>\n      <div class=\"content row\">\n        <div class=\"img-container\">\n          \n            <img alt=\"Toronto Downtown Skyscraper Business Sunrise Reflection Rentals\" height=\"438\" src=\"https://images.rentals.ca/images/2908583663_d5bc33c473_b.width-585.jpg\" width=\"585\">\n          \n        </div>\n        <div class=\"text-container\">\n          <div class=\"rich-text\"><p>Canada\u2019s largest and most diverse city, Toronto has a little bit of everything. Live here and at your doorstep \u2013 metaphorically speaking \u2013 you will find beaches, museums, small-town feeling neighbourhoods, cultural communities and so much more! The best thing about Toronto is that it gives you exactly what you want. The worst thing is that you can be overwhelmed with all that choice! Not sure what is right for you? Try something you never have before, like an improv class. Then see what sticks and what new friends you meet in the big city!</p></div>\n        </div>\n      </div>\n    </section>\n\n    <section class=\"content-guide-aggregated-info\">\n      <div class=\"container\">\n        \n          <section class=\"content-guide-item\">\n            <a name=\"housing-market\"></a>\n            <h3>\n              Housing Market\n            </h3>\n            <div class=\"rich-text\"><p>Housing in Toronto has so many options that it can be overwhelming. Fight this by targeting a few neighbourhoods that you like and where the rent fits your budget. Just make sure you\u2019re being realistic about the base price for the city. Toronto is one of Canada\u2019s most expensive markets, so you may have to get thr ...
#
#
#         recordActive: null,
#       };
#
#       App.store.page.breadcrumbs = App.store.search.response.meta.focus.breadcrumbs;
#     });
#   </script>
# <script type="text/javascript">
#   AppStartup.push(function() {
#     App.i18n.currentLanguage = {"bidi": false, "code": "en", "name": "English", "name_local": "English", "name_translated": "English"};
#   });
#
#   /**
#    * User
#    */
#
#   AppStartup.push(function() {
#     App.store.user = {"is_anonymous": true};
#   });
#
#   /**
#    * Geodata
#    */
#
#
#     AppStartup.push(function() {
#       App.store.geoData = {"city": null, "active_city": null};
#     });
#
#
#   /**
#    * Endpoints
#    */
#   AppStartup.push(function() {
#     App.endpoints.listings = '/phoenix/api/v1.0.1/listings';
#     App.endpoints.setLanguage = '/i18n/setlang/';
#
#     App.endpoints.user = {
#       user: '/phoenix/api/v1.0.1/user',
#       change_password: '/phoenix/api/v1.0.1/user/change-password',
#       notifications: '/phoenix/api/v1.0.1/user/notifications',
#       notifications_reset: '/phoenix/api/v1.0.1/user/notifications/reset',
#       listings: '/phoenix/api/v1.0.1/user/listings',
#       drafts: '/phoenix/api/v1.0.1/user/drafts',
#       favourites: '/phoenix/api/v1.0.1/user/favourites',
#       savedSearches: '/phoenix/api/v1.0.1/user/saved-searches',
#       login: '/phoenix/api/v1.0.1/user/login',
#       logout: '/phoenix/api/v1.0.1/user/logout',
#       register: '/phoenix/api/v1.0.1/users',
#       resetPassword: '/phoenix/api/v1.0.1/user/reset-password',
#     };
#
#     App.endpoints.autosuggest = '/phoenix/api/v1.0.1/autocomplete';
#
#     App.endpoints.location = {
#       city: '/phoenix/api/v1.0.1/location/cities',
#       neighbourhood: '/phoenix/api/v1.0.1/location/neighbourhoods',
#     };
#   });
#
#   /**
#    * URL's (typically leave this application and go to a new page)
#    */
#   AppStartup.push(function() {
#     App.urls['index'] = '/';
#     App.urls['contact-page'] = '/contact';
#     App.urls['about'] = '/team';
#     App.urls['rent_report'] = '/national-rent-report';
#     App.urls['password_reset'] = '/reset-password';
#     App.urls['accounts:logout'] = '/accounts/logout/';
#     App.urls['manage:index'] = '/manage/';
#     App.urls['manage:listing'] = '/manage/listing';
#     App.urls['manage:favourites'] = '/manage/favourites';
#     App.urls['rentalsstaff:index'] = '/staff/';
#     App.urls['rentalsstaff:listings_advanced'] = '/staff/listings-advanced';
#     App.urls['wagtailadmin_home'] = '/cms/';
#   });
#
#   /**
#    * Constants
#    */
#   AppStartup.push(function() {
#     App.constants.I18N = {
#       LANGUAGE_DEFAULT: 'en',
#       URL_CITY_PREFIX: {
#         fr: 'a-louer-',
#       }
#     };
#
#     App.constants.RENTRANGE_MIN = 0;
#     App.constants.RENTRANGE_MAX = 5000;
#
#     App.constants.SORT_DEFAULT = 'relevant';
#
#     App.constants.SEARCH_RESULT_MAP_ZOOM = {
#       GENERIC: 13,
#       NEIGHBOURHOOD: 15,
#     };
#
#     App.constants.GOOGLE_MAPS_API_KEY = 'AIzaSyCBJeBxHKmIYsccLvyAVJju3trAcPm0N00';
#     App.constants.LOCAL_LOGIC_TOKEN = '924b6e5da7d532a96c1360e93618e2cfa8ed204f507e921e6535bbe3a37dfaff381d55fc6ef33e79';
#
#     App.constants.GOOGLE_ANALYTICS_ENABLED = true;
#     App.constants.HOTJAR_ENABLED = true;
#     App.constants.TROVIT_ENABLED = true;
#     App.constants.ROLLBAR_ENABLED = true;
#   });
#
#   /**
#    * Assets URI
#    */
#   AppStartup.push(function() {
#     App.assets = {
#       'rentalsca-phoenix/img/logo.svg': '/static/rentalsca-phoenix/img/logo.b3cdac8bd08a.svg',
#       'rentalsca-phoenix/img/lazy-loading-loading.svg': '/static/rentalsca-phoenix/img/lazy-loading-loading.2d0d83ed6597.svg',
#       'rentalsca-phoenix/img/map-marker-default-blue.svg': '/static/rentalsca-phoenix/img/map-marker-default-blue.74f97c9ef0a2.svg',
#       'rentalsca-phoenix/img/listing-local-logic-home.svg': '/static/rentalsca-phoenix/img/listing-local-logic-home.8a54c65e538f.svg',
#     };
#   });
# </script>
# <!-- add this -->
# <script type="text/javascript">
#   var addthis_config = addthis_config || {};
#   addthis_config.lang = 'en';
# </script>
# <script async="async" src="//s7.addthis.com/js/300/addthis_widget.js#pubid=ra-5c06b280bafabe3f" type="text/javascript"></script>
# <!-- /add this -->
# <!-- trovit -->
# <script type="text/javascript">
#   (function(i,s,o,g,r,a,m){i['TrovitAnalyticsObject']=r;i[r]=i[r]||function(){
#     (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#     m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://analytics.trovit.com/trovit-analytics.js','ta');
#
#   ta('init', 'ca', 1, 'ce68b0088a6cb5cf603bbf65281339b3');
# </script>
# <!-- /trovit -->
# <!-- hotjar -->
# <script>
#   (function(h,o,t,j,a,r){
#     h.hj=h.hj||function(){(h.hj.q=h.hj.q||[]).push(arguments)};
#     h._hjSettings={hjid:959397,hjsv:6};
#     a=o.getElementsByTagName('head')[0];
#     r=o.createElement('script');r.async=1;
#     r.src=t+h._hjSettings.hjid+j+h._hjSettings.hjsv;
#     a.appendChild(r);
#   })(window,document,'https://static.hotjar.com/c/hotjar-','.js?sv=');
# </script>
# <!-- /hotjar -->
# <!-- google analytics -->
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#     (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#     m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-79132992-1', 'auto');
#   ga('send', 'pageview');
# </script>
# <!-- /google analytics -->
# <!-- sift -->
# <script type="text/javascript">
#  var _account = 'c00fccb581';
#  var _user_id = '';
#  var _session_id = 'hwva1m4aqcyr4jlunt64adpeu748vgq4';
#
#  var _sift = window._sift = window._sift || [];
#  _sift.push(['_setAccount', _account]);
#  _sift.push(['_setUserId', _user_id]);
#  _sift.push(['_setSessionId', _session_id]);
#
#  _sift.push(['_trackPageview']);
#
#  (function() {
#      function ls() {
#          var e = document.createElement('script');
#          e.src = 'https://cdn.sift.com/s.js';
#          document.body.appendChild(e);
#                        }
#      if (window.attachEvent) {
#          window.attachEvent('onload', ls);
#      } else {
#          window.addEventListener('load', ls, false);
#      }
#  })();
# </script>
# <!-- /sift -->
# </body>
# </html>

# %%
response1 = requests.get("https://www.torontorentals.com/toronto")

# %%
soap1 = BeautifulSoup(response1.text,"html.parser")
soap1
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en"> <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <title>Toronto, ON Apartments, Condos &amp; Houses For Rent</title>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="yes" name="apple-mobile-web-app-capable">
# <link href="https://maps.googleapis.com" rel="preconnect"/>
# <link href="https://maps.gstatic.com" rel="preconnect"/>
# <link href="https://fonts.googleapis.com" rel="preconnect"/>
# <link href="https://cdn2.torontorentals.com" rel="preconnect"/>
# <link href="https://www.google-analytics.com" rel="preconnect"/>
# <link href="https://fonts.gstatic.com" rel="preconnect"/>
# <link href="https://stats.g.doubleclick.net" rel="preconnect"/>
# <link href="https://analytics.trovit.com" rel="preconnect"/>
# <meta content="app-id=1475449043" name="apple-itunes-app"/>
# <meta content="app-id=com.rentalsca" name="google-play-app"/>
# <link href="/static/torontorentals.com/images/favicon.403f1ac6506f.ico" rel="icon" type="image/vnd.microsoft.icon">
# <link href="/static/torontorentals.com/images/favicon.cb74a72bad22.png" rel="icon">
# <link href="/static/torontorentalscom/dist/search-results-page.7b156e7680d9.css" rel="stylesheet" type="text/css">
# <script>
#
#  (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#  /*
#     {'debug': False, 'js_script': 'analytics.js', 'tracking_id': 'UA-2572459-11', 'tracker_config': {'useAmpClientId': True}}
#   */
#  ga('create', 'UA-2572459-11', 'auto', {"useAmpClientId": true});
#  ga('send', 'pageview');
# </script>
# <meta content="Exclusive Apartment, Condo or House listings in Toronto Ontario. Browse the best selection of rentals in Toronto using our simple maps for easy navigation. Subscribe to TorontoRentals.com free listing alerts for the newest rentals posted daily from private owners and property managers." name="description">
# <link href="https://www.torontorentals.com/toronto" rel="canonical"/>
# <link href="https://www.torontorentals.com/toronto?amp" rel="amphtml">
# <meta content="Toronto, ON Apartments, Condos &amp; Houses For Rent" property="og:title">
# <meta content="Exclusive Apartment, Condo or House listings in Toronto Ontario. Browse the best selection of rentals in Toronto using our simple maps for easy navigation. Subscribe to TorontoRentals.com free listing alerts for the newest rentals posted daily from private owners and property managers." property="og:description">
# <meta content="https://www.torontorentals.com/toronto" property="og:url">
# <meta content="article" property="og:type"/>
# <meta content="en" property="og:locale"/>
# <meta content="TorontoRentals.com" property="og:site_name"/>
# <meta content="/static/torontorentalscom/img/opengraph-image-1456x1456.28de4fe08823.jpg" property="og:image"/>
# <meta content="1456" property="og:image:width"/>
# <meta content="1456" property="og:image:height"/>
# <meta content="TorontoRentals.com logo super imposed over Toronto skyline" property="og:image:alt"/>
# <meta content="1930145733971727" property="fb:app_id"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@torentals" name="twitter:site"/>
# <meta content="@torentals" name="twitter:creator"/>
# <meta content="Toronto, ON Apartments, Condos &amp; Houses For Rent" name="twitter:title"/>
# <meta content="Exclusive Apartment, Condo or House listings in Toronto Ontario. Browse the best selection of rentals in Toronto using our simple maps for easy navigation. Subscribe to TorontoRentals.com free listing alerts for the newest rentals posted daily from private owners and property managers." name="twitter:description"/>
# <meta content="/static/torontorentalscom/img/opengraph-image-1456x1456.28de4fe08823.jpg" name="twitter:image"/>
# <link href="https://www.torontorentals.com/toronto?p=2" rel="next"/>
# </meta></meta></meta></link></meta></link></link></link></meta></head>
# <body class="search-results-page">
# <input name="csrfmiddlewaretoken" type="hidden" value="2FbkilPr48SjJFgjrdlg49z8hIIbA6gkvrwj1ZbNipR8rqf2IazS5XeAyKHZzKnl"/>
# <div class="modal fade" id="modal-login" role="dialog" tabindex="-1">
# <div class="modal-dialog" role="document">
# <div class="modal-content">
# <div class="modal-header">
# <h5 class="modal-title">
# Welcome!
# <span class="modal-subtitle">Log In to Your Account</span>
# </h5>
# <button aria-label="Close" class="close" data-dismiss="modal" type="button">
# <span aria-hidden="true">×</span>
# </button>
# </div>
# <div class="modal-body form-group-as-line">
# <form class="material" data-redirect-url="/manage/listings" method="post">
# <input name="csrfmiddlewaretoken" type="hidden" value="2FbkilPr48SjJFgjrdlg49z8hIIbA6gkvrwj1ZbNipR8rqf2IazS5XeAyKHZzKnl"/>
# <div class="form-group">
# <input class="form-control" id="login-email" name="email" required="" type="email"/>
# <label for="login-email">Email*</label>
# </div>
# <div class="form-group">
# <input class="form-control" id="login-password" name="password" required="" type="password"/>
# <label for="login-password">Password*</label>
# </div>
# <div class="modal-alert alert"></div>
# <div class="d-flex justify-content-between align-items-center">
# <div class="form-check">
# <input class="form-check-input sr-only" id="login-remember-me" name="remember-me" type="checkbox"/>
# <label class="form-check-label" for="login-remember-me">Remember me</label>
# </div>
# <button class="btn btn-primary" type="submit">Log In</button>
# </div>
# </form>
# </div>
# <div class="modal-footer p-0 as-buttons justify-content-between align-items-center">
# <a class="btn w-50 mr-0 border-right text-center" data-to-another-modal="#modal-reset-password" href="#">Forgot your Password?</a>
# <a class="btn w-50 ml-0 text-center" data-to-another-modal="#modal-create-account" href="#">Create Account</a>
# </div>
# </div>
# </div>
# </div>
# <div class="modal fade" id="modal-reset-password" role="dialog" tabindex="-1">
# <div class="modal-dialog" role="document">
# <div class="modal-content">
# <div class="modal-header">
# <h5 class="modal-title">
# Forgot your info?
# <span class="modal-subtitle">Reset Your Password</span>
# </h5>
# <button aria-label="Close" class="close" data-dismiss="modal" type="button">
# <span aria-hidden="true">×</span>
# </button>
# </div>
# <div class="modal-body form-group-as-line">
# <form class="material" method="post">
# <input name="csrfmiddlewaretoken" type="hidden" value="2FbkilPr48SjJFgjrdlg49z8hIIbA6gkvrwj1ZbNipR8rqf2IazS5XeAyKHZzKnl">
# <div class="form-group">
# <input class="form-control" id="reset-password-email" name="email" required="" type="email" value=""/>
# <label for="reset-password-email">Email*</label>
# </div>
# <div class="modal-alert alert"></div>
# <div class="d-flex justify-content-between align-items-center">
# <p class="mb-0 mr-2">We will send you an email with further instructions.</p>
# <button class="btn btn-primary" type="submit">Reset</button>
# </div>
# </input></form>
# </div>
# <div class="modal-footer justify-content-start">
# <p class="mb-0">No need to reset? <a data-to-another-modal="#modal-login" href="#">Login.</a></p>
# </div>
# </div>
# </div>
# </div>
# <div class="modal fade" id="modal-create-account" role="dialog" tabindex="-1">
# <div class="modal-dialog" role="document">
# <div class="modal-content">
# <div class="modal-header">
# <h5 class="modal-title">
# Get started!
# <span class="modal-subtitle">Create a New Account</span>
# </h5>
# <button aria-label="Close" class="close" data-dismiss="modal" type="button">
# <span aria-hidden="true">×</span>
# </button>
# </div>
# <div class="modal-body form-group-as-line">
# <form class="material" data-redirect-url="/manage/listings/new?from=add-rental" method="post">
# <input name="csrfmiddlewaretoken" type="hidden" value="2FbkilPr48SjJFgjrdlg49z8hIIbA6gkvrwj1ZbNipR8rqf2IazS5XeAyKHZzKnl"/>
# <div class="form-group">
# <input class="form-control" id="create-account-full-name" name="name" required="" type="text"/>
# <label for="create-account-full-name">Full Name*</label>
# </div>
# <div class="row">
# <div class="col-6">
# <div class="form-group">
# <input class="form-control" id="create-account-email" name="email" required="" type="email"/>
# <label for="create-account-email">Email*</label>
# </div>
# </div>
# <div class="col-6">
# <div class="form-group">
# <input class="form-control phone" id="create-account-phone" name="phone" required="" type="tel"/>
# <label for="create-account-phone">Phone*</label>
# </div>
# </div>
# </div>
# <div class="row">
# <div class="col-6">
# <div class="form-group">
# <input class="form-control" id="create-account-password" name="password" required="" type="password"/>
# <label for="create-account-password">Password*</label>
# </div>
# </div>
# <div class="col-6">
# <div class="form-group">
# <input class="form-control" id="create-account-password-2" name="password2" required="" type="password"/>
# <label for="create-account-password-2">Repeat Password*</label>
# </div>
# </div>
# </div>
# <div class="form-group">
# <input class="form-control" id="create-account-company" name="company" type="text"/>
# <label for="create-account-company">Company</label>
# </div>
# <div class="modal-alert alert"></div>
# <div class="d-flex justify-content-between align-items-center">
# <div class="form-check mr-2">
# <input class="form-check-input sr-only" id="create-account-accept-terms" required="" type="checkbox"/>
# <label class="form-check-label" for="create-account-accept-terms">I agree to the <a href="/terms">Terms of Use</a> &amp; <a href="/privacy">Privacy Policy.</a></label>
# </div>
# <button class="btn btn-primary" type="submit">Register</button>
# </div>
# </form>
# </div>
# <div class="modal-footer justify-content-start align-items-center">
# <p class="m-0">Already have an account? <a href="/manage/listings/new?from=login">Log In.</a></p>
# </div>
# </div>
# </div>
# </div>
# <header class="main-header">
# <div class="container not-apply-map-tab-fix-vh">
# <nav class="navbar justify-content-between navbar-expand-lg">
# <a class="navbar-brand" href="/">
# <img height="40" src="/static/torontorentalscom/img/logo-blue.f70f9e5a8349.svg" width="80"/>
# <span class="logo-text d-none d-sm-inline-block"><strong>TorontoRentals</strong>.com</span>
# </a>
# <button aria-label="Open search" class="navbar-search ml-auto d-lg-none" data-target="#main-header-search-modal" data-toggle="modal" type="button">
# <i class="fa fa-search"></i>
# </button>
# <button aria-controls="main-header-navbar" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-target="#main-header-navbar" data-toggle="collapse" type="button">
# <span class="navbar-toggler-icon"></span>
# </button>
# <div class="d-none d-lg-block">
# <form action="/search" class="search-form-main">
# <div class="input-group">
# <input autocomplete="disabled" class="form-control" name="s" required="" type="text"/>
# <div class="label-behind">
# <span>Search by <strong>City</strong> or <strong>Address</strong></span>
# </div>
# <div class="input-group-append">
# <button class="btn btn-primary" type="submit">Search</button>
# <button aria-label="Close" class="close" data-dismiss="modal" type="button">
# <span aria-hidden="true">×</span>
# </button>
# </div>
# </div>
# </form>
# </div>
# <div class="collapse navbar-collapse" id="main-header-navbar">
# <div class="non-mobile">
# <ul class="navbar-nav">
# <li class="nav-item">
# <a class="btn btn-outline-primary" href="/manage/listings/new?from=login">Log in / Sign up</a>
# </li>
# <li class="nav-item">
# <a class="btn btn-primary btn-new-listing" href="/manage/listings/new?from=add-rental">
# <span class="label-new-listing">
# Add Rental
# </span>
# </a>
# </li>
# </ul>
# </div>
# <div class="mobile">
# <div class="mobile-slideout-panel">
# <ul>
# <li class="level-1">
# <a href="/manage/listings/new?from=add-rental">
# <span class="label">
# Add Rental
# </span>
# </a>
# </li>
# <li class="level-2">
# <a href="/manage/listings/new?from=login">Login</a>
# </li>
# <li class="level-2">
# <a href="/manage/listings/new?from=sign-up">Sign Up</a>
# </li>
# <li class="level-3">
# <a href="/neighbourhood-guide/toronto">
# <span class="tag">
# New
# </span>
# <span class="label">
# Neighborhood Guides
# </span>
# </a>
# </li>
# </ul>
# <ul class="social-profiles">
# <li class="social-instagram">
# <a href="https://www.instagram.com/to.rentals/" rel="noopener" target="_blank">
# <i class="fa fa-instagram"></i>
# <span class="hidden label">Instagram</span>
# </a>
# </li>
# <li class="social-facebook">
# <a href="https://www.facebook.com/torentals/" rel="noopener" target="_blank">
# <i class="fa fa-facebook-square"></i>
# <span class="hidden label">Facebook</span>
# </a>
# </li>
# <li class="social-youtube">
# <a href="https://www.youtube.com/channel/UCxx2QQwDaGaTarDNjOBRnMw" rel="noopener" target="_blank">
# <i class="fa fa-youtube-play"></i>
# <span class="hidden label">Youtube</span>
# </a>
# </li>
# <li class="social-twitter">
# <a href="http://twitter.com/torentals" rel="noopener" target="_blank">
# <i class="fa fa-twitter"></i>
# <span class="hidden label">Twitter</span>
# </a>
# </li>
# <li class="social-linkedin">
# <a href="https://www.linkedin.com/company/toronto-rentals-com" rel="noopener" target="_blank">
# <i class="fa fa-linkedin-square"></i>
# <span class="hidden label">LinkedIn</span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </nav>
# </div>
# </header>
# <div aria-hidden="true" class="modal fade" id="main-header-search-modal" role="dialog" tabindex="-1">
# <div class="modal-dialog" role="document">
# <div class="modal-content">
# <form action="/search" class="search-form-main">
# <div class="input-group">
# <input autocomplete="disabled" class="form-control" name="s" required="" type="text"/>
# <div class="label-behind">
# <span>Search by <strong>City</strong> or <strong>Address</strong></span>
# </div>
# <div class="input-group-append">
# <button class="btn btn-primary" type="submit">Search</button>
# <button aria-label="Close" class="close" data-dismiss="modal" type="button">
# <span aria-hidden="true">×</span>
# </button>
# </div>
# </div>
# </form>
# </div>
# </div>
# </div>
# <div class="list-back main-wrapper">
# <script type="application/ld+json">
#    {
#        "@context": "http://schema.org",
#        "@type": "SearchResultsPage",
#        "lastReviewed": "2020-03-07"
#    }
#   </script>
# <script type="application/ld+json">
#    {
#        "@context": "http://schema.org",
#        "@type": "City",
#        "name": "Toronto",
#
#        "address": {
#            "@type": "PostalAddress",
#            "addressLocality": "Toronto",
#            "addressRegion": "ON",
#            "addressCountry": "CA"
#        }
#    }
#   </script>
# <nav class="search-result-mobile-navbar col-12 d-xl-none d-flex justify-content-between align-items-stretch box-shadow">
# <a class="active" data-target="list" href="#">
# <i class="fa fa-list"></i>
# List
# </a>
# <a class="" data-target="map" href="#">
# <i class="fa fa-map-o"></i>
# Map
# </a>
# <a data-target="filters" href="#">
# <i class="fa fa-filter"></i>
# Filters
# </a>
# </nav>
# <div class="filter-container">
# <div class="container">
# <div class="row">
# <div class="col-12 container-columns">
# <div class="col1">
# <div class="filter-price-range">
# <div class="input-group">
# <i aria-hidden="true" class="fa fa-usd"></i>
# <input class="form-control" name="rent_min" value="0">
# </input></div>
# <div class="price slider"></div>
# <div class="input-group">
# <i aria-hidden="true" class="fa fa-usd"></i>
# <input class="form-control" name="rent_max" value="5000+">
# </input></div>
# </div>
# <div class="sort-by d-xl-none">
# <select class="form-control" name="sort-by">
# <option value="newest">Newest</option>
# <option value="price">Price - $</option>
# <option value="-price">Price - $$$</option>
# </select>
# </div>
# <div class="filter-dropdown filter-property-type simple-dropdown" data-multiselect="1" data-name="property-type">
# <i aria-hidden="true" class="fa fa-home fa-fw"></i>
# <span class="label">Type</span>
# <i aria-hidden="true" class="fa fa-angle-down"></i>
# <ul class="dropdown">
# <li class="simple-dropdown-item" data-value="Apartment">Apartment</li>
# <li class="simple-dropdown-item" data-value="Room">Room</li>
# <li class="simple-dropdown-item" data-value="House">House</li>
# <li class="simple-dropdown-item" data-value="Studio">Studio</li>
# <li class="simple-dropdown-item" data-value="Basement">Basement</li>
# <li class="simple-dropdown-item" data-value="Condo">Condo</li>
# </ul>
# </div>
# <div class="filter-dropdown filter-beds simple-dropdown" data-name="beds">
# <i aria-hidden="true" class="fa fa-bed fa-fw"></i>
# <span class="label">Beds</span>
# <i aria-hidden="true" class="fa fa-angle-down"></i>
# <ul class="dropdown">
# <li class="simple-dropdown-item">0+</li>
# <li class="simple-dropdown-item">1+</li>
# <li class="simple-dropdown-item">2+</li>
# <li class="simple-dropdown-item">3+</li>
# <li class="simple-dropdown-item">4+</li>
# </ul>
# </div>
# <div class="filter-dropdown filter-pets simple-dropdown" data-name="pets">
# <i aria-hidden="true" class="fa fa-paw fa-fw"></i>
# <span class="label">Pets</span>
# <i aria-hidden="true" class="fa fa-angle-down"></i>
# <ul class="dropdown">
# <li class="simple-dropdown-item" data-value="yes">Yes</li>
# <li class="simple-dropdown-item" data-value="no">No</li>
# </ul>
# </div>
# </div>
# <div class="col2">
# <div class="filter-dropdown more-filters simple-dropdown">
# <div class="more">
# <i aria-hidden="true" class="fa fa-plus"></i>
# More Filters
# </div>
# <div class="less">
# <i aria-hidden="true" class="fa fa-minus"></i>
# Less Filters
# </div>
# <div class="dropdown">
# <div class="dropdown-body">
# <div class="group group-1">
# <div class="group-row-1">
# <label>Bathrooms</label>
# <ul class="option-group checklist single-select" data-name="baths">
# <li data-value="">Any</li>
# <li data-value="1+">1+</li>
# <li data-value="2+">2+</li>
# <li data-value="3+">3+</li>
# </ul>
# </div>
# <div class="group-row group-row-2 group-size">
# <label>Size</label>
# <ul>
# <li>
# <select class="form-control" name="size-min">
# <option value="">Min sqf</option>
# <option value="100">100 sqf</option>
# <option value="200">200 sqf</option>
# <option value="500">500 sqf</option>
# <option value="1000">1000 sqf</option>
# <option value="2500">2500 sqf</option>
# </select>
# </li>
# <li>
# <select class="form-control" name="size-max">
# <option value="">Max sqf</option>
# <option value="200">200 sqf</option>
# <option value="500">500 sqf</option>
# <option value="1000">1000 sqf</option>
# <option value="2500">2500 sqf</option>
# <option value="5000">5000 sqf</option>
# </select>
# </li>
# </ul>
# </div>
# </div>
# <div class="group group-2">
# <div class="group-row group-row-1 features">
# <label>Features</label>
# <ul class="checklist" data-name="features">
# <li data-value="laundry">In-Suite Laundry <i class="fa"></i></li>
# <li data-value="air-conditioning">Air Conditioning <i class="fa"></i></li>
# <li data-value="dishwasher">Dishwasher <i class="fa"></i></li>
# <li data-value="balcony">Balcony <i class="fa"></i></li>
# <li data-value="gym">Gym <i class="fa"></i></li>
# <li data-value="parking">Parking <i class="fa"></i></li>
# </ul>
# </div>
# <div class="group-row group-row-2 utilities">
# <label>Utilities Included</label>
# <ul class="checklist" data-name="utilities">
# <li data-value="hydro">Hydro <i class="fa"></i></li>
# <li data-value="wifi">Wi-Fi <i class="fa"></i></li>
# <li data-value="heating">Heating <i class="fa"></i></li>
# <li data-value="water">Water <i class="fa"></i></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="dropdown-footer">
# <a class="btn" href="/toronto">Clear Filters</a>
# <button class="btn btn-primary update" type="button">
# <span class="d-xl-none">
# Done
# </span>
# <span class="d-none d-xl-inline-block">
# Update Filters
# </span>
# </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="listings-schemaorg-wrapper">
# <script type="application/ld+json">
#  {
#      "@context": "http://schema.org",
#
#      "@type": "Accommodation",
#
#
#      "url": "https://www.torontorentals.com/etobicoke/571-prince-edward-dr-n-id69764",
#      "name": "571 Prince Edward Dr N",
#      "description": "Dunpar has always sought to build projects in areas rich in existing amenities, and our newest project, Kingsway Village Square on Prince Edward, is no exception. Kingsway Village Square is a mid-rise Manhattan-style building, situated at 571 Prince Edward Drive North, just moments away from the quaint shops and restaurants of Bloor West Village. Steps away from libraries, gyms, food shops and highly ranked local schools. High Park, Royal York and the Old Mill subway stations are within walking distance. Upscale shopping is a short drive away to Sherway Gardens. **Site includes a 24/7 Concierge.** **Open House Dates: Open 7 Days a Week 11AM-7PM**",
#      "geo": {
#          "@type": "GeoCoordinates",
#          "latitude": 43.6602184,
#          "longitude": -79.5100634
#      },
#      "containedInPlace": {
#          "@type": "City",
#          "url": "https://www.torontorentals.com/etobicoke",
#          "name" : "Etobicoke",
#          "address": {
#              "@type": "PostalAddress",
#              "addressCountry" : "CA",
#              "addressRegion" : "Ontario"
#          }
#      },
#      "containsPlace": [
#
#          {
#              "@context": "http://schema.org",
#
#              "@type": "Accommodation",
#
#              "name": "1 bedroom",
#              "potentialAction": {
#                  "@type": "RentAction",
#                  "priceSpecification": {
#                      "@type": "PriceSpecification",
#                      "price": 2000.00,
#                      "priceCurrency": "CAD"
#                  }
#              },
#
#              "numberOfRooms": 1
#          },
#
#          {
#              "@context": "http://schema.org",
#
#              "@type": "Accommodation",
#
#              "name": "1 bedroom",
#              "potentialAction": {
#                  "@type": "RentAction",
#                  "priceSpecification": {
#                      "@type": "PriceSpecification",
#                      "price": 2300.00,
#                      "priceCurrency": "CAD"
#                  }
#              },
#
#              "numberOfRooms": 1
#          },
#
#          {
#              "@context": "http://schema.org",
#
#              "@type": "Accommodation",
#
#              "name": "2 bedroom",
#              "potentialAction": {
#                  "@type": "RentAction",
#                  "priceSpecification": {
#                      "@type": "PriceSpecification",
#                      "price": 2700.00,
#                      "priceCurrency": "CAD"
#                  }
#              },
#
#              "numberOfRooms": 2
#          },
#
#          {
#              "@context": "http://schema.org",
#
#              "@type": "Accommodation",
#
#              "name": "2 bedroom",
#              "potentialAction": {
#                  "@type": "RentAction",
#                  "priceSpecification": {
#                      "@type": "PriceSpecification",
#                      "price": 3850.00,
#                      "priceCurrency": "CAD"
#                  }
#              },
#
#              "numberOfRooms": 2
#          }
#
#      ],
#      "address": {
#          "@type" : "PostalAddress",
#          "addressCountry" : "CA",
#          "addressLocality" : "Etobicoke",
#          "addressRegion" : "Ontario",
#          "postalCode" : "M8X 0A1",
#          "streetAddress" : "571 Prince Edward Dr N"
#      },
#      "telephone" :  "",
#      "photo" : [
#
#
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/manage-upload-rentalinfodmsproperty.com-nLADo9_352x198.jpg",
#              "image": "https://cdn2.torontorentals.com/photos/large/manage-upload-rentalinfodmsproperty.com-nLADo9.jpg"
#          },
#
#
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/manage-upload-rentalinfodmsproperty.com-gvhPyY_352x198.jpg",
#              "image": "https://cdn2.torontorentals.com/photos/large/manage-upload-rentalinfodmsproperty.com-gvhPyY.jpg"
#          },
#
#
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/manage-upload-rentalinfodmsproperty.com-wtKonJ_352x198.png",
#              "image": "https://cdn2.torontorentals.com/photos/large/manage-upload-rentalinfodmsproperty.com-wtKonJ.png"
#          },
#
#
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/manage-upload-rentalinfodmsproperty.com-2qQ5Ln_352x198.png",
#              "image": "https://cdn2.torontorentals.com/photos/large/manage-upload-rentalinfodmsproperty.com-2qQ5Ln.png"
#          }
#
#      ]
#  }
# </script>
# <script type="application/ld+json">
#  {
#      "@context": "http://schema.org",
#
#      "@type": "Accommodation",
#
#
#      "url": "https://www.torontorentals.com/toronto/ecentral-id64432",
#      "name": "eCentral",
#      "description": "**MOVE IN TODAY AND RECEIVE 1 MONTH FREE RENT ON SELECT SUITES!** Terms and Conditions Apply. Contact us to book a tour and discuss the details! **Now Renting 1 and 2 Bedroom Suites, and 2 Bedroom Penthouses and Townhomes. Limited suites are available.** Schedule a tour today to view our designer model suites and community amenities. Visit our leasing centre at 15 Roehampton Avenue \u2013 open 7 days a week. It's all about proximity. It's life at the centre of it all. It's taking advantage of the numerous transit options and easily getting from point A to point B. Or it's staying home and availing yourself of the reimagined retail and entertainment of Toronto's newest place to be \u2013 Yonge and Eglinton. At eCentral the world is at your doorstep. It's why your living room looks better and why your weekends sound better. It's why you seize every opportunity, because you can, and because the day won't live itself. *Pricing subject to change based on real-time availability. For all floorplans and pricing, visit [www.ecentralliving.com/rental-suites](http://www.ecentralliving.com/rental-suites) or contact us for more details. **Suite photos advertised are of a model suite and are not representative of all suites available for rent **Office Hours** Monday \u2013 Friday 10AM \u2013 7PM Saturday \u2013 Sunday 10AM - 5PM Professional property management and resident services by Rhapsody Property Management Services **Community Amenities** * 4200 sq.ft. Rooftop Fitness Centre * Yoga and Spin Studio * Spa Treatment Room * Private Study Lounge * Two Party Rooms with Kitchens * Rooftop Lounge with Outdoor Fireplace * BBQs with Dining Area * Lounge with Wet Bar * Dining Room * Games Room * Library * Dog Wash * Pet-Friendly Community * Professional Managed by Rhapsody Property Management Services * Future Underground Access to Eglinton TTC station, ePlace, and the Future Eglinton Crosstown LRT* * Concierge Services * Guest Suites * Single Fob Keyless Access into Building and Suites * Secured Underground Parking * Bike Storage * Storage Lockers * Parcel Pending Package Management System * After-Hours Security * Resident Portal * Amenity Booking System * Online Rent Payment System * Visitor Parking On-Site ($) **Suite Amenities** * Offering studio, 1 & 2 bedroom suites, 2 bedroom penthouses, and 2 bedroom townhomes * 4 Piece Stainless Steel Kitchen Appliances * In-suite Washer and Dryer * Quartz Countertops * High Ceilings * Private Balcony and Patio **Location Details** eCentral is located next to three storeys of retail in ePlace and across the street from one of Toronto's busiest midtown shopping destinations \u2013 RioCan's newly renovated and revitalized Yonge Eglinton Centre.",
#      "geo": {
#          "@type": "GeoCoordinates",
#          "latitude": 43.7079426,
#          "longitude": -79.3978607
#      },
#      "containedInPlace": {
#          "@type": "City",
#          "url": "https://www.torontorentals.com/toronto",
#          "name" : "Toronto",
#          "address": {
#              "@type": "PostalAddress",
#              "addressCountry" : "CA",
#              "addressRegion" : "Ontario"
#          }
#      },
#      "containsPlace": [
#
#          {
#              "@context": "http://schema.org",
#
#              "@type": "Accommodation",
#
#              "name": "Studio",
#              "potentialAction": {
#                  "@type": "RentAction",
#                  "priceSpecification": {
#                      "@type": "PriceSpecification",
#                      "price": 2002.50,
#                      "priceCurrency": "CAD"
#                  }
#              },
#
#              "numberOfRooms": 0
#          },
#
#          {
#              "@context": "http://schema.org",
#
#              "@type": "Accommodation",
#
#              "name": "1 Bedroom",
#              "potentialAction": {
#                  "@type": "RentAction",
#                  "priceSpecification": {
#                      "@type": "PriceSpecification",
#                      "price": 2248.50,
#                      "priceCurrency": "CAD"
#                  }
#              },
#
#              "numberOfRooms": 1
#          },
#
#          {
#              "@context": "http://schema.org",
#
#              "@type": "Accommodation",
#
#              "name": "1 Bedroom",
#              "potentialAction": {
#                  "@type": "RentAction",
#                  "priceSpecification": {
#                      "@type": "PriceSpecification",
#                      "price": 2455.75,
#                      "priceCurrency": "CAD"
#                  }
#              },
#
#              "numberOfRooms": 1
#          },
#
#          {
#              "@context": "http://schema.org",
#
#              "@type": "Accommodation",
#
#              "name": "2 Bedroom Townhome",
#              "potentialAction": {
#                  "@type": "RentAction",
#                  "priceSpecification": {
#                      "@type": "PriceSpecification",
#                      "price": 3608.00,
#                      "priceCurrency": "CAD"
#                  }
#              },
#
#              "numberOfRooms": 2
#          },
#
#          {
#              "@context": "http://schema.org",
#
#              "@type": "Accommodation",
#
#              "name": "2 Bedroom",
#              "potentialAction": {
#                  "@type": "RentAction",
#                  "priceSpecification": {
#                      "@type": "PriceSpecification",
#                      "price": 3847.00,
#                      "priceCurrency": "CAD"
#                  }
#              },
#
#              "numberOfRooms": 2
#          },
#
#          {
#              "@context": "http://schema.org",
#
#              "@type": "Accommodation",
#
#              "name": "2 Bedroom",
#              "potentialAction": {
#                  "@type": "RentAction",
#                  "priceSpecification": {
#                      "@type": "PriceSpecification",
#                      "price": 4998.25,
#                      "priceCurrency": "CAD"
#                  }
#              },
#
#              "numberOfRooms": 2
#          }
#
#      ],
#      "address": {
#          "@type" : "PostalAddress",
#          "addressCountry" : "CA",
#          "addressLocality" : "Toronto",
#          "addressRegion" : "Ontario",
#          "postalCode" : "M4P 1P9",
#          "streetAddress" : "15 Roehampton Ave"
#      },
#      "telephone" :  "",
#      "photo" : [
#
#
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/db8ecb3ae4b90ec01cf797336ec7f204_352x198.jpg",
#              "image": "https://cdn2.torontorentals.com/photos/large/db8ecb3ae4b90ec01cf797336ec7f204.jpg"
#          },
#
#
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/f479edd8a140f0c8322b511b2c348ed6_352x198.jpg",
#              "image": "https://cdn2.torontorentals.com/photos/large/f479edd8a140f0c8322b511b2c348ed6.jpg"
#          },
#
#
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/129e1961e515396ba2adccb51304839a_352x198.jpg",
#              "image": "https://cdn2.torontorentals.com/photos/large/129e1961e515396ba2adccb51304839a.jpg"
#          },
#
#
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/03a32985bf669c9ffbadd2ad90a18d8a_352x198.jpg",
#              "image": "https://cdn2.torontorentals.com/photos/large/03a32985bf669c9ffbadd2ad90a18d8a.jpg"
#          },
#
#
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/7b7648a4314d97445b2bd92933d73890_352x198.jpg",
#              "image": "https://cdn2.torontorentals.com/photos/large/7b7648a4314d97445b2bd92933d73890.jpg"
#          },
#
#
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/5def987fdfc980e8854ce526b37dc123_352x198.jpg",
#              "image": "https://cdn2.torontorentals.com/photos/large/5def987fdfc980e8854ce526b37dc123.jpg"
#          },
#
#
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/bb16ab6b61d125cbdd6298fdf0f6c720_352x198.jpg",
#              "image": "https://cdn2.torontorentals.com/photos/large/bb16ab6b61d125cbdd6298fdf0f6c720.jpg"
#          },
#
#
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/f7f57bc4d8a6f63a4ffca379011f5eef_352x198.jpg",
#              "image": "https://cdn2.torontorentals.com/photos/large/f7f57bc4d8a6f63a4ffca379011f5eef.jpg"
#          },
#
#
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/ee2d714ff982bd7ec78fb98e268afe5c_352x198.jpg",
#              "image": "https://cdn2.torontorentals.com/photos/large/ee2d714ff982bd7ec78fb98e268afe5c.jpg"
#          },
#
#
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/9629fe1a7d04e09d450cfd410b4e942d_352x198.jpg",
#              "image": "https://cdn2.torontorentals.com/photos/large/9629fe1a7d04e09d450cfd410b4e942d.jpg"
#          },
#
#
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/ed2d7e950946909c6607715816a79435_352x198.jpg",
#              "image": "https://cdn2.torontorentals.com/photos/large/ed2d7e950946909c6607715816a79435.jpg"
#          },
#
#
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/3ac749640f23a5ff19380a4b773aa727_352x198.jpg",
#              "image": "https://cdn2.torontorentals.com/photos/large/3ac749640f23a5ff19380a4b773aa727.jpg"
#          },
#
#
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/71c21b85cd19c9e4d88ab4a8c260f00d_352x198.jpg",
#              "image": "https://cdn2.torontorentals.com/photos/large/71c21b85cd19c9e4d88ab4a8c260f00d.jpg"
#          },
#
#
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/ce46dd4fc9df91738aac2b931dce76c5_352x198.jpg",
#              "image": "https://cdn2.torontorentals.com/photos/large/ce46dd4fc9df91738aac2b931dce76c5.jpg"
#          },
#
#
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/50837a629a7cdd6ddf800b3872ce6772_352x198.jpg",
#              "image": "https://cdn2.torontorentals.com/photos/large/50837a629a7cdd6ddf800b3872ce6772.jpg"
#          },
#
#
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/6bbb2f71e15bb2fe19a18fa49705e9ac_352x198.jpg",
#              "image": "https://cdn2.torontorentals.com/photos/large/6bbb2f71e15bb2fe19a18fa49705e9ac.jpg"
#          },
#
#
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/25bcc77fec56fee7c631bf6113e1a180_352x198.jpg",
#              "image": "https://cdn2.torontorentals.com/photos/large/25bcc77fec56fee7c631bf6113e1a180.jpg"
#          },
#
#
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/88db4ec64b23613300510a39ec71ec1a_352x198.jpg",
#              "image": "https://cdn2.torontorentals.com/photos/large/88db4ec64b23613300510a39ec71ec1a.jpg"
#          }
#
#      ]
#  }
# </script>
# <script type="application/ld+json">
#  {
#      "@context": "http://schema.org",
#
#      "@type": "ApartmentComplex",
#
#
#      "url": "https://www.torontorentals.com/north-york/bayview-towers-id426",
#      "name": "Bayview Towers",
#      "description": "_Units starting from listed price_ Amenities & Features of Apartments --- * 505 Cummer Ave. in the prestigious area of Bayview & Finch * Beautiful entrance and friendly staff make Shickedanz Bros. Properties a superior living experience * Our cozy lobby area welcomes you home * Residents appreciate a sense of community at Schickedanz Bros. Properties. A book exchange is available in the brightly lit laundry facilities on site * Our large outdoor swimming pool offers hours of fun in the sun * Beautiful Ruddington park offers tennis courts for the young at heart * Minutes to Hwy 401, 404, 407 and the D.V.P. 7 minute busride to Finch subway",
#      "geo": {
#          "@type": "GeoCoordinates",
#          "latitude": 43.792349,
#          "longitude": -79.393537
#      },
#      "containedInPlace": {
#          "@type": "City",
#          "url": "https://www.torontorentals.com/north-york",
#          "name" : "North York",
#          "address": {
#              "@type": "PostalAddress",
#              "addressCountry" : "CA",
#              "addressRegion" : "Ontario"
#          }
#      },
#      "containsPlace": [
#
#          {
#              "@context": "http://schema.org",
#
#              "@type": "Apartment",
#
#              "name": "1 bedroom",
#              "potentialAction": {
#                  "@type": "RentAction",
#                  "priceSpecification": {
#                      "@type": "PriceSpecification",
#                      "price": 1647.00,
#                      "priceCurrency": "CAD"
#                  }
#              },
#
#              "numberOfRooms": 1
#          },
#
#          {
#              "@context": "http://schema.org",
#
#              "@type": "Apartment",
#
#              "name": "2 bedroom",
#              "potentialAction": {
#                  "@type": "RentAction",
#                  "priceSpecification": {
#                      "@type": "PriceSpecification",
#                      "price": 1927.00,
#                      "priceCurrency": "CAD"
#                  }
#              },
#
#              "numberOfRooms": 2
#          },
#
#          {
#              "@context": "http://schema.org",
#
#              "@type": "Apartment",
#
#              "name": "3 bedroom",
#              "potentialAction": {
#                  "@type": "RentAction",
#                  "priceSpecification": {
#                      "@type": "PriceSpecification",
#                      "price": 2227.00,
#                      "priceCurrency": "CAD"
#                  }
#              },
#
#              "numberOfRooms": 3
#          }
#
#      ],
#      "address": {
#          "@type" : "PostalAddress",
#          "addressCountry" : "CA",
#          "addressLocality" : "North York",
#          "addressRegion" : "Ontario",
#          "postalCode" : "M2K 2L8",
#          "streetAddress" : "505 Cummer Ave"
#      },
#      "telephone" :  "",
#      "photo" : [
#
#
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/7a3d6a17-0c8b-4e44-a19c-678d7ac50569_352x198.jpg",
#              "image": "https://cdn2.torontorentals.com/photos/large/7a3d6a17-0c8b-4e44-a19c-678d7ac50569.jpg"
#          },
#
#
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/3c5d8fcc-d94f-4597-94ab-9a52972756cb_352x198.jpg",
#              "image": "https://cdn2.torontorentals.com/photos/large/3c5d8fcc-d94f-4597-94ab-9a52972756cb.jpg"
#          },
#
#
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/cdf5a1a1-b9db-47f7-ae49-1f76761e244f_352x198.jpg",
#              "image": "https://cdn2.torontorentals.com/photos/large/cdf5a1a1-b9db-47f7-ae49-1f76761e244f.jpg"
#          },
#
#
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/abf18ad3-671d-45d3-9310-a665a7e1935a_352x198.jpg",
#              "image": "https://cdn2.torontorentals.com/photos/large/abf18ad3-671d-45d3-9310-a665a7e1935a.jpg"
#          },
#
#
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/b5f588f5-0d6b-41fc-9dbc-77c21dd07d81_352x198.jpg",
#              "image": "https://cdn2.torontorentals.com/photos/large/b5f588f5-0d6b-41fc-9dbc-77c21dd07d81.jpg"
#          },
#
#
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/075216ba-a2da-4181-b910-fb956824048c_352x198.jpg",
#              "image": "https://cdn2.torontorentals.com/photos/large/075216ba-a2da-4181-b910-fb956824048c.jpg"
#          },
#
#
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/548aa59b-7822-4780-a625-06ac48254893_352x198.jpg",
#              "image": "https://cdn2.torontorentals.com/photos/large/548aa59b-7822-4780-a625-06ac48254893.jpg"
#          },
#
#
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/e7d86c65-6688-4603-84e8-cda464b3a176_352x198.jpg",
#              "image": "https://cdn2.torontorentals.com/photos/large/e7d86c65-6688-4603-84e8-cda464b3a176.jpg"
#          },
#
#
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/03faabf7-16a9-4eaa-b314-2f46f33ddafb_352x198.jpg",
#              "image": "https://cdn2.torontorentals.com/photos/large/03faabf7-16a9-4eaa-b314-2f46f33ddafb.jpg"
#          },
#
#
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/manage-upload-admintorontorentals.com-VMfwU2_352x198.png",
#              "image": "https://cdn2.torontorentals.com/photos/large/manage-upload-admintorontorentals.com-VMfwU2.png"
#          }
#
#      ]
#  }
# </script>
# <script type="application/ld+json">
#  {
#      "@context": "http://schema.org",
#
#      "@type": "Accommodation",
#
#
#      "url": "https://www.torontorentals.com/toronto/kings-club-id60237",
#      "name": "Kings Club",
#      "description": "Visit our Website: <https://www.caprent.com/apartments-for-rent/toronto-on /kings-club/> **Why Pay Double?** Pay One Month and Move In* **Rental Office is located in the Kings Club Building at 1100 King Street West 4th Floor** ****Experience serious living without the investment - Kings Club is a new purpose-built rental building that offers all the amenities of a condo without the commitment of a mortgage. Located in the heart of Liberty Village, Kings Club offers beautiful downtown Toronto apartments for rent with stainless steel appliances, in-suite laundry, and building amenities like a rooftop infinity pool, yoga room and fitness centre. Aside from the opportunity to rent a brand new bachelor, 1 bedroom, 1 + den, 2 bedroom, 2 +den and 3 bedroom suites, Kings Club residents can easily access three floors of on-site retailers including Shoppers Drug Mart, Longos, Canadian Tire and Kids N Co to name a few. * 2 + Den units are over 1,000 square feet Parking from: $175.00 Have Questions? Contact the Property Manager: (416) 306-3051 Building Features **Apartment Features** * Stainless steel fridge, stove, dishwasher, microwave hood range, washer and dryer * Two-toned kitchen cabinets with under-mount lighting * Subway tiled glass backsplash for easy clean up * Two-toned kitchen islands in most suites * Track lighting in kitchen * Quartz counter tops * Contemporary ceramic flooring in bathroom * Large medicine cabinet in bathroom * Some suites with glass showers * Rich laminate flooring * Smooth finished 9 to 9 \u00bd foot ceilings * Pot lights throughout * Floor to ceiling windows complete with premium window coverings * Wheelchair accessible suites available **Amenity Features in the building** * Stunning rooftop patio complete with BBQ's and lounge seating * Rooftop infinity pool with breath taking views * Convenient parcel service * Concierge onsite * 24 security desk * Yoga studio * Fitness centre * Games room * Large business centre complete with boardroom * Kids Zone * 2 levels of resident parking * Visitor parking underground * Lockers in 2 different sizes * Bicycle storage * WI-FI available in all common areas * Surround sound in games room, boardroom and fitness centre **Retailers in the building** * Longo's * Canadian Tire * Shoppers Drug Mart * Winners * Kids & Company * McDonald\u2019s * Petsmart Neighbourhood Features * Quickly becoming one of Toronto's most up-and-coming neighbourhoods, Liberty Village's industrial-meets-urban style offers a variety of amenities, from trendy coffee shops to elevated dining to popular shops inside the Liberty Market Building. * With easy access to the 504 King streetcar and the Gardiner Expressway, Liberty Village serves as an urban epi-centre of Toronto's west end. * Kings Club residents never experience a dull moment in Liberty Village, with BMO Field, Lamport Stadium, Ontario Place, Exhibition Place and Lake Ontario just minutes away. * Check out popular Toronto offerings all year round like Toronto Fashion Week, TIFF, North by Northeast, Toronto Pride and Caribana.",
#      "geo": {
#          "@type": "GeoCoordinates",
#          "latitude": 43.63985,
#          "longitude": -79.42373
#      },
#      "containedInPlace": {
#          "@type": "City",
#          "url": "https://www.torontorentals.com/toronto",
#          "name" : "Toronto",
#          "address": {
#              "@type": "PostalAddress",
#              "addressCountry" : "CA",
#              "addressRegion" : "Ontario"
#          }
#      },
#      "containsPlace": [
#
#          {
#              "@context": "http://schema.org",
#
#              "@type": "Accommodation",
#
#              "name": "1 Bedroom",
# ...
#         rent: [0, 0],
#        url: '/toronto/2283-eglinton-avenue-apartments-id2506',
#        city: {
#            'name': 'Toronto'
#        },
#        location: {
#            lat: 43.7305806,
#            lng: -79.2723281
#        }
#    });
#
#
#
#
#
#         markers.push({
#         id: '2493',
#         name: 'Stubbs Apartments',
#         street: '44 Stubbs Drive',
#         visible_street: '44 Stubbs Drive',
#         type: 'apartment',
#         rent: [2260.00, 2260.00],
#        url: '/north-york/stubbs-apartments-id2493',
#        city: {
#            'name': 'North York'
#        },
#        location: {
#            lat: 43.76135,
#            lng: -79.3630688
#        }
#    });
#
#
#
#
#
#         markers.push({
#         id: '2487',
#         name: 'Rathburn Apartments',
#         street: '2121 Rathburn Road East',
#         visible_street: '2121 Rathburn Road East',
#         type: 'apartment',
#         rent: [0, 0],
#        url: '/mississauga/rathburn-apartments-id2487',
#        city: {
#            'name': 'Mississauga'
#        },
#        location: {
#            lat: 43.6428202,
#            lng: -79.5932344
#        }
#    });
#
#
#
#
#
#         markers.push({
#         id: '2488',
#         name: 'Park Royal Village Apartments',
#         street: '2360 Bonner Road',
#         visible_street: '2360 Bonner Road',
#         type: 'apartment',
#         rent: [1385.00, 2155.00],
#        url: '/mississauga/park-royal-village-apartments-id2488',
#        city: {
#            'name': 'Mississauga'
#        },
#        location: {
#            lat: 43.5145567,
#            lng: -79.6481561
#        }
#    });
#
#
#
#
#
#         markers.push({
#         id: '2843',
#         name: 'Bloor Dixie Townhomes',
#         street: '3515-3516 Havenwood Drive',
#         visible_street: '3515-3516 Havenwood Drive',
#         type: 'apartment',
#         rent: [2625.00, 2625.00],
#        url: '/mississauga/bloor-dixie-townhomes-id2843',
#        city: {
#            'name': 'Mississauga'
#        },
#        location: {
#            lat: 43.6215133,
#            lng: -79.5945884
#        }
#    });
#
#
#
#
#
#         markers.push({
#         id: '2489',
#         name: 'Bloor and Havenwood Townhomes',
#         street: '1560 Bloor Street East',
#         visible_street: '1560 Bloor Street East',
#         type: 'apartment',
#         rent: [2320.00, 2625.00],
#        url: '/mississauga/bloor-and-havenwood-townhomes-id2489',
#        city: {
#            'name': 'Mississauga'
#        },
#        location: {
#            lat: 43.6200261,
#            lng: -79.59077
#        }
#    });
#
#
#
#
#
#         markers.push({
#         id: '2480',
#         name: 'Applewood Towers Apartments',
#         street: '1055 Bloor Street East',
#         visible_street: '1055 Bloor Street East',
#         type: 'apartment',
#         rent: [1780.00, 2225.00],
#        url: '/mississauga/applewood-towers-apartments-id2480',
#        city: {
#            'name': 'Mississauga'
#        },
#        location: {
#            lat: 43.6103589,
#            lng: -79.6018216
#        }
#    });
#
#
#
#
#
#         markers.push({
#         id: '2471',
#         name: 'West Park Village Townhomes',
#         street: '10 Blackfriar Avenue',
#         visible_street: '10 Blackfriar Avenue',
#         type: 'apartment',
#         rent: [0, 0],
#        url: '/etobicoke/west-park-village-townhomes-id2471',
#        city: {
#            'name': 'Etobicoke'
#        },
#        location: {
#            lat: 43.6941658,
#            lng: -79.5622045
#        }
#    });
#
#
#
#
#
#         markers.push({
#         id: '2470',
#         name: 'West Park Village Apartments',
#         street: '10 Blackfriar Avenue',
#         visible_street: '10 Blackfriar Avenue',
#         type: 'apartment',
#         rent: [2125.00, 2400.00],
#        url: '/etobicoke/west-park-village-apartments-id2470',
#        city: {
#            'name': 'Etobicoke'
#        },
#        location: {
#            lat: 43.6941658,
#            lng: -79.5622045
#        }
#    });
#
#
#
#
#
#         markers.push({
#         id: '2457',
#         name: 'Brampton Village Apartments',
#         street: '80 Orenda Court',
#         visible_street: '80 Orenda Court',
#         type: 'apartment',
#         rent: [1850.00, 1850.00],
#        url: '/brampton/brampton-village-apartments-id2457',
#        city: {
#            'name': 'Brampton'
#        },
#        location: {
#            lat: 43.6919068,
#            lng: -79.7483795
#        }
#    });
#
#
#
#
#
#         markers.push({
#         id: '2453',
#         name: 'Balmoral Townhomes',
#         street: 'Balmoral Drive',
#         visible_street: 'Balmoral Drive',
#         type: 'apartment',
#         rent: [0, 0],
#        url: '/brampton/balmoral-townhomes-id2453',
#        city: {
#            'name': 'Brampton'
#        },
#        location: {
#            lat: 43.71586,
#            lng: -79.7047533
#        }
#    });
#
#
#
#
#
#         markers.push({
#         id: '59759',
#         name: '',
#         street: '5 Valhalla Inn Rd',
#         visible_street: '5 Valhalla Inn Rd',
#         type: 'Condo',
#         rent: [1850.00, 1850.00],
#        url: '/etobicoke/5-valhalla-inn-rd-id59759',
#        city: {
#            'name': 'Etobicoke'
#        },
#        location: {
#            lat: 43.6413997,
#            lng: -79.5579567
#        }
#    });
#
#
#
#
#
#         markers.push({
#         id: '59943',
#         name: 'South Beach Condo',
#         street: '88 Park Lawn Rd | Unit: 1715',
#         visible_street: '88 Park Lawn Rd | Unit: 1715',
#         type: 'Condo',
#         rent: [2195.00, 2195.00],
#        url: '/etobicoke/south-beach-condo-id59943',
#        city: {
#            'name': 'Etobicoke'
#        },
#        location: {
#            lat: 43.6240747,
#            lng: -79.4849171
#        }
#    });
#
#
#
#
#
#         markers.push({
#         id: '59672',
#         name: '',
#         street: 'Sherway Gardens Rd',
#         visible_street: 'Sherway Gardens Rd',
#         type: 'Condo',
#         rent: [1875.00, 1875.00],
#        url: '/etobicoke/sherway-gardens-rd-id59672',
#        city: {
#            'name': 'Etobicoke'
#        },
#        location: {
#            lat: 43.6151746,
#            lng: -79.5522144
#        }
#    });
#
#
#
#
#
#         markers.push({
#         id: '59351',
#         name: '',
#         street: '244 Lumsden Ave',
#         visible_street: '244 Lumsden Ave',
#         type: 'House',
#         rent: [2499.00, 2499.00],
#        url: '/toronto/244-lumsden-ave-id59351',
#        city: {
#            'name': 'Toronto'
#        },
#        location: {
#            lat: 43.6934164,
#            lng: -79.3130743
#        }
#    });
#
#
#
#
#
#         markers.push({
#         id: '59880',
#         name: 'The Oasis - 1700 Eglinton Avenue East',
#         street: '1700 Eglinton Ave E | Unit: 205',
#         visible_street: '1700 Eglinton Ave E | Unit: 205',
#         type: 'Condo',
#         rent: [2300.00, 2300.00],
#        url: '/north-york/the-oasis-1700-eglinton-avenue-east-id59880',
#        city: {
#            'name': 'North York'
#        },
#        location: {
#            lat: 43.7265234,
#            lng: -79.3127988
#        }
#    });
#
#
#
#
#
#         markers.push({
#         id: '59848',
#         name: 'Library District',
#         street: '170 Fort York Blvd | Unit: n/a',
#         visible_street: '170 Fort York Blvd | Unit: n/a',
#         type: 'Condo',
#         rent: [2300.00, 2300.00],
#        url: '/toronto/library-district-id59848',
#        city: {
#            'name': 'Toronto'
#        },
#        location: {
#            lat: 43.6393466,
#            lng: -79.3997415
#        }
#    });
#
#
#
#
#
#         markers.push({
#         id: '59892',
#         name: 'Kensington Market Lofts',
#         street: '160 Baldwin St',
#         visible_street: '160 Baldwin St',
#         type: 'Apartment',
#         rent: [2750.00, 2750.00],
#        url: '/toronto/kensington-market-lofts-id59892',
#        city: {
#            'name': 'Toronto'
#        },
#        location: {
#            lat: 43.6552093,
#            lng: -79.3998674
#        }
#    });
#
#
#
#
#
#         markers.push({
#         id: '59628',
#         name: 'James Cooper Mansion',
#         street: '28 Linden St | Unit: 2801',
#         visible_street: '28 Linden St | Unit: 2801',
#         type: 'Condo',
#         rent: [2100.00, 2100.00],
#        url: '/toronto/james-cooper-mansion-id59628',
#        city: {
#            'name': 'Toronto'
#        },
#        location: {
#            lat: 43.670878,
#            lng: -79.3766958
#        }
#    });
#
#
#
#
#
#         markers.push({
#         id: '59675',
#         name: 'Upper Beaches Home',
#         street: '1822 Gerrard St E',
#         visible_street: 'Gerrard St E',
#         type: 'House',
#         rent: [3700.00, 3700.00],
#        url: '/toronto/upper-beaches-home-id59675',
#        city: {
#            'name': 'Toronto'
#        },
#        location: {
#            lat: 43.6786613,
#            lng: -79.3144809
#        }
#    });
#
#
#
#
#
#         markers.push({
#         id: '59853',
#         name: '',
#         street: '166 Worthington Ave',
#         visible_street: 'Worthington Ave',
#         type: 'Basement',
#         rent: [1950.00, 1950.00],
#        url: '/richmond-hill/worthington-ave-id59853',
#        city: {
#            'name': 'Richmond Hill'
#        },
#        location: {
#            lat: 43.9571367,
#            lng: -79.4419636
#        }
#    });
#
#
#
#
#
#         markers.push({
#         id: '59625',
#         name: 'Golnoosh Pourshahid',
#         street: '11 Brunel Ct | Unit: 2203',
#         visible_street: '11 Brunel Ct | Unit: 2203',
#         type: 'Condo',
#         rent: [2200.00, 2200.00],
#        url: '/toronto/golnoosh-pourshahid-id59625',
#        city: {
#            'name': 'Toronto'
#        },
#        location: {
#            lat: 43.6394055,
#            lng: -79.3932324
#        }
#    });
#
#
#
#
#
#         markers.push({
#         id: '59750',
#         name: 'Northern Dancer',
#         street: '1733 Queen St E | Unit: 514',
#         visible_street: '1733 Queen St E | Unit: 514',
#         type: 'Condo',
#         rent: [1875.00, 1875.00],
#        url: '/toronto/northern-dancer-id59750',
#        city: {
#            'name': 'Toronto'
#        },
#        location: {
#            lat: 43.6672988,
#            lng: -79.3109055
#        }
#    });
#
#
#
#
#
#         markers.push({
#         id: '59748',
#         name: '38 Avenue Rd.',
#         street: '38 Avenue Rd | Unit: suite 205',
#         visible_street: '38 Avenue Rd | Unit: suite 205',
#         type: 'Condo',
#         rent: [4250.00, 4250.00],
#        url: '/toronto/38-avenue-rd-id59748',
#        city: {
#            'name': 'Toronto'
#        },
#        location: {
#            lat: 43.6703971,
#            lng: -79.3950228
#        }
#    });
#
#
#
#
#
#         markers.push({
#         id: '59704',
#         name: 'Aqualina Bayside Condo',
#         street: '15 Sellers Ave',
#         visible_street: '15 Sellers Ave',
#         type: 'Condo',
#         rent: [3300.00, 3300.00],
#        url: '/toronto/aqualina-bayside-condo-id59704',
#        city: {
#            'name': 'Toronto'
#        },
#        location: {
#            lat: 43.6815468,
#            lng: -79.4453711
#        }
#    });
#
#
#
#
#
#         markers.push({
#         id: '59622',
#         name: 'World Trade Center',
#         street: '10 Yonge St | Unit: 302',
#         visible_street: '10 Yonge St | Unit: 302',
#         type: 'Condo',
#         rent: [3300.00, 3300.00],
#        url: '/toronto/world-trade-center-id59622',
#        city: {
#            'name': 'Toronto'
#        },
#        location: {
#            lat: 43.6421529,
#            lng: -79.3756671
#        }
#    });
#
#
#
#
#
#         markers.push({
#         id: '59547',
#         name: 'the code',
#         street: '6 Parkwood Ave',
#         visible_street: '6 Parkwood Ave',
#         type: 'Condo',
#         rent: [3700.00, 3700.00],
#        url: '/toronto/the-code-id59547',
#        city: {
#            'name': 'Toronto'
#        },
#        location: {
#            lat: 43.6852419,
#            lng: -79.409829
#        }
#    });
#
#
#
#
#
#         markers.push({
#         id: '59524',
#         name: 'This is a test for reactivation',
#         street: '270 Queen St W | Unit: 1a',
#         visible_street: 'Queen St W | Unit: 1a',
#         type: 'Condo',
#         rent: [2700.00, 2700.00],
#        url: '/toronto/this-is-a-test-for-reactivation-id59524',
#        city: {
#            'name': 'Toronto'
#        },
#        location: {
#            lat: 43.6498807,
#            lng: -79.3919814
#        }
#    });
#
#
#
#    var activeListing = null;
#
#
#    $(document).ready(trcom.searchresults.init({
#        markerIcons: {
#            seen: '/static/torontorentalscom/img/marker_grey_.af18f2b97164.svg',
#            active: '/static/torontorentalscom/img/marker_lightblue.6c9b0aa0a887.svg',
#            standard: '/static/torontorentalscom/img/marker_blue_.7816d6042b3b.svg'
#        },
#        activeListing: activeListing,
#        citySlug: 'toronto',
#        center: {
#
#            // there's a city active
#            lat: 43.70011,
#            lng: -79.4163
#
#        },
#        markers: markers,
#        urls: {
#            searchListings: '/api/v4/search_listings',
#            supportSearch: '/api/v5/support-search'
#        }
#    }));
#   </script>
# <div class="hidden marker-popup-wrapper">
# <div class="marker-popup">
# <h4><a class="street replace url" href="" target="_blank"></a></h4>
# <span class="distance"><strong></strong> from Campus</span>
# <span class="type"></span>
# <div class="marker-popup-bottom">
# <span class="rent"></span>
# <a class="replace url see-details" href="" target="_blank">
# View Details
# </a>
# </div>
# </div>
# </div>
# <div class="modal fade" id="modal-contact" role="dialog" tabindex="-1">
# <div class="modal-dialog" role="document">
# <div class="modal-content">
# <form action="" class="material" method="post">
# <input name="csrfmiddlewaretoken" type="hidden" value="2FbkilPr48SjJFgjrdlg49z8hIIbA6gkvrwj1ZbNipR8rqf2IazS5XeAyKHZzKnl">
# <div class="modal-header">
# <h5 class="modal-title">
# Send Message to:
# <span class="modal-subtitle">
# -
# </span>
# </h5>
# <button aria-label="Close" class="close" data-dismiss="modal" type="button">
# <span aria-hidden="true">×</span>
# </button>
# </div>
# <div class="modal-body row-as-line">
# <div class="listing-phone-click-to-reveal" data-listing-id="">
# <div class="listing-phone-click-to-reveal__activate">
# <a href="#">
# <i aria-hidden="true" class="fa fa-phone"></i>
# View Phone Number
# </a>
# </div>
# <div class="listing-phone-click-to-reveal__content">
# Contact @ <a href="tel:"></a>
# </div>
# </div>
# <div class="row">
# <div class="col-12">
# <div class="form-group">
# <input class="form-control" id="contact-name" name="name" required="" type="text"/>
# <label for="contact-name">Your Name*</label>
# </div>
# </div>
# </div>
# <div class="row">
# <div class="col-12">
# <div class="form-group select-wrapper">
# <select class="form-control" name="unit_id">
# </select>
# <label for="unit_id">Unit</label>
# </div>
# </div>
# </div>
# <div class="row">
# <div class="col-6">
# <div class="form-group">
# <input class="form-control" id="contact-email" name="email" type="email"/>
# <label for="contact-email">Email</label>
# </div>
# </div>
# <div class="col-6">
# <div class="form-group">
# <input class="form-control" id="contact-phone" name="phone" type="tel"/>
# <label for="contact-phone">Phone</label>
# </div>
# </div>
# </div>
# <div class="row">
# <div class="col-12">
# <textarea class="form-control" name="message">I would like to schedule a time to view your listing. Please let me know when the best time would be.
# Thank you!</textarea>
# </div>
# </div>
# <div class="modal-alert alert"></div>
# <div class="row mb-0 text-right">
# <div class="col-12">
# <button class="btn btn-primary" type="submit">Send</button>
# </div>
# </div>
# </div>
# </input></form>
# </div>
# </div>
# </div>

# %%
script_dump = soap1.find_all("script")

# %%
test1 = script_dump[5]
test2 = BeautifulSoup(test1.text,"html.parser")
newDictionary=json.loads(str(test2))
newDictionary['url']
# Out:
# 'https://www.torontorentals.com/north-york/bayview-towers-id426'

# %%
latitude = newDictionary['geo']['latitude']

# %%
longitude = newDictionary['geo']['longitude']
print(longitude)
print(latitude)
Locality = newDictionary['address']['addressLocality']
Region = newDictionary['address']['addressRegion']
PostalCode = newDictionary['address']['postalCode']
StreetAddress = newDictionary['address']['streetAddress']
print(Locality, Region, PostalCode, StreetAddress)
# Out:
# -79.393537
# 43.792349
# North York Ontario M2K 2L8 505 Cummer Ave

# %%
NameofApartment = newDictionary['name']
print(NameofApartment)
typeofApartment = newDictionary['@type']
print(typeofApartment)
# Out:
# Bayview Towers
# ApartmentComplex

# %%
price = newDictionary['containsPlace'][0]['potentialAction']['priceSpecification']['price']
# Out:
# 3

# %%
script_dump[3:-6]
# Out:
# [<script type="application/ld+json">
#   {
#       "@context": "http://schema.org",
#
#       "@type": "Accommodation",
#
#
#       "url": "https://www.torontorentals.com/etobicoke/571-prince-edward-dr-n-id69764",
#       "name": "571 Prince Edward Dr N",
#       "description": "Dunpar has always sought to build projects in areas rich in existing amenities, and our newest project, Kingsway Village Square on Prince Edward, is no exception. Kingsway Village Square is a mid-rise Manhattan-style building, situated at 571 Prince Edward Drive North, just moments away from the quaint shops and restaurants of Bloor West Village. Steps away from libraries, gyms, food shops and highly ranked local schools. High Park, Royal York and the Old Mill subway stations are within walking distance. Upscale shopping is a short drive away to Sherway Gardens. **Site includes a 24/7 Concierge.** **Open House Dates: Open 7 Days a Week 11AM-7PM**",
#       "geo": {
#           "@type": "GeoCoordinates",
#           "latitude": 43.6602184,
#           "longitude": -79.5100634
#       },
#       "containedInPlace": {
#           "@type": "City",
#           "url": "https://www.torontorentals.com/etobicoke",
#           "name" : "Etobicoke",
#           "address": {
#               "@type": "PostalAddress",
#               "addressCountry" : "CA",
#               "addressRegion" : "Ontario"
#           }
#       },
#       "containsPlace": [
#
#           {
#               "@context": "http://schema.org",
#
#               "@type": "Accommodation",
#
#               "name": "1 bedroom",
#               "potentialAction": {
#                   "@type": "RentAction",
#                   "priceSpecification": {
#                       "@type": "PriceSpecification",
#                       "price": 2000.00,
#                       "priceCurrency": "CAD"
#                   }
#               },
#
#               "numberOfRooms": 1
#           },
#
#           {
#               "@context": "http://schema.org",
#
#               "@type": "Accommodation",
#
#               "name": "1 bedroom",
#               "potentialAction": {
#                   "@type": "RentAction",
#                   "priceSpecification": {
#                       "@type": "PriceSpecification",
#                       "price": 2300.00,
#                       "priceCurrency": "CAD"
#                   }
#               },
#
#               "numberOfRooms": 1
#           },
#
#           {
#               "@context": "http://schema.org",
#
#               "@type": "Accommodation",
#
#               "name": "2 bedroom",
#               "potentialAction": {
#                   "@type": "RentAction",
#                   "priceSpecification": {
#                       "@type": "PriceSpecification",
#                       "price": 2700.00,
#                       "priceCurrency": "CAD"
#                   }
#               },
#
#               "numberOfRooms": 2
#           },
#
#           {
#               "@context": "http://schema.org",
#
#               "@type": "Accommodation",
#
#               "name": "2 bedroom",
#               "potentialAction": {
#                   "@type": "RentAction",
#                   "priceSpecification": {
#                       "@type": "PriceSpecification",
#                       "price": 3850.00,
#                       "priceCurrency": "CAD"
#                   }
#               },
#
#               "numberOfRooms": 2
#           }
#
#       ],
#       "address": {
#           "@type" : "PostalAddress",
#           "addressCountry" : "CA",
#           "addressLocality" : "Etobicoke",
#           "addressRegion" : "Ontario",
#           "postalCode" : "M8X 0A1",
#           "streetAddress" : "571 Prince Edward Dr N"
#       },
#       "telephone" :  "",
#       "photo" : [
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/manage-upload-rentalinfodmsproperty.com-nLADo9_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/manage-upload-rentalinfodmsproperty.com-nLADo9.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/manage-upload-rentalinfodmsproperty.com-gvhPyY_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/manage-upload-rentalinfodmsproperty.com-gvhPyY.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/manage-upload-rentalinfodmsproperty.com-wtKonJ_352x198.png",
#               "image": "https://cdn2.torontorentals.com/photos/large/manage-upload-rentalinfodmsproperty.com-wtKonJ.png"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/manage-upload-rentalinfodmsproperty.com-2qQ5Ln_352x198.png",
#               "image": "https://cdn2.torontorentals.com/photos/large/manage-upload-rentalinfodmsproperty.com-2qQ5Ln.png"
#           }
#
#       ]
#   }
#  </script>,
#  <script type="application/ld+json">
#   {
#       "@context": "http://schema.org",
#
#       "@type": "Accommodation",
#
#
#       "url": "https://www.torontorentals.com/toronto/ecentral-id64432",
#       "name": "eCentral",
#       "description": "**MOVE IN TODAY AND RECEIVE 1 MONTH FREE RENT ON SELECT SUITES!** Terms and Conditions Apply. Contact us to book a tour and discuss the details! **Now Renting 1 and 2 Bedroom Suites, and 2 Bedroom Penthouses and Townhomes. Limited suites are available.** Schedule a tour today to view our designer model suites and community amenities. Visit our leasing centre at 15 Roehampton Avenue \u2013 open 7 days a week. It's all about proximity. It's life at the centre of it all. It's taking advantage of the numerous transit options and easily getting from point A to point B. Or it's staying home and availing yourself of the reimagined retail and entertainment of Toronto's newest place to be \u2013 Yonge and Eglinton. At eCentral the world is at your doorstep. It's why your living room looks better and why your weekends sound better. It's why you seize every opportunity, because you can, and because the day won't live itself. *Pricing subject to change based on real-time availability. For all floorplans and pricing, visit [www.ecentralliving.com/rental-suites](http://www.ecentralliving.com/rental-suites) or contact us for more details. **Suite photos advertised are of a model suite and are not representative of all suites available for rent **Office Hours** Monday \u2013 Friday 10AM \u2013 7PM Saturday \u2013 Sunday 10AM - 5PM Professional property management and resident services by Rhapsody Property Management Services **Community Amenities** * 4200 sq.ft. Rooftop Fitness Centre * Yoga and Spin Studio * Spa Treatment Room * Private Study Lounge * Two Party Rooms with Kitchens * Rooftop Lounge with Outdoor Fireplace * BBQs with Dining Area * Lounge with Wet Bar * Dining Room * Games Room * Library * Dog Wash * Pet-Friendly Community * Professional Managed by Rhapsody Property Management Services * Future Underground Access to Eglinton TTC station, ePlace, and the Future Eglinton Crosstown LRT* * Concierge Services * Guest Suites * Single Fob Keyless Access into Building and Suites * Secured Underground Parking * Bike Storage * Storage Lockers * Parcel Pending Package Management System * After-Hours Security * Resident Portal * Amenity Booking System * Online Rent Payment System * Visitor Parking On-Site ($) **Suite Amenities** * Offering studio, 1 & 2 bedroom suites, 2 bedroom penthouses, and 2 bedroom townhomes * 4 Piece Stainless Steel Kitchen Appliances * In-suite Washer and Dryer * Quartz Countertops * High Ceilings * Private Balcony and Patio **Location Details** eCentral is located next to three storeys of retail in ePlace and across the street from one of Toronto's busiest midtown shopping destinations \u2013 RioCan's newly renovated and revitalized Yonge Eglinton Centre.",
#       "geo": {
#           "@type": "GeoCoordinates",
#           "latitude": 43.7079426,
#           "longitude": -79.3978607
#       },
#       "containedInPlace": {
#           "@type": "City",
#           "url": "https://www.torontorentals.com/toronto",
#           "name" : "Toronto",
#           "address": {
#               "@type": "PostalAddress",
#               "addressCountry" : "CA",
#               "addressRegion" : "Ontario"
#           }
#       },
#       "containsPlace": [
#
#           {
#               "@context": "http://schema.org",
#
#               "@type": "Accommodation",
#
#               "name": "Studio",
#               "potentialAction": {
#                   "@type": "RentAction",
#                   "priceSpecification": {
#                       "@type": "PriceSpecification",
#                       "price": 2002.50,
#                       "priceCurrency": "CAD"
#                   }
#               },
#
#               "numberOfRooms": 0
#           },
#
#           {
#               "@context": "http://schema.org",
#
#               "@type": "Accommodation",
#
#               "name": "1 Bedroom",
#               "potentialAction": {
#                   "@type": "RentAction",
#                   "priceSpecification": {
#                       "@type": "PriceSpecification",
#                       "price": 2248.50,
#                       "priceCurrency": "CAD"
#                   }
#               },
#
#               "numberOfRooms": 1
#           },
#
#           {
#               "@context": "http://schema.org",
#
#               "@type": "Accommodation",
#
#               "name": "1 Bedroom",
#               "potentialAction": {
#                   "@type": "RentAction",
#                   "priceSpecification": {
#                       "@type": "PriceSpecification",
#                       "price": 2455.75,
#                       "priceCurrency": "CAD"
#                   }
#               },
#
#               "numberOfRooms": 1
#           },
#
#           {
#               "@context": "http://schema.org",
#
#               "@type": "Accommodation",
#
#               "name": "2 Bedroom Townhome",
#               "potentialAction": {
#                   "@type": "RentAction",
#                   "priceSpecification": {
#                       "@type": "PriceSpecification",
#                       "price": 3608.00,
#                       "priceCurrency": "CAD"
#                   }
#               },
#
#               "numberOfRooms": 2
#           },
#
#           {
#               "@context": "http://schema.org",
#
#               "@type": "Accommodation",
#
#               "name": "2 Bedroom",
#               "potentialAction": {
#                   "@type": "RentAction",
#                   "priceSpecification": {
#                       "@type": "PriceSpecification",
#                       "price": 3847.00,
#                       "priceCurrency": "CAD"
#                   }
#               },
#
#               "numberOfRooms": 2
#           },
#
#           {
#               "@context": "http://schema.org",
#
#               "@type": "Accommodation",
#
#               "name": "2 Bedroom",
#               "potentialAction": {
#                   "@type": "RentAction",
#                   "priceSpecification": {
#                       "@type": "PriceSpecification",
#                       "price": 4998.25,
#                       "priceCurrency": "CAD"
#                   }
#               },
#
#               "numberOfRooms": 2
#           }
#
#       ],
#       "address": {
#           "@type" : "PostalAddress",
#           "addressCountry" : "CA",
#           "addressLocality" : "Toronto",
#           "addressRegion" : "Ontario",
#           "postalCode" : "M4P 1P9",
#           "streetAddress" : "15 Roehampton Ave"
#       },
#       "telephone" :  "",
#       "photo" : [
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/db8ecb3ae4b90ec01cf797336ec7f204_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/db8ecb3ae4b90ec01cf797336ec7f204.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/f479edd8a140f0c8322b511b2c348ed6_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/f479edd8a140f0c8322b511b2c348ed6.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/129e1961e515396ba2adccb51304839a_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/129e1961e515396ba2adccb51304839a.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/03a32985bf669c9ffbadd2ad90a18d8a_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/03a32985bf669c9ffbadd2ad90a18d8a.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/7b7648a4314d97445b2bd92933d73890_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/7b7648a4314d97445b2bd92933d73890.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/5def987fdfc980e8854ce526b37dc123_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/5def987fdfc980e8854ce526b37dc123.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/bb16ab6b61d125cbdd6298fdf0f6c720_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/bb16ab6b61d125cbdd6298fdf0f6c720.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/f7f57bc4d8a6f63a4ffca379011f5eef_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/f7f57bc4d8a6f63a4ffca379011f5eef.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/ee2d714ff982bd7ec78fb98e268afe5c_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/ee2d714ff982bd7ec78fb98e268afe5c.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/9629fe1a7d04e09d450cfd410b4e942d_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/9629fe1a7d04e09d450cfd410b4e942d.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/ed2d7e950946909c6607715816a79435_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/ed2d7e950946909c6607715816a79435.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/3ac749640f23a5ff19380a4b773aa727_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/3ac749640f23a5ff19380a4b773aa727.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/71c21b85cd19c9e4d88ab4a8c260f00d_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/71c21b85cd19c9e4d88ab4a8c260f00d.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/ce46dd4fc9df91738aac2b931dce76c5_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/ce46dd4fc9df91738aac2b931dce76c5.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/50837a629a7cdd6ddf800b3872ce6772_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/50837a629a7cdd6ddf800b3872ce6772.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/6bbb2f71e15bb2fe19a18fa49705e9ac_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/6bbb2f71e15bb2fe19a18fa49705e9ac.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/25bcc77fec56fee7c631bf6113e1a180_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/25bcc77fec56fee7c631bf6113e1a180.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/88db4ec64b23613300510a39ec71ec1a_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/88db4ec64b23613300510a39ec71ec1a.jpg"
#           }
#
#       ]
#   }
#  </script>,
#  <script type="application/ld+json">
#   {
#       "@context": "http://schema.org",
#
#       "@type": "ApartmentComplex",
#
#
#       "url": "https://www.torontorentals.com/north-york/bayview-towers-id426",
#       "name": "Bayview Towers",
#       "description": "_Units starting from listed price_ Amenities & Features of Apartments --- * 505 Cummer Ave. in the prestigious area of Bayview & Finch * Beautiful entrance and friendly staff make Shickedanz Bros. Properties a superior living experience * Our cozy lobby area welcomes you home * Residents appreciate a sense of community at Schickedanz Bros. Properties. A book exchange is available in the brightly lit laundry facilities on site * Our large outdoor swimming pool offers hours of fun in the sun * Beautiful Ruddington park offers tennis courts for the young at heart * Minutes to Hwy 401, 404, 407 and the D.V.P. 7 minute busride to Finch subway",
#       "geo": {
#           "@type": "GeoCoordinates",
#           "latitude": 43.792349,
#           "longitude": -79.393537
#       },
#       "containedInPlace": {
#           "@type": "City",
#           "url": "https://www.torontorentals.com/north-york",
#           "name" : "North York",
#           "address": {
#               "@type": "PostalAddress",
#               "addressCountry" : "CA",
#               "addressRegion" : "Ontario"
#           }
#       },
#       "containsPlace": [
#
#           {
#               "@context": "http://schema.org",
#
#               "@type": "Apartment",
#
#               "name": "1 bedroom",
#               "potentialAction": {
#                   "@type": "RentAction",
#                   "priceSpecification": {
#                       "@type": "PriceSpecification",
#                       "price": 1647.00,
#                       "priceCurrency": "CAD"
#                   }
#               },
#
#               "numberOfRooms": 1
#           },
#
#           {
#               "@context": "http://schema.org",
#
#               "@type": "Apartment",
#
#               "name": "2 bedroom",
#               "potentialAction": {
#                   "@type": "RentAction",
#                   "priceSpecification": {
#                       "@type": "PriceSpecification",
#                       "price": 1927.00,
#                       "priceCurrency": "CAD"
#                   }
#               },
#
#               "numberOfRooms": 2
#           },
#
#           {
#               "@context": "http://schema.org",
#
#               "@type": "Apartment",
#
#               "name": "3 bedroom",
#               "potentialAction": {
#                   "@type": "RentAction",
#                   "priceSpecification": {
#                       "@type": "PriceSpecification",
#                       "price": 2227.00,
#                       "priceCurrency": "CAD"
#                   }
#               },
#
#               "numberOfRooms": 3
#           }
#
#       ],
#       "address": {
#           "@type" : "PostalAddress",
#           "addressCountry" : "CA",
#           "addressLocality" : "North York",
#           "addressRegion" : "Ontario",
#           "postalCode" : "M2K 2L8",
#           "streetAddress" : "505 Cummer Ave"
#       },
#       "telephone" :  "",
#       "photo" : [
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/7a3d6a17-0c8b-4e44-a19c-678d7ac50569_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/7a3d6a17-0c8b-4e44-a19c-678d7ac50569.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/3c5d8fcc-d94f-4597-94ab-9a52972756cb_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/3c5d8fcc-d94f-4597-94ab-9a52972756cb.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/cdf5a1a1-b9db-47f7-ae49-1f76761e244f_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/cdf5a1a1-b9db-47f7-ae49-1f76761e244f.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/abf18ad3-671d-45d3-9310-a665a7e1935a_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/abf18ad3-671d-45d3-9310-a665a7e1935a.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/b5f588f5-0d6b-41fc-9dbc-77c21dd07d81_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/b5f588f5-0d6b-41fc-9dbc-77c21dd07d81.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/075216ba-a2da-4181-b910-fb956824048c_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/075216ba-a2da-4181-b910-fb956824048c.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/548aa59b-7822-4780-a625-06ac48254893_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/548aa59b-7822-4780-a625-06ac48254893.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/e7d86c65-6688-4603-84e8-cda464b3a176_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/e7d86c65-6688-4603-84e8-cda464b3a176.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/03faabf7-16a9-4eaa-b314-2f46f33ddafb_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/03faabf7-16a9-4eaa-b314-2f46f33ddafb.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/manage-upload-admintorontorentals.com-VMfwU2_352x198.png",
#               "image": "https://cdn2.torontorentals.com/photos/large/manage-upload-admintorontorentals.com-VMfwU2.png"
#           }
#
#       ]
#   }
#  </script>,
#  <script type="application/ld+json">
#   {
#       "@context": "http://schema.org",
#
#       "@type": "Accommodation",
#
#
#       "url": "https://www.torontorentals.com/toronto/kings-club-id60237",
#       "name": "Kings Club",
#       "description": "Visit our Website: <https://www.caprent.com/apartments-for-rent/toronto-on /kings-club/> **Why Pay Double?** Pay One Month and Move In* **Rental Office is located in the Kings Club Building at 1100 King Street West 4th Floor** ****Experience serious living without the investment - Kings Club is a new purpose-built rental building that offers all the amenities of a condo without the commitment of a mortgage. Located in the heart of Liberty Village, Kings Club offers beautiful downtown Toronto apartments for rent with stainless steel appliances, in-suite laundry, and building amenities like a rooftop infinity pool, yoga room and fitness centre. Aside from the opportunity to rent a brand new bachelor, 1 bedroom, 1 + den, 2 bedroom, 2 +den and 3 bedroom suites, Kings Club residents can easily access three floors of on-site retailers including Shoppers Drug Mart, Longos, Canadian Tire and Kids N Co to name a few. * 2 + Den units are over 1,000 square feet Parking from: $175.00 Have Questions? Contact the Property Manager: (416) 306-3051 Building Features **Apartment Features** * Stainless steel fridge, stove, dishwasher, microwave hood range, washer and dryer * Two-toned kitchen cabinets with under-mount lighting * Subway tiled glass backsplash for easy clean up * Two-toned kitchen islands in most suites * Track lighting in kitchen * Quartz counter tops * Contemporary ceramic flooring in bathroom * Large medicine cabinet in bathroom * Some suites with glass showers * Rich laminate flooring * Smooth finished 9 to 9 \u00bd foot ceilings * Pot lights throughout * Floor to ceiling windows complete with premium window coverings * Wheelchair accessible suites available **Amenity Features in the building** * Stunning rooftop patio complete with BBQ's and lounge seating * Rooftop infinity pool with breath taking views * Convenient parcel service * Concierge onsite * 24 security desk * Yoga studio * Fitness centre * Games room * Large business centre complete with boardroom * Kids Zone * 2 levels of resident parking * Visitor parking underground * Lockers in 2 different sizes * Bicycle storage * WI-FI available in all common areas * Surround sound in games room, boardroom and fitness centre **Retailers in the building** * Longo's * Canadian Tire * Shoppers Drug Mart * Winners * Kids & Company * McDonald\u2019s * Petsmart Neighbourhood Features * Quickly becoming one of Toronto's most up-and-coming neighbourhoods, Liberty Village's industrial-meets-urban style offers a variety of amenities, from trendy coffee shops to elevated dining to popular shops inside the Liberty Market Building. * With easy access to the 504 King streetcar and the Gardiner Expressway, Liberty Village serves as an urban epi-centre of Toronto's west end. * Kings Club residents never experience a dull moment in Liberty Village, with BMO Field, Lamport Stadium, Ontario Place, Exhibition Place and Lake Ontario just minutes away. * Check out popular Toronto offerings all year round like Toronto Fashion Week, TIFF, North by Northeast, Toronto Pride and Caribana.",
#       "geo": {
#           "@type": "GeoCoordinates",
#           "latitude": 43.63985,
#           "longitude": -79.42373
#       },
#       "containedInPlace": {
#           "@type": "City",
#           "url": "https://www.torontorentals.com/toronto",
#           "name" : "Toronto",
#           "address": {
#               "@type": "PostalAddress",
#               "addressCountry" : "CA",
#               "addressRegion" : "Ontario"
#           }
#       },
#       "containsPlace": [
#
#           {
#               "@context": "http://schema.org",
#
#               "@type": "Accommodation",
#
#               "name": "1 Bedroom",
#               "potentialAction": {
#                   "@type": "RentAction",
#                   "priceSpecification": {
#                       "@type": "PriceSpecification",
#                       "price": 2150.00,
#                       "priceCurrency": "CAD"
#                   }
#               },
#
#               "numberOfRooms": 1
#           },
#
#           {
#               "@context": "http://schema.org",
#
#               "@type": "Accommodation",
#
#               "name": "1 Bedroom",
#               "potentialAction": {
#                   "@type": "RentAction",
#                   "priceSpecification": {
#                       "@type": "PriceSpecification",
#                       "price": 2170.00,
#                       "priceCurrency": "CAD"
#                   }
#               },
#
#               "numberOfRooms": 1
#           },
#
#           {
#               "@context": "http://schema.org",
#
#               "@type": "Accommodation",
#
#               "name": "2 Bedroom",
#               "potentialAction": {
#                   "@type": "RentAction",
#                   "priceSpecification": {
#                       "@type": "PriceSpecification",
#                       "price": 2480.00,
#                       "priceCurrency": "CAD"
#                   }
#               },
#
#               "numberOfRooms": 2
#           },
#
#           {
#               "@context": "http://schema.org",
#
#               "@type": "Accommodation",
#
#               "name": "2 Bedroom",
#               "potentialAction": {
#                   "@type": "RentAction",
#                   "priceSpecification": {
#                       "@type": "PriceSpecification",
#                       "price": 3635.00,
#                       "priceCurrency": "CAD"
#                   }
#               },
#
#               "numberOfRooms": 2
#           },
#
#           {
#               "@context": "http://schema.org",
#
#               "@type": "Accommodation",
#
#               "name": "3 Bedroom",
#               "potentialAction": {
#                   "@type": "RentAction",
#                   "priceSpecification": {
#                       "@type": "PriceSpecification",
#                       "price": 3815.00,
#                       "priceCurrency": "CAD"
#                   }
#               },
#
#               "numberOfRooms": 3
#           }
#
#       ],
#       "address": {
#           "@type" : "PostalAddress",
#           "addressCountry" : "CA",
#           "addressLocality" : "Toronto",
#           "addressRegion" : "Ontario",
#           "postalCode" : "M6K 0C6",
#           "streetAddress" : "1100 King Street West"
#       },
#       "telephone" :  "",
#       "photo" : [
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/aa214bc99104068d0a0477f1d2115a23_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/aa214bc99104068d0a0477f1d2115a23.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/d860fac512f07f367d6ecb0add1f1631_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/d860fac512f07f367d6ecb0add1f1631.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/1b01afcda1de2fb1d3fa39929f702ed8_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/1b01afcda1de2fb1d3fa39929f702ed8.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/925b10c73747fadfc0a82eb3c6cd86be_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/925b10c73747fadfc0a82eb3c6cd86be.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/fcb28022f877dfcfe51eba4ca0596a6c_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/fcb28022f877dfcfe51eba4ca0596a6c.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/3a45ff19f609a834b2a134bfcba5fdd0_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/3a45ff19f609a834b2a134bfcba5fdd0.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/72e815125edec438e725c02884728a52_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/72e815125edec438e725c02884728a52.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/bb55990947fe14aadb499b9ea08d31fd_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/bb55990947fe14aadb499b9ea08d31fd.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/d78b53aa19a26bf7319ac120c02cbce2_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/d78b53aa19a26bf7319ac120c02cbce2.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/a0b48fafeb930c719093241f964cd956_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/a0b48fafeb930c719093241f964cd956.jpg"
#           }
#
#       ]
#   }
#  </script>,
#  <script type="application/ld+json">
#   {
#       "@context": "http://schema.org",
#
#       "@type": "ApartmentComplex",
#
#
#       "url": "https://www.torontorentals.com/north-york/70-ruddington-drive-id447",
#       "name": "70 Ruddington Drive",
#       "description": "Amenities & Features of Apartments * 70 Ruddington Drive in the prestigious area of Bayview & Finch * Nestled in a quiet self contained area of Willowdale. * Live condo style in bright spotlessly clean suites with self controlled air conditioning, eat-in kitchens with dishwashers * Our cozy lobby welcomes you home * Enjoy the Card Room, our residents do * Residents appreciate a sense of community at Schickedanz Bros. Properties. A book exchange is available in the brightly lit laundry facilities on site * Superior green space adjacent to the property offers spacious parkland for your enjoyment * Tennis courts in Ruddington park are open for your use from early spring to late fall * Our large outdoor swimming pool offers hours of fun in the sun * Grocery, pharmacy, banks, restaurants & coffee shops as well as hair dressers, barbers and postal services are located in the Bayview/Cummer shopping centre adjacent to the property",
#       "geo": {
#           "@type": "GeoCoordinates",
#           "latitude": 43.792965,
#           "longitude": -79.391069
#       },
#       "containedInPlace": {
#           "@type": "City",
#           "url": "https://www.torontorentals.com/north-york",
#           "name" : "North York",
#           "address": {
#               "@type": "PostalAddress",
#               "addressCountry" : "CA",
#               "addressRegion" : "Ontario"
#           }
#       },
#       "containsPlace": [
#
#           {
#               "@context": "http://schema.org",
#
#               "@type": "Apartment",
#
#               "name": "1 bedroom",
#               "potentialAction": {
#                   "@type": "RentAction",
#                   "priceSpecification": {
#                       "@type": "PriceSpecification",
#                       "price": 1837.00,
#                       "priceCurrency": "CAD"
#                   }
#               },
#
#               "numberOfRooms": 1
#           },
#
#           {
#               "@context": "http://schema.org",
#
#               "@type": "Apartment",
#
#               "name": "2 bedroom",
#               "potentialAction": {
#                   "@type": "RentAction",
#                   "priceSpecification": {
#                       "@type": "PriceSpecification",
#                       "price": 2487.00,
#                       "priceCurrency": "CAD"
#                   }
#               },
#
#               "numberOfRooms": 2
#           }
#
#       ],
#       "address": {
#           "@type" : "PostalAddress",
#           "addressCountry" : "CA",
#           "addressLocality" : "North York",
#           "addressRegion" : "Ontario",
#           "postalCode" : "M2K 2X8",
#           "streetAddress" : "70 Ruddington Drive"
#       },
#       "telephone" :  "",
#       "photo" : [
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/80590da4-59de-4f7c-ae20-cfc51fddb7fa_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/80590da4-59de-4f7c-ae20-cfc51fddb7fa.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/f0d72054-495f-4caf-b191-695aaffd9499_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/f0d72054-495f-4caf-b191-695aaffd9499.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/bfc50fa9-3147-4be2-8bb9-a38dd1526f9a_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/bfc50fa9-3147-4be2-8bb9-a38dd1526f9a.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/225fb70c-0528-4e90-afd3-3ebf1dbfbd02_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/225fb70c-0528-4e90-afd3-3ebf1dbfbd02.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/79570231-1e96-48f8-bffa-5454cf2aa396_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/79570231-1e96-48f8-bffa-5454cf2aa396.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/d73d0a42-1585-4cee-b908-bc913513716c_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/d73d0a42-1585-4cee-b908-bc913513716c.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/239e09e8-a4c5-4101-a13f-54b7c6c20123_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/239e09e8-a4c5-4101-a13f-54b7c6c20123.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/bf281975-2292-42af-85a6-35e57be0d2d8_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/bf281975-2292-42af-85a6-35e57be0d2d8.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/289ae636-aaa0-4926-aafe-0dc84e202b2b_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/289ae636-aaa0-4926-aafe-0dc84e202b2b.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/bda50a00-6278-48fd-b9bf-8f9b5205db32_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/bda50a00-6278-48fd-b9bf-8f9b5205db32.jpg"
#           }
#
#       ]
#   }
#  </script>,
#  <script type="application/ld+json">
#   {
#       "@context": "http://schema.org",
#
#       "@type": "ApartmentComplex",
#
#
#       "url": "https://www.torontorentals.com/north-york/bayview-towers-id448",
#       "name": "Bayview Towers",
#       "description": "_Units starting from listed price_ Amenities & Features of Apartments --- * 50 Ruddington Drive is in the prestigious area of Bayview & Finch * Nestled in a quiet self contained area of Willowdale * Minutes to Hwy 404, 401, 407 and the D.V.P. 7 minute bus ride to Finch subway * Our beautiful lobby and friendly staff makes Schickedanz properties a superior living experience * Tennis courts for the young at heart * A playground for the children * Our large outdoor swimming pool offers hours of fun in the sun * Residents appreciate a sense of community at Schickedanz Bros. Properties * A book exchange is available in the brightly lit laundry facilities on site",
#       "geo": {
#           "@type": "GeoCoordinates",
#           "latitude": 43.790521,
#           "longitude": -79.388709
#       },
#       "containedInPlace": {
#           "@type": "City",
#           "url": "https://www.torontorentals.com/north-york",
#           "name" : "North York",
#           "address": {
#               "@type": "PostalAddress",
#               "addressCountry" : "CA",
#               "addressRegion" : "Ontario"
#           }
#       },
#       "containsPlace": [
#
#           {
#               "@context": "http://schema.org",
#
#               "@type": "Apartment",
#
#               "name": "1 bedroom",
#               "potentialAction": {
#                   "@type": "RentAction",
#                   "priceSpecification": {
#                       "@type": "PriceSpecification",
#                       "price": 1587.00,
#                       "priceCurrency": "CAD"
#                   }
#               },
#
#               "numberOfRooms": 1
#           },
#
#           {
#               "@context": "http://schema.org",
#
#               "@type": "Apartment",
#
#               "name": "2 bedroom",
#               "potentialAction": {
#                   "@type": "RentAction",
#                   "priceSpecification": {
#                       "@type": "PriceSpecification",
#                       "price": 1927.00,
#                       "priceCurrency": "CAD"
#                   }
#               },
#
#               "numberOfRooms": 2
#           },
#
#           {
#               "@context": "http://schema.org",
#
#               "@type": "Apartment",
#
#               "name": "3 bedroom",
#               "potentialAction": {
#                   "@type": "RentAction",
#                   "priceSpecification": {
#                       "@type": "PriceSpecification",
#                       "price": 2227.00,
#                       "priceCurrency": "CAD"
#                   }
#               },
#
#               "numberOfRooms": 3
#           }
#
#       ],
#       "address": {
#           "@type" : "PostalAddress",
#           "addressCountry" : "CA",
#           "addressLocality" : "North York",
#           "addressRegion" : "Ontario",
#           "postalCode" : "M2K 2J9",
#           "streetAddress" : "50 Ruddington Drive"
#       },
#       "telephone" :  "",
#       "photo" : [
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/6a315cba-183f-4858-8f82-8df09e575c51_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/6a315cba-183f-4858-8f82-8df09e575c51.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/5a25994a-a13e-4eef-a95f-7b825f3376f7_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/5a25994a-a13e-4eef-a95f-7b825f3376f7.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/30d841b3-a62e-4768-9781-5e988f392c7e_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/30d841b3-a62e-4768-9781-5e988f392c7e.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/de598416-2a2c-4cbc-ad90-455acbea3bb1_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/de598416-2a2c-4cbc-ad90-455acbea3bb1.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/cd19567a-a3f4-41b4-ac14-b4de6cb254bd_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/cd19567a-a3f4-41b4-ac14-b4de6cb254bd.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/bd6a2315-7421-42b9-8fab-e76219578630_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/bd6a2315-7421-42b9-8fab-e76219578630.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/0ed6bdf7-ecfc-40bb-8d33-10fa5cab1ed8_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/0ed6bdf7-ecfc-40bb-8d33-10fa5cab1ed8.jpg"
#           }
#
#       ]
#   }
#  </script>,
#  <script type="application/ld+json">
#   {
#       "@context": "http://schema.org",
#
#       "@type": "ApartmentComplex",
#
#
#       "url": "https://www.torontorentals.com/north-york/clipper-place-id580",
#       "name": "Clipper Place",
# ...
#       "geo": {
#           "@type": "GeoCoordinates",
#           "latitude": 43.78716,
#           "longitude": -79.335473
#       },
#       "containedInPlace": {
#           "@type": "City",
#           "url": "https://www.torontorentals.com/north-york",
#           "name" : "North York",
#           "address": {
#               "@type": "PostalAddress",
#               "addressCountry" : "CA",
#               "addressRegion" : "Ontario"
#           }
#       },
#       "containsPlace": [
#
#           {
#               "@context": "http://schema.org",
#
#               "@type": "Apartment",
#
#               "name": "1 bedroom",
#               "potentialAction": {
#                   "@type": "RentAction",
#                   "priceSpecification": {
#                       "@type": "PriceSpecification",
#                       "price": 1550.00,
#                       "priceCurrency": "CAD"
#                   }
#               },
#
#               "numberOfRooms": 1
#           },
#
#           {
#               "@context": "http://schema.org",
#
#               "@type": "Apartment",
#
#               "name": "2 bedroom",
#               "potentialAction": {
#                   "@type": "RentAction",
#                   "priceSpecification": {
#                       "@type": "PriceSpecification",
#                       "price": 1787.00,
#                       "priceCurrency": "CAD"
#                   }
#               },
#
#               "numberOfRooms": 2
#           },
#
#           {
#               "@context": "http://schema.org",
#
#               "@type": "Apartment",
#
#               "name": "3 bedroom",
#               "potentialAction": {
#                   "@type": "RentAction",
#                   "priceSpecification": {
#                       "@type": "PriceSpecification",
#                       "price": 1837.00,
#                       "priceCurrency": "CAD"
#                   }
#               },
#
#               "numberOfRooms": 3
#           }
#
#       ],
#       "address": {
#           "@type" : "PostalAddress",
#           "addressCountry" : "CA",
#           "addressLocality" : "North York",
#           "addressRegion" : "Ontario",
#           "postalCode" : "M2J 4E2",
#           "streetAddress" : "70 Clipper Road"
#       },
#       "telephone" :  "",
#       "photo" : [
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/595471b8-abd2-4277-b42e-0c6d1c8c766b_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/595471b8-abd2-4277-b42e-0c6d1c8c766b.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/9641f781-6698-4cc5-8613-90dbec0c963e_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/9641f781-6698-4cc5-8613-90dbec0c963e.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/699ec2ee-a141-482c-8452-115e658c2a1d_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/699ec2ee-a141-482c-8452-115e658c2a1d.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/ce9925af-f2a1-43f3-8501-352921532723_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/ce9925af-f2a1-43f3-8501-352921532723.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/c3945d4e-bf28-441e-b273-602bb85565fc_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/c3945d4e-bf28-441e-b273-602bb85565fc.jpg"
#           }
#
#       ]
#   }
#  </script>,
#  <script type="application/ld+json">
#   {
#       "@context": "http://schema.org",
#
#       "@type": "ApartmentComplex",
#
#
#       "url": "https://www.torontorentals.com/north-york/bayview-towers-id422",
#       "name": "Bayview Towers",
#       "description": "_Units starting from listed price_ Amenities & Features of Apartments * Minutes to Hwy 401, 404, 407 and the D.V.P. 7 minute busride to Finch subway * 60 Ruddington Drive is in the prestigious area of Bayview & Finch * Nestled in a quiet self contained area of Willowdale * Ruddington park offers a playground for the children * Tennis courts for the young at heart * Residents appreciate a sense of community at Schickedanz Bros. Properties * Grocery, pharmacy, banks, restaurants & coffee shops as well as hair dressers, barbers and postal services are located in the Bayview/Cummer shopping centre adjacent to the property * Beautiful entrance and friendly staff make Schickedanz Bros. Properties a superior living experience * Our cozy lobby area welcomes you home * A book exchange is available in the brightly lit laundry facilities on site * Large outdoor swimming pool for sun and fun",
#       "geo": {
#           "@type": "GeoCoordinates",
#           "latitude": 43.790986,
#           "longitude": -79.389675
#       },
#       "containedInPlace": {
#           "@type": "City",
#           "url": "https://www.torontorentals.com/north-york",
#           "name" : "North York",
#           "address": {
#               "@type": "PostalAddress",
#               "addressCountry" : "CA",
#               "addressRegion" : "Ontario"
#           }
#       },
#       "containsPlace": [
#
#           {
#               "@context": "http://schema.org",
#
#               "@type": "Apartment",
#
#               "name": "1 bedroom",
#               "potentialAction": {
#                   "@type": "RentAction",
#                   "priceSpecification": {
#                       "@type": "PriceSpecification",
#                       "price": 1587.00,
#                       "priceCurrency": "CAD"
#                   }
#               },
#
#               "numberOfRooms": 1
#           },
#
#           {
#               "@context": "http://schema.org",
#
#               "@type": "Apartment",
#
#               "name": "2 bedroom",
#               "potentialAction": {
#                   "@type": "RentAction",
#                   "priceSpecification": {
#                       "@type": "PriceSpecification",
#                       "price": 1927.00,
#                       "priceCurrency": "CAD"
#                   }
#               },
#
#               "numberOfRooms": 2
#           },
#
#           {
#               "@context": "http://schema.org",
#
#               "@type": "Apartment",
#
#               "name": "3 bedroom",
#               "potentialAction": {
#                   "@type": "RentAction",
#                   "priceSpecification": {
#                       "@type": "PriceSpecification",
#                       "price": 2227.00,
#                       "priceCurrency": "CAD"
#                   }
#               },
#
#               "numberOfRooms": 3
#           }
#
#       ],
#       "address": {
#           "@type" : "PostalAddress",
#           "addressCountry" : "CA",
#           "addressLocality" : "North York",
#           "addressRegion" : "Ontario",
#           "postalCode" : "M2K 2J9",
#           "streetAddress" : "60 Ruddington Drive"
#       },
#       "telephone" :  "",
#       "photo" : [
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/9bfbac1f-c624-47d1-a5d4-ea316c582a2d_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/9bfbac1f-c624-47d1-a5d4-ea316c582a2d.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/b92b6589-2a34-46b8-84e1-0be9d925dc61_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/b92b6589-2a34-46b8-84e1-0be9d925dc61.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/ec562bbb-9b91-4c58-a943-de6515ff0001_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/ec562bbb-9b91-4c58-a943-de6515ff0001.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/8e5970e3-93d4-49ec-b83c-2b1e1c14ba06_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/8e5970e3-93d4-49ec-b83c-2b1e1c14ba06.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/546b7766-766c-4f2d-a5ce-aa6f50888454_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/546b7766-766c-4f2d-a5ce-aa6f50888454.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/d4d491dd-7db8-4e5f-a298-7980ea2a5a16_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/d4d491dd-7db8-4e5f-a298-7980ea2a5a16.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/9e0d87f7-7ee3-4154-bc09-7fbd012fce22_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/9e0d87f7-7ee3-4154-bc09-7fbd012fce22.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/7097ff60-4368-40fa-b371-8b9dcac0574d_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/7097ff60-4368-40fa-b371-8b9dcac0574d.jpg"
#           }
#
#       ]
#   }
#  </script>,
#  <script type="application/ld+json">
#   {
#       "@context": "http://schema.org",
#
#       "@type": "ApartmentComplex",
#
#
#       "url": "https://www.torontorentals.com/north-york/665-roselawn-avenue-id480",
#       "name": "665 Roselawn Avenue",
#       "description": "Amenities & Features of Lowrise Apartments --- * Controlled-access lobby * Laundry facilities on site * Parking Available * upgraded elevators * Renovated lobby and common areas * Professional building management on site Welcome to Terrace Gardens, a high-end five-storey apartment building situated in the prestigious neighbourhood of Forest Hill. Your new home has been completely renovated to feature a contemporary lobby, upgraded elevators, stylish hallways, and modernized lobby access, designed to impress your guests from the moment they walk-in!",
#       "geo": {
#           "@type": "GeoCoordinates",
#           "latitude": 43.705336,
#           "longitude": -79.425024
#       },
#       "containedInPlace": {
#           "@type": "City",
#           "url": "https://www.torontorentals.com/north-york",
#           "name" : "North York",
#           "address": {
#               "@type": "PostalAddress",
#               "addressCountry" : "CA",
#               "addressRegion" : "Ontario"
#           }
#       },
#       "containsPlace": [
#
#           {
#               "@context": "http://schema.org",
#
#               "@type": "Apartment",
#
#               "name": "Studio / Bachelor",
#               "potentialAction": {
#                   "@type": "RentAction",
#                   "priceSpecification": {
#                       "@type": "PriceSpecification",
#                       "price": 1205.00,
#                       "priceCurrency": "CAD"
#                   }
#               },
#
#               "numberOfRooms": 0
#           },
#
#           {
#               "@context": "http://schema.org",
#
#               "@type": "Apartment",
#
#               "name": "1 bedroom",
#               "potentialAction": {
#                   "@type": "RentAction",
#                   "priceSpecification": {
#                       "@type": "PriceSpecification",
#                       "price": 1440.00,
#                       "priceCurrency": "CAD"
#                   }
#               },
#
#               "numberOfRooms": 1
#           },
#
#           {
#               "@context": "http://schema.org",
#
#               "@type": "Apartment",
#
#               "name": "2 bedroom",
#               "potentialAction": {
#                   "@type": "RentAction",
#                   "priceSpecification": {
#                       "@type": "PriceSpecification",
#                       "price": 1695.00,
#                       "priceCurrency": "CAD"
#                   }
#               },
#
#               "numberOfRooms": 2
#           }
#
#       ],
#       "address": {
#           "@type" : "PostalAddress",
#           "addressCountry" : "CA",
#           "addressLocality" : "North York",
#           "addressRegion" : "Ontario",
#           "postalCode" : "M5N 1L1",
#           "streetAddress" : "665 Roselawn Avenue"
#       },
#       "telephone" :  "",
#       "photo" : [
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/3d24432c-c6ba-413a-9818-0cee70feebaa_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/3d24432c-c6ba-413a-9818-0cee70feebaa.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/7ade3476-208f-42b8-a4a6-8cb805ea66f4_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/7ade3476-208f-42b8-a4a6-8cb805ea66f4.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/633bcf80-3d0a-4126-9567-b387baff5546_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/633bcf80-3d0a-4126-9567-b387baff5546.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/081fe6ad-099c-4412-8337-986f550bd738_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/081fe6ad-099c-4412-8337-986f550bd738.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/868019a3-b650-4aee-ab8d-8e4ae387ff55_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/868019a3-b650-4aee-ab8d-8e4ae387ff55.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/3e467d97-ec18-433d-abfb-23b01f6ced20_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/3e467d97-ec18-433d-abfb-23b01f6ced20.jpg"
#           },
#
#
#
#           {
#               "@type": "Photograph",
#               "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/4a71f392-2b12-49bc-8c11-ad1f57c57f70_352x198.jpg",
#               "image": "https://cdn2.torontorentals.com/photos/large/4a71f392-2b12-49bc-8c11-ad1f57c57f70.jpg"
#           }
#
#       ]
#   }
#  </script>]

# %%
urls = []
for group in script_dump[3:-6]:
    test1 = group
    test2 = BeautifulSoup(test1.text,"html.parser")
    newDictionary=json.loads(test2.text)
    response2 = requests.get(newDictionary['url'])
    urls.append(response2)
    
urls
# Out:
# [<Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>]

# %%
for group in script_dump[3:-6]:
    test1 = group
    test2 = BeautifulSoup(test1.text,"html.parser")
    newDictionary=json.loads(test2.text)
    NameofApartment = newDictionary['name']
    print('---------------ApartMent Name:- ',NameofApartment,"------------------")

    response2 = requests.get(newDictionary['url'])
    sub_soap = BeautifulSoup(response2.text,"html.parser")
    sub_soap
    table = sub_soap.find_all('td')
    #print("Table:-- ", table)
    #print((len(table)//5)*5)
    #print(table)
    for i in range(0,(len(table)//5)*5,5):
        beds = BeautifulSoup((table[i+1]).text,"html.parser")
        bath = BeautifulSoup((table[i+2]).text,"html.parser")
        price = BeautifulSoup((table[i+3]).text,"html.parser")
        print("No of bedrooms are {}, No of bathrooms are {}, Price is {}".format(beds,bath,price))
        
    time.sleep(5)
#     for i in range(0,len(newDictionary['containsPlace'])):
        
#         price = each['potentialAction']['priceSpecification']['price']
#         numberOfRooms = each['numberOfRooms']

#         print('Price is {} for {} No of rooms',format(str(price),numberOfRooms))
# Out:
# ---------------ApartMent Name:-  571 Prince Edward Dr N ------------------
# No of bedrooms are 1, No of bathrooms are 1, Price is
# $2,000
#
# No of bedrooms are 1, No of bathrooms are 1, Price is
# $2,300
#
# No of bedrooms are 2, No of bathrooms are 2, Price is
# $2,700
#
#
# No of bedrooms are 2, No of bathrooms are 2, Price is
# $3,850
#
# ---------------ApartMent Name:-  eCentral ------------------
# No of bedrooms are 0, No of bathrooms are 1, Price is
# $2,002.5
#
# No of bedrooms are 1, No of bathrooms are 1, Price is
# $2,248.5
#
# No of bedrooms are 1, No of bathrooms are 2, Price is
# $2,455.8
#
# No of bedrooms are 2, No of bathrooms are 2, Price is
# $3,608
#
# No of bedrooms are 2, No of bathrooms are 2, Price is
# $3,847
#
# No of bedrooms are 2, No of bathrooms are 2 ½, Price is
# $4,998.3
#
# ---------------ApartMent Name:-  Bayview Towers ------------------
# No of bedrooms are 1, No of bathrooms are 1, Price is
# $1,647
#
# No of bedrooms are 2, No of bathrooms are 1, Price is
# $1,927
#
# No of bedrooms are 3, No of bathrooms are 1, Price is
# $2,227
#
# ---------------ApartMent Name:-  Kings Club ------------------
# No of bedrooms are 1, No of bathrooms are 1, Price is
# $2,150
#
# No of bedrooms are 1, No of bathrooms are 1, Price is
# $2,170
#
# No of bedrooms are 2, No of bathrooms are 1, Price is
# $2,480
#
# No of bedrooms are 2, No of bathrooms are 1, Price is
# $3,635
#
# No of bedrooms are 3, No of bathrooms are 1, Price is
# $3,815
#
# ---------------ApartMent Name:-  70 Ruddington Drive ------------------
# No of bedrooms are 1, No of bathrooms are 1, Price is
# $1,837
#
# No of bedrooms are 2, No of bathrooms are 1, Price is
# $2,487
#
# ---------------ApartMent Name:-  Bayview Towers ------------------
# No of bedrooms are 1, No of bathrooms are 1, Price is
# $1,587
#
# No of bedrooms are 2, No of bathrooms are 1, Price is
# $1,927
#
# No of bedrooms are 3, No of bathrooms are 1, Price is
# $2,227
#
# ---------------ApartMent Name:-  Clipper Place ------------------
# No of bedrooms are 1, No of bathrooms are 1, Price is
# $1,550
#
# No of bedrooms are 2, No of bathrooms are 1, Price is
# $1,787
#
# No of bedrooms are 3, No of bathrooms are 2, Price is
# $1,837
#
# ---------------ApartMent Name:-  Bayview Towers ------------------
# No of bedrooms are 1, No of bathrooms are 1, Price is
# $1,587
#
# No of bedrooms are 2, No of bathrooms are 1, Price is
# $1,927
#
# No of bedrooms are 3, No of bathrooms are 1, Price is
# $2,227
#
#
# ---------------ApartMent Name:-  665 Roselawn Avenue ------------------
# No of bedrooms are 0, No of bathrooms are 1, Price is
# $1,205
#
# No of bedrooms are 1, No of bathrooms are 1, Price is
# $1,440
#
# No of bedrooms are 2, No of bathrooms are 1, Price is
# $1,695

# %%
group = script_dump[5]
# Out:
# ---------------ApartMent Name:-  Bayview Towers ------------------
# 15
# [<td class="name">
# <span class="floorplan-name">
# 1 bedroom
# </span>
# </td>, <td class="beds">1</td>, <td class="baths">1</td>, <td class="price">
# $1,647
# </td>, <td class="hidden-xs"><a class="btn btn-primary open-popup" data-target="#modal-contact" data-target-attr-unit_id="196913" href="javascript:;">Check availability</a></td>, <td class="name">
# <span class="floorplan-name">
# 2 bedroom
# </span>
# </td>, <td class="beds">2</td>, <td class="baths">1</td>, <td class="price">
# $1,927
# </td>, <td class="hidden-xs"><a class="btn btn-primary open-popup" data-target="#modal-contact" data-target-attr-unit_id="196914" href="javascript:;">Check availability</a></td>, <td class="name">
# <span class="floorplan-name">
# 3 bedroom
# </span>
# </td>, <td class="beds">3</td>, <td class="baths">1</td>, <td class="price">
# $2,227
# </td>, <td class="hidden-xs"><a class="btn btn-primary open-popup" data-target="#modal-contact" data-target-attr-unit_id="196915" href="javascript:;">Check availability</a></td>, <td valign="top"> <ul> <li> 505 Cummer Ave. in the prestigious area of Bayview &amp; Finch</li> <li> Beautiful entrance and friendly staff make Shickedanz Bros. Properties a superior living experience</li> <li> Our cozy lobby area welcomes you home</li> <li> Residents appreciate a sense of community at Schickedanz Bros. Properties. A book exchange is available in the brightly lit laundry facilities on site</li> <li> Our large outdoor swimming pool offers hours of fun in the sun</li> <li> Beautiful Ruddington park offers tennis courts for the young at heart</li> <li> Minutes to Hwy 401, 404, 407 and the D.V.P. 7 minute busride to Finch subway</li> </ul> </td>]
# No of bedrooms are 1, No of bathrooms are 1, Price is
# $1,647
#
# No of bedrooms are 2, No of bathrooms are 1, Price is
# $1,927
#
# No of bedrooms are 3, No of bathrooms are 1, Price is
# $2,227

# %%
response2 = requests.get('https://www.torontorentals.com/toronto/kings-club-id60237')
sub_soap = BeautifulSoup(response2.text,"html.parser")
sub_soap
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en"> <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <title>1100 King Street West, Toronto, ON, M6K 0C6</title>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="yes" name="apple-mobile-web-app-capable">
# <link href="https://maps.googleapis.com" rel="preconnect"/>
# <link href="https://maps.gstatic.com" rel="preconnect"/>
# <link href="https://fonts.googleapis.com" rel="preconnect"/>
# <link href="https://cdn2.torontorentals.com" rel="preconnect"/>
# <link href="https://www.google-analytics.com" rel="preconnect"/>
# <link href="https://fonts.gstatic.com" rel="preconnect"/>
# <link href="https://stats.g.doubleclick.net" rel="preconnect"/>
# <link href="https://analytics.trovit.com" rel="preconnect"/>
# <meta content="app-id=1475449043" name="apple-itunes-app"/>
# <meta content="app-id=com.rentalsca" name="google-play-app"/>
# <link href="/static/torontorentals.com/images/favicon.403f1ac6506f.ico" rel="icon" type="image/vnd.microsoft.icon">
# <link href="/static/torontorentals.com/images/favicon.cb74a72bad22.png" rel="icon">
# <link href="/static/torontorentalscom/dist/listing-page.3e2dca2222ec.css" rel="stylesheet" type="text/css">
# <script>
#
#  (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#  /*
#     {'debug': False, 'js_script': 'analytics.js', 'tracking_id': 'UA-2572459-11', 'tracker_config': {'useAmpClientId': True}}
#   */
#  ga('create', 'UA-2572459-11', 'auto', {"useAmpClientId": true});
#  ga('send', 'pageview');
# </script>
# <link href="https://www.torontorentals.com/toronto/kings-club-id60237" rel="canonical">
# <link href="https://www.torontorentals.com/toronto/kings-club-id60237?amp" rel="amphtml">
# <meta content="1100 King Street West apartment is for rent in Toronto, ON. 1 Bdrm available at 1100 King Street West, Toronto. Visit our Website: &lt;https://www. Caprent. Com/apartments-for-rent/toronto-on /kings-club/&gt;. Why Pay Double?. Pay One Month and Move In." name="description">
# <meta content="1100 King Street West, Toronto, ON, M6K 0C6" property="og:title">
# <meta content="1100 King Street West apartment is for rent in Toronto, ON. 1 Bdrm available at 1100 King Street West, Toronto. Visit our Website: &lt;https://www. Caprent. Com/apartments-for-rent/toronto-on /kings-club/&gt;. Why Pay Double?. Pay One Month and Move In." property="og:description">
# <meta content="https://www.torontorentals.com/toronto/kings-club-id60237" property="og:url">
# <meta content="article" property="og:type"/>
# <meta content="en" property="og:locale"/>
# <meta content="TorontoRentals.com" property="og:site_name"/>
# <meta content="https://cdn2.torontorentals.com/photos/large/aa214bc99104068d0a0477f1d2115a23.jpg" property="og:image"/>
# <meta content="640" property="og:image:width"/>
# <meta content="640" property="og:image:height"/>
# <meta content="Listing at 1100 King Street West, Toronto, ON" property="og:image:alt"/>
# <meta content="1930145733971727" property="fb:app_id"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@torentals" name="twitter:site"/>
# <meta content="@torentals" name="twitter:creator"/>
# <meta content="1100 King Street West, Toronto, ON, M6K 0C6" name="twitter:title"/>
# <meta content="1100 King Street West apartment is for rent in Toronto, ON. 1 Bdrm available at 1100 King Street West, Toronto. Visit our Website: &lt;https://www. Caprent. Com/apartments-for-rent/toronto-on /kings-club/&gt;. Why Pay Double?. Pay One Month and Move In." name="twitter:description"/>
# <meta content="https://cdn2.torontorentals.com/photos/large/aa214bc99104068d0a0477f1d2115a23.jpg" name="twitter:image"/>
# </meta></meta></meta></meta></link></link></link></link></link></meta></head>
# <body class="listing-page">
# <input name="csrfmiddlewaretoken" type="hidden" value="Py7DVi1Imid0galeu4Z6yc7u3gsuRkL24kaMauU4JHHtE0LHXVBpnigfxR8knknT"/>
# <div class="modal fade" id="modal-login" role="dialog" tabindex="-1">
# <div class="modal-dialog" role="document">
# <div class="modal-content">
# <div class="modal-header">
# <h5 class="modal-title">
# Welcome!
# <span class="modal-subtitle">Log In to Your Account</span>
# </h5>
# <button aria-label="Close" class="close" data-dismiss="modal" type="button">
# <span aria-hidden="true">×</span>
# </button>
# </div>
# <div class="modal-body form-group-as-line">
# <form class="material" data-redirect-url="/manage/listings" method="post">
# <input name="csrfmiddlewaretoken" type="hidden" value="Py7DVi1Imid0galeu4Z6yc7u3gsuRkL24kaMauU4JHHtE0LHXVBpnigfxR8knknT"/>
# <div class="form-group">
# <input class="form-control" id="login-email" name="email" required="" type="email"/>
# <label for="login-email">Email*</label>
# </div>
# <div class="form-group">
# <input class="form-control" id="login-password" name="password" required="" type="password"/>
# <label for="login-password">Password*</label>
# </div>
# <div class="modal-alert alert"></div>
# <div class="d-flex justify-content-between align-items-center">
# <div class="form-check">
# <input class="form-check-input sr-only" id="login-remember-me" name="remember-me" type="checkbox"/>
# <label class="form-check-label" for="login-remember-me">Remember me</label>
# </div>
# <button class="btn btn-primary" type="submit">Log In</button>
# </div>
# </form>
# </div>
# <div class="modal-footer p-0 as-buttons justify-content-between align-items-center">
# <a class="btn w-50 mr-0 border-right text-center" data-to-another-modal="#modal-reset-password" href="#">Forgot your Password?</a>
# <a class="btn w-50 ml-0 text-center" data-to-another-modal="#modal-create-account" href="#">Create Account</a>
# </div>
# </div>
# </div>
# </div>
# <div class="modal fade" id="modal-reset-password" role="dialog" tabindex="-1">
# <div class="modal-dialog" role="document">
# <div class="modal-content">
# <div class="modal-header">
# <h5 class="modal-title">
# Forgot your info?
# <span class="modal-subtitle">Reset Your Password</span>
# </h5>
# <button aria-label="Close" class="close" data-dismiss="modal" type="button">
# <span aria-hidden="true">×</span>
# </button>
# </div>
# <div class="modal-body form-group-as-line">
# <form class="material" method="post">
# <input name="csrfmiddlewaretoken" type="hidden" value="Py7DVi1Imid0galeu4Z6yc7u3gsuRkL24kaMauU4JHHtE0LHXVBpnigfxR8knknT">
# <div class="form-group">
# <input class="form-control" id="reset-password-email" name="email" required="" type="email" value=""/>
# <label for="reset-password-email">Email*</label>
# </div>
# <div class="modal-alert alert"></div>
# <div class="d-flex justify-content-between align-items-center">
# <p class="mb-0 mr-2">We will send you an email with further instructions.</p>
# <button class="btn btn-primary" type="submit">Reset</button>
# </div>
# </input></form>
# </div>
# <div class="modal-footer justify-content-start">
# <p class="mb-0">No need to reset? <a data-to-another-modal="#modal-login" href="#">Login.</a></p>
# </div>
# </div>
# </div>
# </div>
# <div class="modal fade" id="modal-create-account" role="dialog" tabindex="-1">
# <div class="modal-dialog" role="document">
# <div class="modal-content">
# <div class="modal-header">
# <h5 class="modal-title">
# Get started!
# <span class="modal-subtitle">Create a New Account</span>
# </h5>
# <button aria-label="Close" class="close" data-dismiss="modal" type="button">
# <span aria-hidden="true">×</span>
# </button>
# </div>
# <div class="modal-body form-group-as-line">
# <form class="material" data-redirect-url="/manage/listings/new?from=add-rental" method="post">
# <input name="csrfmiddlewaretoken" type="hidden" value="Py7DVi1Imid0galeu4Z6yc7u3gsuRkL24kaMauU4JHHtE0LHXVBpnigfxR8knknT"/>
# <div class="form-group">
# <input class="form-control" id="create-account-full-name" name="name" required="" type="text"/>
# <label for="create-account-full-name">Full Name*</label>
# </div>
# <div class="row">
# <div class="col-6">
# <div class="form-group">
# <input class="form-control" id="create-account-email" name="email" required="" type="email"/>
# <label for="create-account-email">Email*</label>
# </div>
# </div>
# <div class="col-6">
# <div class="form-group">
# <input class="form-control phone" id="create-account-phone" name="phone" required="" type="tel"/>
# <label for="create-account-phone">Phone*</label>
# </div>
# </div>
# </div>
# <div class="row">
# <div class="col-6">
# <div class="form-group">
# <input class="form-control" id="create-account-password" name="password" required="" type="password"/>
# <label for="create-account-password">Password*</label>
# </div>
# </div>
# <div class="col-6">
# <div class="form-group">
# <input class="form-control" id="create-account-password-2" name="password2" required="" type="password"/>
# <label for="create-account-password-2">Repeat Password*</label>
# </div>
# </div>
# </div>
# <div class="form-group">
# <input class="form-control" id="create-account-company" name="company" type="text"/>
# <label for="create-account-company">Company</label>
# </div>
# <div class="modal-alert alert"></div>
# <div class="d-flex justify-content-between align-items-center">
# <div class="form-check mr-2">
# <input class="form-check-input sr-only" id="create-account-accept-terms" required="" type="checkbox"/>
# <label class="form-check-label" for="create-account-accept-terms">I agree to the <a href="/terms">Terms of Use</a> &amp; <a href="/privacy">Privacy Policy.</a></label>
# </div>
# <button class="btn btn-primary" type="submit">Register</button>
# </div>
# </form>
# </div>
# <div class="modal-footer justify-content-start align-items-center">
# <p class="m-0">Already have an account? <a href="/manage/listings/new?from=login">Log In.</a></p>
# </div>
# </div>
# </div>
# </div>
# <header class="main-header">
# <div class="container not-apply-map-tab-fix-vh">
# <nav class="navbar justify-content-between navbar-expand-lg">
# <a class="navbar-brand" href="/">
# <img height="40" src="/static/torontorentalscom/img/logo-blue.f70f9e5a8349.svg" width="80"/>
# <span class="logo-text d-none d-sm-inline-block"><strong>TorontoRentals</strong>.com</span>
# </a>
# <button aria-label="Open search" class="navbar-search ml-auto d-lg-none" data-target="#main-header-search-modal" data-toggle="modal" type="button">
# <i class="fa fa-search"></i>
# </button>
# <button aria-controls="main-header-navbar" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-target="#main-header-navbar" data-toggle="collapse" type="button">
# <span class="navbar-toggler-icon"></span>
# </button>
# <div class="d-none d-lg-block">
# <form action="/search" class="search-form-main">
# <div class="input-group">
# <input autocomplete="disabled" class="form-control" name="s" required="" type="text"/>
# <div class="label-behind">
# <span>Search by <strong>City</strong> or <strong>Address</strong></span>
# </div>
# <div class="input-group-append">
# <button class="btn btn-primary" type="submit">Search</button>
# <button aria-label="Close" class="close" data-dismiss="modal" type="button">
# <span aria-hidden="true">×</span>
# </button>
# </div>
# </div>
# </form>
# </div>
# <div class="collapse navbar-collapse" id="main-header-navbar">
# <div class="non-mobile">
# <ul class="navbar-nav">
# <li class="nav-item">
# <a class="btn btn-outline-primary" href="/manage/listings/new?from=login">Log in / Sign up</a>
# </li>
# <li class="nav-item">
# <a class="btn btn-primary btn-new-listing" href="/manage/listings/new?from=add-rental">
# <span class="label-new-listing">
# Add Rental
# </span>
# </a>
# </li>
# </ul>
# </div>
# <div class="mobile">
# <div class="mobile-slideout-panel">
# <ul>
# <li class="level-1">
# <a href="/manage/listings/new?from=add-rental">
# <span class="label">
# Add Rental
# </span>
# </a>
# </li>
# <li class="level-2">
# <a href="/manage/listings/new?from=login">Login</a>
# </li>
# <li class="level-2">
# <a href="/manage/listings/new?from=sign-up">Sign Up</a>
# </li>
# <li class="level-3">
# <a href="/neighbourhood-guide/toronto">
# <span class="tag">
# New
# </span>
# <span class="label">
# Neighborhood Guides
# </span>
# </a>
# </li>
# </ul>
# <ul class="social-profiles">
# <li class="social-instagram">
# <a href="https://www.instagram.com/to.rentals/" rel="noopener" target="_blank">
# <i class="fa fa-instagram"></i>
# <span class="hidden label">Instagram</span>
# </a>
# </li>
# <li class="social-facebook">
# <a href="https://www.facebook.com/torentals/" rel="noopener" target="_blank">
# <i class="fa fa-facebook-square"></i>
# <span class="hidden label">Facebook</span>
# </a>
# </li>
# <li class="social-youtube">
# <a href="https://www.youtube.com/channel/UCxx2QQwDaGaTarDNjOBRnMw" rel="noopener" target="_blank">
# <i class="fa fa-youtube-play"></i>
# <span class="hidden label">Youtube</span>
# </a>
# </li>
# <li class="social-twitter">
# <a href="http://twitter.com/torentals" rel="noopener" target="_blank">
# <i class="fa fa-twitter"></i>
# <span class="hidden label">Twitter</span>
# </a>
# </li>
# <li class="social-linkedin">
# <a href="https://www.linkedin.com/company/toronto-rentals-com" rel="noopener" target="_blank">
# <i class="fa fa-linkedin-square"></i>
# <span class="hidden label">LinkedIn</span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </nav>
# </div>
# </header>
# <div aria-hidden="true" class="modal fade" id="main-header-search-modal" role="dialog" tabindex="-1">
# <div class="modal-dialog" role="document">
# <div class="modal-content">
# <form action="/search" class="search-form-main">
# <div class="input-group">
# <input autocomplete="disabled" class="form-control" name="s" required="" type="text"/>
# <div class="label-behind">
# <span>Search by <strong>City</strong> or <strong>Address</strong></span>
# </div>
# <div class="input-group-append">
# <button class="btn btn-primary" type="submit">Search</button>
# <button aria-label="Close" class="close" data-dismiss="modal" type="button">
# <span aria-hidden="true">×</span>
# </button>
# </div>
# </div>
# </form>
# </div>
# </div>
# </div>
# <div class="list-back main-wrapper">
# <script type="application/ld+json">
#  {
#      "@context": "http://schema.org",
#
#      "@type": "Accommodation",
#
#
#      "url": "https://www.torontorentals.com/toronto/kings-club-id60237",
#      "name": "Kings Club",
#      "description": "Visit our Website: <https://www.caprent.com/apartments-for-rent/toronto-on /kings-club/> **Why Pay Double?** Pay One Month and Move In* **Rental Office is located in the Kings Club Building at 1100 King Street West 4th Floor** ****Experience serious living without the investment - Kings Club is a new purpose-built rental building that offers all the amenities of a condo without the commitment of a mortgage. Located in the heart of Liberty Village, Kings Club offers beautiful downtown Toronto apartments for rent with stainless steel appliances, in-suite laundry, and building amenities like a rooftop infinity pool, yoga room and fitness centre. Aside from the opportunity to rent a brand new bachelor, 1 bedroom, 1 + den, 2 bedroom, 2 +den and 3 bedroom suites, Kings Club residents can easily access three floors of on-site retailers including Shoppers Drug Mart, Longos, Canadian Tire and Kids N Co to name a few. * 2 + Den units are over 1,000 square feet Parking from: $175.00 Have Questions? Contact the Property Manager: (416) 306-3051 Building Features **Apartment Features** * Stainless steel fridge, stove, dishwasher, microwave hood range, washer and dryer * Two-toned kitchen cabinets with under-mount lighting * Subway tiled glass backsplash for easy clean up * Two-toned kitchen islands in most suites * Track lighting in kitchen * Quartz counter tops * Contemporary ceramic flooring in bathroom * Large medicine cabinet in bathroom * Some suites with glass showers * Rich laminate flooring * Smooth finished 9 to 9 \u00bd foot ceilings * Pot lights throughout * Floor to ceiling windows complete with premium window coverings * Wheelchair accessible suites available **Amenity Features in the building** * Stunning rooftop patio complete with BBQ's and lounge seating * Rooftop infinity pool with breath taking views * Convenient parcel service * Concierge onsite * 24 security desk * Yoga studio * Fitness centre * Games room * Large business centre complete with boardroom * Kids Zone * 2 levels of resident parking * Visitor parking underground * Lockers in 2 different sizes * Bicycle storage * WI-FI available in all common areas * Surround sound in games room, boardroom and fitness centre **Retailers in the building** * Longo's * Canadian Tire * Shoppers Drug Mart * Winners * Kids & Company * McDonald\u2019s * Petsmart Neighbourhood Features * Quickly becoming one of Toronto's most up-and-coming neighbourhoods, Liberty Village's industrial-meets-urban style offers a variety of amenities, from trendy coffee shops to elevated dining to popular shops inside the Liberty Market Building. * With easy access to the 504 King streetcar and the Gardiner Expressway, Liberty Village serves as an urban epi-centre of Toronto's west end. * Kings Club residents never experience a dull moment in Liberty Village, with BMO Field, Lamport Stadium, Ontario Place, Exhibition Place and Lake Ontario just minutes away. * Check out popular Toronto offerings all year round like Toronto Fashion Week, TIFF, North by Northeast, Toronto Pride and Caribana.",
#      "geo": {
#          "@type": "GeoCoordinates",
#          "latitude": 43.63985,
#          "longitude": -79.42373
#      },
#      "containedInPlace": {
#          "@type": "City",
#          "url": "https://www.torontorentals.com/toronto",
#          "name" : "Toronto",
#          "address": {
#              "@type": "PostalAddress",
#              "addressCountry" : "CA",
#              "addressRegion" : "Ontario"
#          }
#      },
#      "containsPlace": [
#
#          {
#              "@context": "http://schema.org",
#
#              "@type": "Accommodation",
#
#              "name": "1 Bedroom",
#              "potentialAction": {
#                  "@type": "RentAction",
#                  "priceSpecification": {
#                      "@type": "PriceSpecification",
#                      "price": 2150.00,
#                      "priceCurrency": "CAD"
#                  }
#              },
#
#              "numberOfRooms": 1
#          },
#
#          {
#              "@context": "http://schema.org",
#
#              "@type": "Accommodation",
#
#              "name": "1 Bedroom",
#              "potentialAction": {
#                  "@type": "RentAction",
#                  "priceSpecification": {
#                      "@type": "PriceSpecification",
#                      "price": 2170.00,
#                      "priceCurrency": "CAD"
#                  }
#              },
#
#              "numberOfRooms": 1
#          },
#
#          {
#              "@context": "http://schema.org",
#
#              "@type": "Accommodation",
#
#              "name": "2 Bedroom",
#              "potentialAction": {
#                  "@type": "RentAction",
#                  "priceSpecification": {
#                      "@type": "PriceSpecification",
#                      "price": 2480.00,
#                      "priceCurrency": "CAD"
#                  }
#              },
#
#              "numberOfRooms": 2
#          },
#
#          {
#              "@context": "http://schema.org",
#
#              "@type": "Accommodation",
#
#              "name": "2 Bedroom",
#              "potentialAction": {
#                  "@type": "RentAction",
#                  "priceSpecification": {
#                      "@type": "PriceSpecification",
#                      "price": 3635.00,
#                      "priceCurrency": "CAD"
#                  }
#              },
#
#              "numberOfRooms": 2
#          },
#
#          {
#              "@context": "http://schema.org",
#
#              "@type": "Accommodation",
#
#              "name": "3 Bedroom",
#              "potentialAction": {
#                  "@type": "RentAction",
#                  "priceSpecification": {
#                      "@type": "PriceSpecification",
#                      "price": 3815.00,
#                      "priceCurrency": "CAD"
#                  }
#              },
#
#              "numberOfRooms": 3
#          }
#
#      ],
#      "address": {
#          "@type" : "PostalAddress",
#          "addressCountry" : "CA",
#          "addressLocality" : "Toronto",
#          "addressRegion" : "Ontario",
#          "postalCode" : "M6K 0C6",
#          "streetAddress" : "1100 King Street West"
#      },
#      "telephone" :  "",
#      "photo" : [
#
#
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/aa214bc99104068d0a0477f1d2115a23_352x198.jpg",
#              "image": "https://cdn2.torontorentals.com/photos/large/aa214bc99104068d0a0477f1d2115a23.jpg"
#          },
#
#
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/d860fac512f07f367d6ecb0add1f1631_352x198.jpg",
#              "image": "https://cdn2.torontorentals.com/photos/large/d860fac512f07f367d6ecb0add1f1631.jpg"
#          },
#
#
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/1b01afcda1de2fb1d3fa39929f702ed8_352x198.jpg",
#              "image": "https://cdn2.torontorentals.com/photos/large/1b01afcda1de2fb1d3fa39929f702ed8.jpg"
#          },
#
#
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/925b10c73747fadfc0a82eb3c6cd86be_352x198.jpg",
#              "image": "https://cdn2.torontorentals.com/photos/large/925b10c73747fadfc0a82eb3c6cd86be.jpg"
#          },
#
#
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/fcb28022f877dfcfe51eba4ca0596a6c_352x198.jpg",
#              "image": "https://cdn2.torontorentals.com/photos/large/fcb28022f877dfcfe51eba4ca0596a6c.jpg"
#          },
#
#
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/3a45ff19f609a834b2a134bfcba5fdd0_352x198.jpg",
#              "image": "https://cdn2.torontorentals.com/photos/large/3a45ff19f609a834b2a134bfcba5fdd0.jpg"
#          },
#
#
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/72e815125edec438e725c02884728a52_352x198.jpg",
#              "image": "https://cdn2.torontorentals.com/photos/large/72e815125edec438e725c02884728a52.jpg"
#          },
#
#
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/bb55990947fe14aadb499b9ea08d31fd_352x198.jpg",
#              "image": "https://cdn2.torontorentals.com/photos/large/bb55990947fe14aadb499b9ea08d31fd.jpg"
#          },
#
#
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/d78b53aa19a26bf7319ac120c02cbce2_352x198.jpg",
#              "image": "https://cdn2.torontorentals.com/photos/large/d78b53aa19a26bf7319ac120c02cbce2.jpg"
#          },
#
#
#
#          {
#              "@type": "Photograph",
#              "thumbnailUrl": "https://cdn2.torontorentals.com/photos/thumbnail/a0b48fafeb930c719093241f964cd956_352x198.jpg",
#              "image": "https://cdn2.torontorentals.com/photos/large/a0b48fafeb930c719093241f964cd956.jpg"
#          }
#
#      ]
#  }
# </script>
# <div class="mobile-listing-nav d-flex hidden-sm-up">
# <button onclick="javascript:window.history.go(-1); return false;"><i class="fa fa-arrow-left"></i></button>
# <button class="share open-popup" data-target="#modal-share-listing"><i class="fa fa-share-alt"></i></button>
# <button class="check-availability open-popup" data-target="#modal-contact">Check Availability</button>
# </div>
# <div class="listing-nav hidden visible-sm-up">
# <div class="container">
# <div class="row">
# <div class="col-sm-8 breadcrumbs-wrapper">
# <ol class="breadcrumbs" itemscope="" itemtype="http://schema.org/BreadcrumbList">
# <li itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
# <a href="https://www.torontorentals.com/" itemprop="item">
# <span itemprop="name">Home</span>
# <meta content="1" itemprop="position">
# </meta></a>
# </li>
# <li itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
# <a href="https://www.torontorentals.com/toronto" itemprop="item">
# <span itemprop="name">Toronto Rentals</span>
# <meta content="2" itemprop="position">
# </meta></a>
# </li>
# <li itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
# <a href="https://www.torontorentals.com/toronto/kings-club-id60237" itemprop="item">
# <span itemprop="name">Kings Club</span>
# <meta content="3" itemprop="position">
# </meta></a>
# </li>
# </ol>
# </div>
# <div class="col-sm-4 sidepanel">
# <button class="btn back" onclick="javascript:window.location.href = '';">
# <i aria-hidden="true" class="fa fa-chevron-circle-left"></i>
# <span class="btn-label">Back to Search</span>
# </button>
# <button class="btn share open-popup" data-target="#modal-share-listing">
# <i aria-hidden="true" class="fa fa-share-alt"></i>
# <span class="btn-label">Share Listing</span>
# </button>
# </div>
# </div>
# </div>
# </div>
# <div class="listing-content">
# <div class="container">
# <div class="row row1">
# <div class="col-12 col-sm-8">
# <h1 class="listing-title">1 Bdrm available at 1100 King Street West, Toronto</h1>
# <h2>
#
# Kings Club -
# 1100 King Street West - Toronto,
# ON M6K 0C6
# </h2>
# </div>
# <div class="col-sm-4 side-panels hidden visible-sm-up">
# <div class="side-panel">
# <div class="listing-phone-click-to-reveal" data-listing-id="60237">
# <div class="listing-phone-click-to-reveal__activate">
# <a href="#">
# <i aria-hidden="true" class="fa fa-phone"></i>
# View Phone Number
# </a>
# </div>
# <div class="listing-phone-click-to-reveal__content">
# Contact @ <a href="tel:(416) 306-3051">(416) 306-3051</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="hidden" id="page-overview">
# <div class="row">
# <div class="col-sm-8 page-overview-tabs">
# <ul>
# <li class="active"><a data-target="#tab-photos" href="javascript:;"><i aria-hidden="true" class="fa fa-camera"></i> Photos</a></li>
# </ul>
# </div>
# <div class="col-sm-4 page-overview-actions">
# <button class="btn btn-primary open-popup" data-target="#modal-contact">Check Availability</button>
# <button class="btn btn-secondary">
# <i aria-hidden="true" class="fa fa-chevron-circle-left"></i>
# Back to Listing
# </button>
# </div>
# </div>
# <div class="carousel slide" data-interval="false" data-ride="carousel" id="page-overview-carousel">
# <div class="photo-count">
# <span class="photo-index">1</span> / <span class="photo-max">10</span>
# </div>
# <div class="carousel-inner" role="listbox">
# <div class="carousel-item active">
# <div class="img-proxy" data-idx="0" data-src="https://cdn2.torontorentals.com/photos/large/aa214bc99104068d0a0477f1d2115a23.jpg"></div>
# </div>
# <div class="carousel-item">
# <div class="img-proxy" data-idx="1" data-src="https://cdn2.torontorentals.com/photos/large/d860fac512f07f367d6ecb0add1f1631.jpg"></div>
# </div>
# <div class="carousel-item">
# <div class="img-proxy" data-idx="2" data-src="https://cdn2.torontorentals.com/photos/large/1b01afcda1de2fb1d3fa39929f702ed8.jpg"></div>
# </div>
# <div class="carousel-item">
# <div class="img-proxy" data-idx="3" data-src="https://cdn2.torontorentals.com/photos/large/925b10c73747fadfc0a82eb3c6cd86be.jpg"></div>
# </div>
# <div class="carousel-item">
# <div class="img-proxy" data-idx="4" data-src="https://cdn2.torontorentals.com/photos/large/fcb28022f877dfcfe51eba4ca0596a6c.jpg"></div>
# </div>
# <div class="carousel-item">
# <div class="img-proxy" data-idx="5" data-src="https://cdn2.torontorentals.com/photos/large/3a45ff19f609a834b2a134bfcba5fdd0.jpg"></div>
# </div>
# <div class="carousel-item">
# <div class="img-proxy" data-idx="6" data-src="https://cdn2.torontorentals.com/photos/large/72e815125edec438e725c02884728a52.jpg"></div>
# </div>
# <div class="carousel-item">
# <div class="img-proxy" data-idx="7" data-src="https://cdn2.torontorentals.com/photos/large/bb55990947fe14aadb499b9ea08d31fd.jpg"></div>
# </div>
# <div class="carousel-item">
# <div class="img-proxy" data-idx="8" data-src="https://cdn2.torontorentals.com/photos/large/d78b53aa19a26bf7319ac120c02cbce2.jpg"></div>
# </div>
# <div class="carousel-item">
# <div class="img-proxy" data-idx="9" data-src="https://cdn2.torontorentals.com/photos/large/a0b48fafeb930c719093241f964cd956.jpg"></div>
# </div>
# </div>
# <a class="carousel-control-prev" data-slide="prev" href="#page-overview-carousel" role="button">
# <span aria-hidden="true" class="carousel-control-prev-icon"></span>
# <span class="sr-only">Previous</span>
# </a>
# <a class="carousel-control-next" data-slide="next" href="#page-overview-carousel" role="button">
# <span aria-hidden="true" class="carousel-control-next-icon"></span>
# <span class="sr-only">Next</span>
# </a>
# </div>
# <div class="carousel slide" data-interval="false" data-ride="carousel" id="page-overview-thumbnails-carousel">
# <div class="carousel-inner" role="listbox">
# <div class="carousel-item active">
# <div class="img-proxy" data-idx="0" data-src="https://cdn2.torontorentals.com/photos/thumbnail/aa214bc99104068d0a0477f1d2115a23_352x198.jpg"></div>
# <div class="img-proxy" data-idx="1" data-src="https://cdn2.torontorentals.com/photos/thumbnail/d860fac512f07f367d6ecb0add1f1631_352x198.jpg"></div>
# <div class="img-proxy" data-idx="2" data-src="https://cdn2.torontorentals.com/photos/thumbnail/1b01afcda1de2fb1d3fa39929f702ed8_352x198.jpg"></div>
# <div class="img-proxy" data-idx="3" data-src="https://cdn2.torontorentals.com/photos/thumbnail/925b10c73747fadfc0a82eb3c6cd86be_352x198.jpg"></div>
# <div class="img-proxy" data-idx="4" data-src="https://cdn2.torontorentals.com/photos/thumbnail/fcb28022f877dfcfe51eba4ca0596a6c_352x198.jpg"></div>
# </div>
# <div class="carousel-item">
# <div class="img-proxy" data-idx="5" data-src="https://cdn2.torontorentals.com/photos/thumbnail/3a45ff19f609a834b2a134bfcba5fdd0_352x198.jpg"></div>
# <div class="img-proxy" data-idx="6" data-src="https://cdn2.torontorentals.com/photos/thumbnail/72e815125edec438e725c02884728a52_352x198.jpg"></div>
# <div class="img-proxy" data-idx="7" data-src="https://cdn2.torontorentals.com/photos/thumbnail/bb55990947fe14aadb499b9ea08d31fd_352x198.jpg"></div>
# <div class="img-proxy" data-idx="8" data-src="https://cdn2.torontorentals.com/photos/thumbnail/d78b53aa19a26bf7319ac120c02cbce2_352x198.jpg"></div>
# <div class="img-proxy" data-idx="9" data-src="https://cdn2.torontorentals.com/photos/thumbnail/a0b48fafeb930c719093241f964cd956_352x198.jpg"></div>
# </div>
# </div>
# <a class="carousel-control-prev" data-slide="prev" href="#page-overview-thumbnails-carousel" role="button">
# <i aria-hidden="true" class="fa fa-chevron-left"></i>
# <span class="sr-only">Previous</span>
# </a>
# <a class="carousel-control-next" data-slide="next" href="#page-overview-thumbnails-carousel" role="button">
# <i aria-hidden="true" class="fa fa-chevron-right"></i>
# <span class="sr-only">Next</span>
# </a>
# </div>
# </div>
# <div class="row row2">
# <div class="col-12 col-lg-8">
# <div class="row no-gutters tabbed-gallery">
# <div class="col-sm-2 left-tabs-wrapper hidden visible-sm-up">
# <ul class="tabs-container" data-target="#gallery-tab-content-container">
# <li class="active">
# <a class="tab-btn" data-group="gallery" data-target="#tab-photos" href="javascript:;">
# <div class="tab-btn-inner">
# <i aria-hidden="true" class="fa fa-camera"></i>
# <span class="tab-text">Photos</span>
# </div>
# </a>
# </li>
# <li>
# <a class="tab-btn" data-group="gallery" data-target="#tab-street" href="javascript:;">
# <div class="tab-btn-inner">
# <i aria-hidden="true" class="fa fa-street-view"></i>
# <span class="tab-text">Street</span>
# </div>
# </a>
# </li>
# </ul>
# </div>
# <div class="col-12 col-sm-10 right-tabs-wrapper" id="gallery-tab-content-container">
# <div class="tab" data-lat="43.63985" data-lon="-79.42373" data-street="1" id="tab-street">
# </div>
# <div class="listing-photo-gallery-wrapper tab active" id="tab-photos">
# <div class="listing-photo-gallery carousel slide" data-interval="false" data-ride="carousel" id="carousel">
# <div class="photo-count">
# <span class="photo-index">1</span> / <span class="photo-max">10</span>
# </div>
# <div class="bottom-right-actions">
# <a class="expand" href="javascript:;"><i aria-hidden="true" class="fa fa-expand"></i></a>
# </div>
# <div class="carousel-inner" role="listbox">
# <div class="carousel-item active">
# <div class="hidden image-info" data-large-url="https://cdn2.torontorentals.com/photos/large/aa214bc99104068d0a0477f1d2115a23.jpg" data-medium-url="https://cdn2.torontorentals.com/photos/medium/aa214bc99104068d0a0477f1d2115a23_720x405.jpg"></div>
# <img src="https://cdn2.torontorentals.com/photos/medium/aa214bc99104068d0a0477f1d2115a23_720x405.jpg"/>
# </div>
# <div class="carousel-item">
# <div class="hidden image-info" data-large-url="https://cdn2.torontorentals.com/photos/large/d860fac512f07f367d6ecb0add1f1631.jpg" data-medium-url="https://cdn2.torontorentals.com/photos/medium/d860fac512f07f367d6ecb0add1f1631_720x405.jpg"></div>
# <img data-action="lazy-load" data-lazy-load-attr="src" data-lazy-load-src="https://cdn2.torontorentals.com/photos/medium/d860fac512f07f367d6ecb0add1f1631_720x405.jpg"/>
# </div>
# <div class="carousel-item">
# <div class="hidden image-info" data-large-url="https://cdn2.torontorentals.com/photos/large/1b01afcda1de2fb1d3fa39929f702ed8.jpg" data-medium-url="https://cdn2.torontorentals.com/photos/medium/1b01afcda1de2fb1d3fa39929f702ed8_720x405.jpg"></div>
# <img data-action="lazy-load" data-lazy-load-attr="src" data-lazy-load-src="https://cdn2.torontorentals.com/photos/medium/1b01afcda1de2fb1d3fa39929f702ed8_720x405.jpg"/>
# </div>
# <div class="carousel-item">
# <div class="hidden image-info" data-large-url="https://cdn2.torontorentals.com/photos/large/925b10c73747fadfc0a82eb3c6cd86be.jpg" data-medium-url="https://cdn2.torontorentals.com/photos/medium/925b10c73747fadfc0a82eb3c6cd86be_720x405.jpg"></div>
# <img data-action="lazy-load" data-lazy-load-attr="src" data-lazy-load-src="https://cdn2.torontorentals.com/photos/medium/925b10c73747fadfc0a82eb3c6cd86be_720x405.jpg"/>
# </div>
# <div class="carousel-item">
# <div class="hidden image-info" data-large-url="https://cdn2.torontorentals.com/photos/large/fcb28022f877dfcfe51eba4ca0596a6c.jpg" data-medium-url="https://cdn2.torontorentals.com/photos/medium/fcb28022f877dfcfe51eba4ca0596a6c_720x405.jpg"></div>
# <img data-action="lazy-load" data-lazy-load-attr="src" data-lazy-load-src="https://cdn2.torontorentals.com/photos/medium/fcb28022f877dfcfe51eba4ca0596a6c_720x405.jpg"/>
# </div>
# <div class="carousel-item">
# <div class="hidden image-info" data-large-url="https://cdn2.torontorentals.com/photos/large/3a45ff19f609a834b2a134bfcba5fdd0.jpg" data-medium-url="https://cdn2.torontorentals.com/photos/medium/3a45ff19f609a834b2a134bfcba5fdd0_720x405.jpg"></div>
# <img data-action="lazy-load" data-lazy-load-attr="src" data-lazy-load-src="https://cdn2.torontorentals.com/photos/medium/3a45ff19f609a834b2a134bfcba5fdd0_720x405.jpg"/>
# </div>
# <div class="carousel-item">
# <div class="hidden image-info" data-large-url="https://cdn2.torontorentals.com/photos/large/72e815125edec438e725c02884728a52.jpg" data-medium-url="https://cdn2.torontorentals.com/photos/medium/72e815125edec438e725c02884728a52_720x405.jpg"></div>
# <img data-action="lazy-load" data-lazy-load-attr="src" data-lazy-load-src="https://cdn2.torontorentals.com/photos/medium/72e815125edec438e725c02884728a52_720x405.jpg"/>
# </div>
# <div class="carousel-item">
# <div class="hidden image-info" data-large-url="https://cdn2.torontorentals.com/photos/large/bb55990947fe14aadb499b9ea08d31fd.jpg" data-medium-url="https://cdn2.torontorentals.com/photos/medium/bb55990947fe14aadb499b9ea08d31fd_720x405.jpg"></div>
# <img data-action="lazy-load" data-lazy-load-attr="src" data-lazy-load-src="https://cdn2.torontorentals.com/photos/medium/bb55990947fe14aadb499b9ea08d31fd_720x405.jpg"/>
# </div>
# <div class="carousel-item">
# <div class="hidden image-info" data-large-url="https://cdn2.torontorentals.com/photos/large/d78b53aa19a26bf7319ac120c02cbce2.jpg" data-medium-url="https://cdn2.torontorentals.com/photos/medium/d78b53aa19a26bf7319ac120c02cbce2_720x405.jpg"></div>
# <img data-action="lazy-load" data-lazy-load-attr="src" data-lazy-load-src="https://cdn2.torontorentals.com/photos/medium/d78b53aa19a26bf7319ac120c02cbce2_720x405.jpg"/>
# </div>
# <div class="carousel-item">
# <div class="hidden image-info" data-large-url="https://cdn2.torontorentals.com/photos/large/a0b48fafeb930c719093241f964cd956.jpg" data-medium-url="https://cdn2.torontorentals.com/photos/medium/a0b48fafeb930c719093241f964cd956_720x405.jpg"></div>
# <img data-action="lazy-load" data-lazy-load-attr="src" data-lazy-load-src="https://cdn2.torontorentals.com/photos/medium/a0b48fafeb930c719093241f964cd956_720x405.jpg"/>
# </div>
# </div>
# <a class="carousel-control-prev" data-slide="prev" href="#carousel" role="button">
# <span aria-hidden="true" class="carousel-control-prev-icon"></span>
# <span class="sr-only">Previous</span>
# </a>
# <a class="carousel-control-next" data-slide="next" href="#carousel" role="button">
# <span aria-hidden="true" class="carousel-control-next-icon"></span>
# <span class="sr-only">Next</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# <ul class="mobile-gallery-tabs hidden-sm-up" data-target="#gallery-tab-content-container">
# <li class="active"><a class="tab-btn" data-group="gallery" data-target="#tab-photos" href="javascript:;"><i aria-hidden="true" class="fa fa-camera"></i></a></li>
# <li><a class="tab-btn" data-group="gallery" data-target="#tab-street" href="javascript:;"><i aria-hidden="true" class="fa fa-street-view"></i></a></li>
# </ul>
# <div class="hidden-sm-up mobile-listing-details">
# <div class="row">
# <div class="col-12 col-sm-8">
# <h2 class="listing-title">1 Bdrm available at 1100 King Street West, Toronto</h2>
# <div class="mobile-rent">
# $2,150 - $3,815
# </div>
# <h3>
# Kings Club -
# 1100 King Street West<br/>
# Toronto,
# ON M6K 0C6
# </h3>
# </div>
# </div>
# </div>
# </div>
# <div class="col-12 side-panels col-lg-4">
# <div class="side-panel rent">
# <dl>
# <dt>
# <i aria-hidden="true" class="fa fa-usd"></i>
# Rent
# </dt>
# <dd>
# <i aria-hidden="true" class="fa fa-usd"></i>
# 2,150 &amp;dash
# <i aria-hidden="true" class="fa fa-usd"></i>
# 3,815
# </dd>
# </dl>
# </div>
# <div class="side-panel contact-form-wrapper">
# <form action="/api/v4/properties/60237/leads" class="material">
# <input name="csrfmiddlewaretoken" type="hidden" value="Py7DVi1Imid0galeu4Z6yc7u3gsuRkL24kaMauU4JHHtE0LHXVBpnigfxR8knknT">
# <div class="form-group">
# <input class="form-control" id="contact-name" name="name" required="" type="text">
# <label for="contact-name">Name</label>
# </input></div>
# <div class="form-group select-wrapper">
# <select class="form-control" name="unit_id">
# <option value="1006715">$2,150 |
# 1 Bedroom</option>
# <option value="1006716">$2,170 |
# 1 Bedroom</option>
# <option value="1006717">$2,480 |
# 2 Bedroom</option>
# <option value="1006718">$3,635 |
# 2 Bedroom</option>
# <option value="1006719">$3,815 |
# 3 Bedroom</option>
# </select>
# <label for="unit_id">Unit</label>
# </div>
# <div class="form-group">
# <input class="form-control" id="contact-email" name="email" type="email">
# <label for="contact-email">Email</label>
# </input></div>
# <div class="form-group">
# <input class="form-control" id="contact-phone" name="phone" type="tel"/>
# <label for="contact-phone">Phone</label>
# </div>
# <div class="message-wrapper hidden">
# <div class="message-name-template hidden">Hi,
# My name is |name| and I am interested in 1100 King Street West, Toronto, ON.</div>
# <div class="message-email-phone-template hidden">
# I can be contacted via |email_or_phone|. Looking forward to hearing back from you.
# </div>
# <textarea class="form-control" name="message">Hi,
# I am interested in 1100 King Street West, Toronto, ON.</textarea>
# </div>
# <div class="modal-alert hidden alert"></div>
# <a class="customize" href="javascript:;">
# <i aria-hidden="true" class="fa fa-pencil"></i>
# Customize Message
# </a>
# <button class="btn btn-primary" type="submit">Send Message</button>
# </input></form>
# </div>
# </div>
# </div>
# <div class="row row3">
# <div class="col-12 col-12 col-lg-8">
# <div class="mobile-units hidden-sm-up">
# <div class="row no-gutters toggle-unit-details">
# <div class="col-6">
# <a href="javascript:;">1 Bedroom</a>
# </div>
# <div class="col-4">
# $2,150
# </div>
# <div class="col-2">
# <i aria-hidden="true" class="fa fa-chevron-down"></i>
# <i aria-hidden="true" class="fa fa-chevron-up"></i>
# </div>
# <div class="row no-gutters unit-details" style="display: none">
# <div class="col-12">
# <dl>
# <dt>Beds</dt>
# <dd>1</dd>
# <dt>Baths</dt>
# <dd>1</dd>
# </dl>
# <a class="btn btn-primary open-popup" data-target="#modal-contact" data-target-attr-unit_id="1006715" href="javascript:;">Check availability</a>
# </div>
# </div>
# </div>
# <div class="row no-gutters toggle-unit-details">
# <div class="col-6">
# <a href="javascript:;">1 Bedroom</a>
# </div>
# <div class="col-4">
# $2,170
# </div>
# <div class="col-2">
# <i aria-hidden="true" class="fa fa-chevron-down"></i>
# <i aria-hidden="true" class="fa fa-chevron-up"></i>
# </div>
# <div class="row no-gutters unit-details" style="display: none">
# <div class="col-12">
# <dl>
# <dt>Beds</dt>
# <dd>1</dd>
# <dt>Baths</dt>
# <dd>1</dd>
# </dl>
# <a class="btn btn-primary open-popup" data-target="#modal-contact" data-target-attr-unit_id="1006716" href="javascript:;">Check availability</a>
# </div>
# </div>
# </div>
# <div class="row no-gutters toggle-unit-details">
# <div class="col-6">
# <a href="javascript:;">2 Bedroom</a>
# </div>
# <div class="col-4">
# $2,480
# </div>
# <div class="col-2">
# <i aria-hidden="true" class="fa fa-chevron-down"></i>
# <i aria-hidden="true" class="fa fa-chevron-up"></i>
# </div>
# <div class="row no-gutters unit-details" style="display: none">
# <div class="col-12">
# <dl>
# <dt>Beds</dt>
# <dd>2</dd>
# <dt>Baths</dt>
# <dd>1</dd>
# </dl>
# <a class="btn btn-primary open-popup" data-target="#modal-contact" data-target-attr-unit_id="1006717" href="javascript:;">Check availability</a>
# </div>
# </div>
# </div>
# <div class="row no-gutters toggle-unit-details">
# <div class="col-6">
# <a href="javascript:;">2 Bedroom</a>
# </div>
# <div class="col-4">
# $3,635
# </div>
# <div class="col-2">
# <i aria-hidden="true" class="fa fa-chevron-down"></i>
# <i aria-hidden="true" class="fa fa-chevron-up"></i>
# </div>
# <div class="row no-gutters unit-details" style="display: none">
# <div class="col-12">
# <dl>
# <dt>Beds</dt>
# <dd>2</dd>
# <dt>Baths</dt>
# <dd>1</dd>
# </dl>
# <a class="btn btn-primary open-popup" data-target="#modal-contact" data-target-attr-unit_id="1006718" href="javascript:;">Check availability</a>
# </div>
# </div>
# </div>
# <div class="row no-gutters toggle-unit-details">
# <div class="col-6">
# <a href="javascript:;">3 Bedroom</a>
# </div>
# <div class="col-4">
#
# $3,815
# </div>
# <div class="col-2">
# <i aria-hidden="true" class="fa fa-chevron-down"></i>
# <i aria-hidden="true" class="fa fa-chevron-up"></i>
# </div>
# <div class="row no-gutters unit-details" style="display: none">
# <div class="col-12">
# <dl>
# <dt>Beds</dt>
# <dd>3</dd>
# <dt>Baths</dt>
# <dd>1</dd>
# </dl>
# <a class="btn btn-primary open-popup" data-target="#modal-contact" data-target-attr-unit_id="1006719" href="javascript:;">Check availability</a>
# </div>
# </div>
# </div>
# </div>
# <p class="updated-box hidden-sm-up">
# Updated: <span class="updated">March 5, 2020</span>
# </p>
# <div class="visible-sm-up hidden">
# <table class="units missing-dimensions missing-availability">
# <thead>
# <tr>
# <th class="name">Floor Plan</th>
# <th class="beds">Beds</th>
# <th class="baths">Baths</th>
# <th class="price">Price</th>
# <th class="updated">
# Updated: <span class="updated">March 5, 2020</span>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td class="name">
# <span class="floorplan-name">
# 1 Bedroom
# </span>
# </td>
# <td class="beds">1</td>
# <td class="baths">1</td>
# <td class="price">
# $2,150
# </td>
# <td class="hidden-xs"><a class="btn btn-primary open-popup" data-target="#modal-contact" data-target-attr-unit_id="1006715" href="javascript:;">Check availability</a></td>
# </tr>
# <tr>
# <td class="name">
# <span class="floorplan-name">
# 1 Bedroom
# </span>
# </td>
# <td class="beds">1</td>
# <td class="baths">1</td>
# <td class="price">
# $2,170
# </td>
# <td class="hidden-xs"><a class="btn btn-primary open-popup" data-target="#modal-contact" data-target-attr-unit_id="1006716" href="javascript:;">Check availability</a></td>
# </tr>
# <tr>
# <td class="name">
# <span class="floorplan-name">
#
# 2 Bedroom
# </span>
# </td>
# <td class="beds">2</td>
# <td class="baths">1</td>
# <td class="price">
# $2,480
# </td>
# <td class="hidden-xs"><a class="btn btn-primary open-popup" data-target="#modal-contact" data-target-attr-unit_id="1006717" href="javascript:;">Check availability</a></td>
# </tr>
# <tr>
# <td class="name">
# <span class="floorplan-name">
# 2 Bedroom
# </span>
# </td>
# <td class="beds">2</td>
# <td class="baths">1</td>
# <td class="price">
# $3,635
# </td>
# <td class="hidden-xs"><a class="btn btn-primary open-popup" data-target="#modal-contact" data-target-attr-unit_id="1006718" href="javascript:;">Check availability</a></td>
# </tr>
# <tr>
# <td class="name">
# <span class="floorplan-name">
# 3 Bedroom
# </span>
# </td>
# <td class="beds">3</td>
# <td class="baths">1</td>
# <td class="price">
# $3,815
# </td>
# <td class="hidden-xs"><a class="btn btn-primary open-popup" data-target="#modal-contact" data-target-attr-unit_id="1006719" href="javascript:;">Check availability</a></td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="about">
# <h3>About Kings Club</h3>
# <ul class="listing-categories clearfix">
# <li>
# <i class="fa listing-category-pet-friendly-rentals"></i>
# <span class="util-label">Pet Friendly</span>
# </li>
# </ul>
# <div class="description">
# <div class="description-inner listing-description">
# <p>Visit our Website: <a href="https://www.caprent.com/apartments-for-rent/toronto-on/kings-club/" target="_blank">https://www.caprent.com/apartments-for-rent/toronto-on/kings-club/</a></p><b>Why Pay Double?</b><p>Pay One Month and Move In*</p><p> </p><p><b>Rental Office is located in the Kings Club Building at 1100 King Street West 4th Floor</b></p><p><b></b> Experience serious living without the investment - Kings Club is a new purpose-built rental building that offers all the amenities of a condo without the commitment of a mortgage.  </p><p>Located in the heart of Liberty Village, Kings Club offers beautiful downtown Toronto apartments for rent with stainless steel appliances, in-suite laundry, and building amenities like a rooftop infinity pool, yoga room and fitness centre.  </p><p>Aside from the opportunity to rent a brand new bachelor, 1 bedroom, 1 + den, 2 bedroom, 2 +den and 3 bedroom suites, Kings Club residents can easily access three floors of on-site retailers including Shoppers Drug Mart, Longos, Canadian Tire and Kids N Co to name a few.</p><p>* 2 + Den units are over 1,000 square feet</p><p>Parking from: $175.00</p><p>Have Questions? Contact the Property Manager: (416) 306-3051</p><p> </p>Building Features<p><b>Apartment Features</b>
# </p><ul><li>Stainless steel fridge, stove, dishwasher, microwave hood range,
# washer and dryer</li><li>Two-toned kitchen cabinets with under-mount lighting</li><li>Subway tiled glass backsplash for easy clean up</li><li>Two-toned kitchen islands in most suites</li><li>Track lighting in kitchen</li><li>Quartz counter tops</li><li>Contemporary ceramic flooring in bathroom</li><li>Large medicine cabinet in bathroom</li><li>Some suites with glass showers </li><li>Rich laminate flooring</li><li>Smooth finished 9 to 9 ½ foot ceilings</li><li>Pot lights throughout</li><li>Floor to ceiling windows complete with premium window coverings</li><li>Wheelchair accessible suites available
#
#
# ...
# <div class="listing-blurb-content">
# <h5>
# </h5>
# <h4>Downtown Condo 1 bed - Modern</h4>
# <span class="rent">
# $1,950
# </span>
# </div>
# </a>
# </li>
# <li>
# <a href="/toronto/fuzion-condos-id74027">
# <img data-action="lazy-load" data-lazy-load-attr="src" data-lazy-load-src="https://cdn2.torontorentals.com/photos/thumbnail/manage-upload-akosmoveta.com-TWUGck_352x198.jpg"/>
# <div class="listing-blurb-content">
# <h5>
# Fuzion Condos
# </h5>
# <h4>Beautiful 1 Bedroom w/ Parking &amp; Locker!</h4>
# <span class="rent">
# $2,100
# </span>
# </div>
# </a>
# </li>
# <li>
# <a href="/toronto/bridge-id64522">
# <img data-action="lazy-load" data-lazy-load-attr="src" data-lazy-load-src="https://cdn2.torontorentals.com/photos/thumbnail/manage-upload-servicezahraproperties.com-dYtVYf_352x198.jpg"/>
# <div class="listing-blurb-content">
# <h5>
# Bridge
# </h5>
# <h4>Gorgeous Condo For Rent</h4>
# <span class="rent">
# $2,795
# </span>
# </div>
# </a>
# </li>
# <li>
# <a href="/toronto/bridge-condominiums-id64644">
# <img data-action="lazy-load" data-lazy-load-attr="src" data-lazy-load-src="https://cdn2.torontorentals.com/photos/thumbnail/manage-upload-nashjabranigmail.com-FqfneB_352x198.png"/>
# <div class="listing-blurb-content">
# <h5>
# Bridge Condominiums
# </h5>
# <h4>38 Joe Shuster # 1907</h4>
# <span class="rent">
# $2,788
# </span>
# </div>
# </a>
# </li>
# <li>
# <a href="/toronto/bridge-condo-id65620">
# <img data-action="lazy-load" data-lazy-load-attr="src" data-lazy-load-src="https://cdn2.torontorentals.com/photos/thumbnail/manage-upload-servicezahraproperties.com-wiN4zY_352x198.jpg"/>
# <div class="listing-blurb-content">
# <h5>
# Bridge Condo
# </h5>
# <h4>Beautiful Condo for Rent</h4>
# <span class="rent">
# $2,750
# </span>
# </div>
# </a>
# </li>
# <li>
# <a href="/toronto/38-joe-shuster-way-id66357">
# <img data-action="lazy-load" data-lazy-load-attr="src" data-lazy-load-src="https://cdn2.torontorentals.com/photos/thumbnail/manage-upload-leaselifegmail.com-_KNPpY_352x198.jpg"/>
# <div class="listing-blurb-content">
# <h5>
# </h5>
# <h4>38 Joe Shuster Way</h4>
# <span class="rent">
# $2,250 - $2,500
# </span>
# </div>
# </a>
# </li>
# <li>
# <a href="/toronto/the-bridge-id66648">
# <img data-action="lazy-load" data-lazy-load-attr="src" data-lazy-load-src="https://cdn2.torontorentals.com/photos/thumbnail/manage-upload--08o9an_352x198.jpg"/>
# <div class="listing-blurb-content">
# <h5>
# The Bridge
# </h5>
# <h4>2BR+2WA CONDO UNIT FOR RENT - TRENDY LIBERTY VILLAGE</h4>
# <span class="rent">
# $2,850
# </span>
# </div>
# </a>
# </li>
# <li>
# <a href="/toronto/38-joe-shuster-way-unit-999-id68203">
# <img data-action="lazy-load" data-lazy-load-attr="src" data-lazy-load-src="https://cdn2.torontorentals.com/photos/thumbnail/manage-upload-maryannsutton.com-_ocixx_352x198.jpg"/>
# <div class="listing-blurb-content">
# <h5>
# </h5>
# <h4>King WEST/ Dufferin Luxury 1 Bedroom Condo - Parking Included!</h4>
# <span class="rent">
# $2,150
# </span>
# </div>
# </a>
# </li>
# <li>
# <a href="/toronto/the-bridge-id68475">
# <img data-action="lazy-load" data-lazy-load-attr="src" data-lazy-load-src="https://cdn2.torontorentals.com/photos/thumbnail/manage-upload--C5fJWf_352x198.jpeg"/>
# <div class="listing-blurb-content">
# <h5>
# The Bridge
# </h5>
# <h4>1 Bedroom condo in Liberty Village</h4>
# <span class="rent">
# $2,100
# </span>
# </div>
# </a>
# </li>
# <li>
# <a href="/toronto/toronto-condo-living-id69048">
# <img data-action="lazy-load" data-lazy-load-attr="src" data-lazy-load-src="https://cdn2.torontorentals.com/photos/thumbnail/manage-upload-maryannsutton.com-45J_HO_352x198.jpg"/>
# <div class="listing-blurb-content">
# <h5>
# Toronto Condo Living!
# </h5>
# <h4>Trendy 1bedroom Condo in King and Dufferin!</h4>
# <span class="rent">
# $2,150
# </span>
# </div>
# </a>
# </li>
# <li>
# <a href="/toronto/kimberly-parris-id70640">
# <img data-action="lazy-load" data-lazy-load-attr="src" data-lazy-load-src="https://cdn2.torontorentals.com/photos/thumbnail/manage-upload--hw6dCo_352x198.jpg"/>
# <div class="listing-blurb-content">
# <h5>
# Kimberly Parris
# </h5>
# <h4>Downtown Liberty Village 2bdm 1bth Condo</h4>
# <span class="rent">
# $2,450
# </span>
# </div>
# </a>
# </li>
# <li>
# <a href="/toronto/the-bridge-id75374">
# <img data-action="lazy-load" data-lazy-load-attr="src" data-lazy-load-src="https://cdn2.torontorentals.com/photos/thumbnail/manage-upload--rNMYPJ_352x198.jpg"/>
# <div class="listing-blurb-content">
# <h5>
# The Bridge
# </h5>
# <h4>2 bed 2 bath 1 parking Pet Friendly Fully Furnished</h4>
# <span class="rent">
# $3,550
# </span>
# </div>
# </a>
# </li>
# <li>
# <a href="/toronto/kings-club-id73235">
# <img data-action="lazy-load" data-lazy-load-attr="src" data-lazy-load-src="https://cdn2.torontorentals.com/photos/thumbnail/manage-upload--3fqeLe_352x198.jpeg"/>
# <div class="listing-blurb-content">
# <h5>
# King's Club
# </h5>
# <h4>Room in a 2-bed brand new Liberty Village Queen W apartment</h4>
# <span class="rent">
# $1,650
# </span>
# </div>
# </a>
# </li>
# <li>
# <a href="/toronto/westside-gallery-lofts-id64160">
# <img data-action="lazy-load" data-lazy-load-attr="src" data-lazy-load-src="https://cdn2.torontorentals.com/photos/thumbnail/manage-upload--Dn9d3S_352x198.jpg"/>
# <div class="listing-blurb-content">
# <h5>
# Westside Gallery Lofts
# </h5>
# <h4>1 Bedroom + Study Nook. Bright and beautiful corner unit!</h4>
# <span class="rent">
# $2,400
# </span>
# </div>
# </a>
# </li>
# <li>
# <a href="/toronto/150-sudbury-st-id67505">
# <img data-action="lazy-load" data-lazy-load-attr="src" data-lazy-load-src="https://cdn2.torontorentals.com/photos/thumbnail/manage-upload--Qvm1hz_352x198.jpg"/>
# <div class="listing-blurb-content">
# <h5>
# </h5>
# <h4>Perfect Newly Furnished (optional) Downtown Toronto 2 Bedroom Condo</h4>
# <span class="rent">
# $2,500
# </span>
# </div>
# </a>
# </li>
# <li>
# <a href="/toronto/westside-gallery-lofts-id69007">
# <img data-action="lazy-load" data-lazy-load-attr="src" data-lazy-load-src="https://cdn2.torontorentals.com/photos/thumbnail/manage-upload-srpintohotmail.com-EGQHY2_352x198.jpg"/>
# <div class="listing-blurb-content">
# <h5>
# Westside Gallery Lofts
# </h5>
# <h4>Queen West Condo for Rent</h4>
# <span class="rent">
# $2,300
# </span>
# </div>
# </a>
# </li>
# <li>
# <a href="/toronto/150-sudbury-st-id64495">
# <img data-action="lazy-load" data-lazy-load-attr="src" data-lazy-load-src="https://cdn2.torontorentals.com/photos/thumbnail/manage-upload-jared333chotmail.com-wmu2yr_352x198.jpeg"/>
# <div class="listing-blurb-content">
# <h5>
# </h5>
# <h4>West Queen West - Art &amp; Design District - 2bdrm 2 bathroom</h4>
# <span class="rent">
# $3,100
# </span>
# </div>
# </a>
# </li>
# <li>
# <a href="/toronto/150-sudbury-st-id66361">
# <img data-action="lazy-load" data-lazy-load-attr="src" data-lazy-load-src="https://cdn2.torontorentals.com/photos/thumbnail/manage-upload-leaselifegmail.com-3T3ajS_352x198.jpg"/>
# <div class="listing-blurb-content">
# <h5>
# 150 Sudbury St
# </h5>
# <span class="rent">
# $2,350
# </span>
# </div>
# </a>
# </li>
# <li>
# <a href="/toronto/36-lisgar-st-id66353">
# <img data-action="lazy-load" data-lazy-load-attr="src" data-lazy-load-src="https://cdn2.torontorentals.com/photos/thumbnail/manage-upload-leaselifegmail.com-azIwuj_352x198.jpg"/>
# <div class="listing-blurb-content">
# <h5>
# 36 Lisgar St
# </h5>
# <span class="rent">
# $2,000 - $2,525
#
# </span>
# </div>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="col-12 col-lg-4 side-panels">
# <div class="side-panel listing-info row">
# <div class="col-6">
# Listing ID: 60237
# </div>
# </div>
# <div class="panel related-searches">
# <h3 class="panel-title">Related Searches</h3>
# <div class="panel-content">
# <ul>
# <li>
# <a href="/toronto/apartments">All Toronto apartments</a>
# </li>
# <li>
# <a href="/toronto/apartments?beds=0">Studio Toronto apartments</a>
# </li>
# <li>
# <a href="/toronto/apartments?beds=1">1 bedroom Toronto apartments</a>
# </li>
# <li>
# <a href="/toronto/apartments?beds=2">2 bedroom Toronto apartments</a>
# </li>
# <li>
# <a href="/toronto/apartments?beds=3">3 bedroom Toronto apartments</a>
# </li>
# <li>
# <a href="/toronto/apartments?beds=4%2B">4 bedroom Toronto apartments</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="modal fade" id="modal-contact" role="dialog" tabindex="-1">
# <div class="modal-dialog" role="document">
# <div class="modal-content">
# <form action="/api/v4/properties/60237/leads" class="material" method="post">
# <input name="csrfmiddlewaretoken" type="hidden" value="Py7DVi1Imid0galeu4Z6yc7u3gsuRkL24kaMauU4JHHtE0LHXVBpnigfxR8knknT"/>
# <div class="modal-header">
# <h5 class="modal-title">
# Send Message to:
# <span class="modal-subtitle">
# 1100 King Street West - Toronto
# </span>
# </h5>
# <button aria-label="Close" class="close" data-dismiss="modal" type="button">
# <span aria-hidden="true">×</span>
# </button>
# </div>
# <div class="modal-body row-as-line">
# <div class="listing-phone-click-to-reveal" data-listing-id="60237">
# <div class="listing-phone-click-to-reveal__activate">
# <a href="#">
# <i aria-hidden="true" class="fa fa-phone"></i>
# View Phone Number
# </a>
# </div>
# <div class="listing-phone-click-to-reveal__content">
# Contact @ <a href="tel:(416) 306-3051">(416) 306-3051</a>
# </div>
# </div>
# <div class="row">
# <div class="col-12">
# <div class="form-group">
# <input class="form-control" id="contact-name" name="name" required="" type="text"/>
# <label for="contact-name">Your Name*</label>
# </div>
# </div>
# </div>
# <div class="row">
# <div class="col-12">
# <div class="form-group select-wrapper">
# <select class="form-control" name="unit_id">
# <option value="1006715">$2,150 |
# 1 Bedroom</option>
# <option value="1006716">$2,170 |
# 1 Bedroom</option>
# <option value="1006717">$2,480 |
# 2 Bedroom</option>
# <option value="1006718">$3,635 |
#
# 2 Bedroom</option>
# <option value="1006719">$3,815 |
# 3 Bedroom</option>
# </select>
# <label for="unit_id">Unit</label>
# </div>
# </div>
# </div>
# <div class="row">
# <div class="col-6">
# <div class="form-group">
# <input class="form-control" id="contact-email" name="email" type="email"/>
# <label for="contact-email">Email</label>
# </div>
# </div>
# <div class="col-6">
# <div class="form-group">
# <input class="form-control" id="contact-phone" name="phone" type="tel"/>
# <label for="contact-phone">Phone</label>
# </div>
# </div>
# </div>
# <div class="row">
# <div class="col-12">
# <textarea class="form-control" name="message">I would like to schedule a time to view your listing. Please let me know when the best time would be.
# Thank you!</textarea>
# </div>
# </div>
# <div class="modal-alert alert"></div>
# <div class="row mb-0 text-right">
# <div class="col-12">
# <button class="btn btn-primary" type="submit">Send</button>
# </div>
# </div>
# </div>
# </form>
# </div>
# </div>
# </div>
# <div class="modal fade" id="modal-share-listing" role="dialog" tabindex="-1">
# <div class="modal-dialog" role="document">
# <form action="/api/v4/properties/60237/share-listing" class="material" method="post">
# <input name="csrfmiddlewaretoken" type="hidden" value="Py7DVi1Imid0galeu4Z6yc7u3gsuRkL24kaMauU4JHHtE0LHXVBpnigfxR8knknT"/>
# <div class="modal-content">
# <div class="modal-header">
# <h5 class="modal-title">
# Share listing
# <span class="modal-subtitle">
# Send via Email
# </span>
# </h5>
# <button aria-label="Close" class="close" data-dismiss="modal" type="button">
# <span aria-hidden="true">×</span>
# </button>
# </div>
# <div class="modal-body form-group-as-line">
# <div class="form-group">
# <input class="form-control" id="share-email" name="email" required="" type="email"/>
# <label for="share-email">Email*</label>
# <div class="input-inner">
# <a href="javascript:;">+ Add Another</a>
# </div>
# </div>
# <div class="modal-alert alert"></div>
# <div class="d-flex justify-content-between align-items-center">
# <p class="mb-0 mr-2">Don't worry, we won't subscribe anyone to anything!</p>
# <button class="btn btn-primary" type="submit">Share</button>
# </div>
# </div>
# </div>
# </form>
# </div>
# </div>
# </div>
# <a name="footer"></a>
# <footer id="global-footer">
# <div class="container">
# <div class="logo">
# <a class="logo-link" href="/">
# <strong>TorontoRentals</strong>.com
# <p>Let us guide you home</p>
# </a>
# </div>
# <div class="sitemap">
# <h3>Sitemap</h3>
# <ul>
# <li><a href="/">Home</a></li>
# <li><a href="/neighbourhood-guide/toronto">Neighbourhood Guide</a></li>
# <li><a href="/contact">Contact</a></li>
# <li><a href="/blog/">Blog</a></li>
# <li><a href="/sitemap">Sitemap</a></li>
# <li><a href="/off-campus-housing">Off-Campus Housing</a></li>
# </ul>
# </div>
# <div class="popular">
# <h3>Popular Searches</h3>
# <ul>
# <li><a href="/toronto">All Toronto Rentals</a></li>
# <li><a href="/toronto/apartments">Toronto Apartments</a></li>
# <li><a href="/toronto/condos">Toronto Condos</a></li>
# <li><a href="/toronto/houses">Toronto Houses</a></li>
# <li><a href="/toronto/basements">Toronto Basements</a></li>
# <li><a href="/mississauga">Mississauga Apartments</a></li>
# <li><a href="/scarborough">Scarborough Apartments</a></li>
# <li><a href="/etobicoke">Etobicoke Apartments</a></li>
# <li><a href="/north-york">North York Apartments</a></li>
# <li><a href="/vaughan">Vaughan Apartments</a></li>
# </ul>
# </div>
# <div class="social">
# <h3>Connect with us</h3>
# <ul class="social-profiles list-unstyled list-inline social">
# <li class="social-instagram">
# <a href="https://www.instagram.com/to.rentals/" rel="noopener" target="_blank">
# <i class="fa fa-instagram"></i>
# <span class="hidden label">Instagram</span>
# </a>
# </li>
# <li class="social-facebook">
# <a href="https://www.facebook.com/torentals/" rel="noopener" target="_blank">
# <i class="fa fa-facebook-square"></i>
# <span class="hidden label">Facebook</span>
# </a>
# </li>
# <li class="social-youtube">
# <a href="https://www.youtube.com/channel/UCxx2QQwDaGaTarDNjOBRnMw" rel="noopener" target="_blank">
# <i class="fa fa-youtube-play"></i>
# <span class="hidden label">Youtube</span>
# </a>
# </li>
# <li class="social-twitter">
# <a href="http://twitter.com/torentals" rel="noopener" target="_blank">
# <i class="fa fa-twitter"></i>
# <span class="hidden label">Twitter</span>
# </a>
# </li>
# <li class="social-linkedin">
# <a href="https://www.linkedin.com/company/toronto-rentals-com" rel="noopener" target="_blank">
# <i class="fa fa-linkedin-square"></i>
# <span class="hidden label">LinkedIn</span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="copyright">
# <div class="container">
# TorontoRentals.com © 1995-2018 Toronto Rentals -
# <ul class="copyright-links">
# <li>
# <a href="/privacy">Privacy Policy</a>
# </li>
# <li>
# <a href="/terms">Terms of Use</a>
# </li>
# </ul>
# </div>
# </div>
# </footer>
# <!--[if lt IE 7]>
#       <p class="chromeframe">You are using an <strong>outdated</strong> browser. Please <a href="http://browsehappy.com/">upgrade your browser</a> or <a href="http://www.google.com/chromeframe/?redirect=true">activate Google Chrome Frame</a> to improve your experience.</p>
#     <![endif]-->
# <script src="https://maps.googleapis.com/maps/api/js?key=AIzaSyCBJeBxHKmIYsccLvyAVJju3trAcPm0N00&amp;libraries=places,geometry"></script>
# <script charset="utf-8" src="/static/torontorentalscom/dist/listing-page.c77be7b05abe.js" type="text/javascript"></script>
# <script type="text/javascript">
#    (function(a,e,c,f,g,h,b,d){var k={ak:"1071770407",cl:"VAfQCKys724Qp9aH_wM",autoreplace:"60237"};a[c]=a[c]||function(){(a[c].q=a[c].q||[]).push(arguments)};a[g]||(a[g]=k.ak);b=e.createElement(h);b.async=1;b.src="//www.gstatic.com/wcm/loader.js";d=e.getElementsByTagName(h)[0];d.parentNode.insertBefore(b,d);a[f]=function(b,d,e){a[c](2,b,k,d,null,new Date,e)};})(window,document,"_googWcmImpl","_googWcmGet","_googWcmAk","script");
#   </script>
# <script type="text/javascript">
#     (function(i,s,o,g,r,a,m){i['TrovitAnalyticsObject']=r;i[r]=i[r]||function(){
#     (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#     m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#     })(window,document,'script','https://analytics.trovit.com/trovit-analytics.js','ta');
#
#     ta('init', 'ca', 1, '5e702b013f51973a44082ff4130b3dd3');
# </script>
# <script async="" defer="">
#  if ($.widget != null && $.ui != null && $.ui.tooltip != null)
#      $.widget.bridge('uitooltip', $.ui.tooltip);
#
#  globs = {
#      urls: {
#          root: '/',
#          api_accounts: '/api/v4/accounts/',
#          api_login_account: '/staff/api/login_account',
# 	 api_reset_password: "/api/v4/accounts/reset-password"
#      },
#      staticprefix: '/static/',
#      csrf: 'Py7DVi1Imid0galeu4Z6yc7u3gsuRkL24kaMauU4JHHtE0LHXVBpnigfxR8knknT'
#  };
# </script>
# </body>
# </html>

# %%
table = sub_soap.find_all('td')
table
# Out:
# [<td class="name">
#  <span class="floorplan-name">
#  1 Bedroom
#  </span>
#  </td>,
#  <td class="beds">1</td>,
#  <td class="baths">1</td>,
#  <td class="price">
#  $2,150
#  </td>,
#  <td class="hidden-xs"><a class="btn btn-primary open-popup" data-target="#modal-contact" data-target-attr-unit_id="1006715" href="javascript:;">Check availability</a></td>,
#  <td class="name">
#  <span class="floorplan-name">
#  1 Bedroom
#  </span>
#  </td>,
#  <td class="beds">1</td>,
#  <td class="baths">1</td>,
#  <td class="price">
#  $2,170
#  </td>,
#  <td class="hidden-xs"><a class="btn btn-primary open-popup" data-target="#modal-contact" data-target-attr-unit_id="1006716" href="javascript:;">Check availability</a></td>,
#  <td class="name">
#  <span class="floorplan-name">
#
#  2 Bedroom
#  </span>
#  </td>,
#  <td class="beds">2</td>,
#  <td class="baths">1</td>,
#  <td class="price">
#  $2,480
#  </td>,
#  <td class="hidden-xs"><a class="btn btn-primary open-popup" data-target="#modal-contact" data-target-attr-unit_id="1006717" href="javascript:;">Check availability</a></td>,
#  <td class="name">
#  <span class="floorplan-name">
#  2 Bedroom
#  </span>
#  </td>,
#  <td class="beds">2</td>,
#  <td class="baths">1</td>,
#  <td class="price">
#  $3,635
#  </td>,
#  <td class="hidden-xs"><a class="btn btn-primary open-popup" data-target="#modal-contact" data-target-attr-unit_id="1006718" href="javascript:;">Check availability</a></td>,
#  <td class="name">
#  <span class="floorplan-name">
#  3 Bedroom
#  </span>
#  </td>,
#  <td class="beds">3</td>,
#  <td class="baths">1</td>,
#  <td class="price">
#  $3,815
#  </td>,
#  <td class="hidden-xs"><a class="btn btn-primary open-popup" data-target="#modal-contact" data-target-attr-unit_id="1006719" href="javascript:;">Check availability</a></td>]

# %%
beds = table[1]
beds = BeautifulSoup(beds.text,"html.parser")

# %%
bath = table[2]
bath.text
# Out:
# '1'

# %%
price = table[3]
price.text.strip('\n')
# Out:
# '$2,150'

# %%
table[5]
# Out:
# <td class="name">
# <span class="floorplan-name">
# 1 Bedroom
# </span>
# </td>

# %%
sub_soap = BeautifulSoup(response2.text,"html.parser")
sub_soap
table = sub_soap.find_all('td')
table

for i in range(0,len(table),5):
    print(i)
    beds = BeautifulSoup((table[i+1]).text,"html.parser")
    bath = BeautifulSoup((table[i+2]).text,"html.parser")
    price = BeautifulSoup((table[i+3]).text,"html.parser")
    print("No of bedrooms are {}, No of bathrooms are {}, Price is {}".format(beds,bath,price))
# Out:
# 0
# No of bedrooms are 1, No of bathrooms are 1, Price is
# $2,150
#
# 5
# No of bedrooms are 1, No of bathrooms are 1, Price is
# $2,170
#
# 10
# No of bedrooms are 2, No of bathrooms are 1, Price is
# $2,480
#
# 15
# No of bedrooms are 2, No of bathrooms are 1, Price is
# $3,635
#
# 20
# No of bedrooms are 3, No of bathrooms are 1, Price is
# $3,815
